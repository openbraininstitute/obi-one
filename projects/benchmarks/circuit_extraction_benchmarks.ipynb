# %% [markdown]
# # Notebook for running circuit extraction benchmraks using the task-launch endpoint
#
# Requirements:
# - obi-one service running locally: `make run-local`
# - Access token: To be copied from platform and pasted below

# %%
import httpx
import obi_one as obi
from entitysdk import Client, ProjectContext, models
from http import HTTPStatus

environment = "staging"
virtual_lab_id = obi.LAB_ID_STAGING_TEST
project_id = obi.PROJECT_ID_STAGING_TEST

token = "eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJZVTEyTEoyNG1sRFRieURlWXgyaGU5RkQzbldkWlBSV2piSVVpa2hocVFVIn0.....PW_igP3HKc1nkuFUb85_t3LPFiR7BVEMA7oF3S10TNAbZZvAZ-32XcW2gAF_CADsM7_rxUYCp8jvMKmoG2yHVkqCdA4Euhz7CQa0OdvxcUzqzAWlIuUh42wAF9s8N___iZjNqF7TeEsUgx10zX2IdD4l3FJCgZ3UX2KHZ6Bstlb8jAFN-RvUVlTvBBbUSLmlk6oLEQuHApkIOTl571Gy2LAdsm-NC03dJ54eUD0nblb70ierxee5MP6nI9Z4eZ2iZTZDsUxOPX2rU5ABMXGUyTNcFalP4gegjvdCkmvKOif3O3ZWYUYLLV4MdIQVUJdXGO473GWTzVrAj38Ofgc0TQ"

# Get DB client
project_context = ProjectContext(virtual_lab_id=virtual_lab_id, project_id=project_id)
db_client = Client(environment=environment, project_context=project_context, token_manager=token)

# Get obi-one API client
OBI_ONE_API_URL = "http://127.0.0.1:8100"
headers = {
    "Authorization": f"Bearer {token}",
    "virtual-lab-id": virtual_lab_id,
    "project-id": project_id,
}
api_client = httpx.Client(base_url=OBI_ONE_API_URL, headers=headers)

# %% [markdown]
# ## Set up circuit extraction benchmark
#
# ### a. Extract a small microcircuit with 10 neurons from parent circuits of different sizes

# %%
neuron_set = obi.IDNeuronSet(neuron_ids=obi.NamedTuple(name="ID0to9", elements=tuple(range(10))))

# %%
# Circuit 0
circuit_id = "418ceb65-af88-419b-98e9-3b3d8db3b4ff"  # nbS1-O1-vSub-nCN-HEX0-L1-01
info = obi.Info(campaign_name="BENCHMARK-Extraction-a0_0", campaign_description="BENCHMARK Extraction of 10 neurons")
do_virtual = True
create_external = True

# %% [markdown]
# ### b. Extract certain percentages (1%, 10%, 100%) from parent circuits of different sizes

# %%
# target_neuron_set = obi.AllNeurons(sample_seed=0, sample_percentage=1)
# target_neuron_set = obi.AllNeurons(sample_seed=0, sample_percentage=10)
# target_neuron_set = obi.AllNeurons(sample_seed=0, sample_percentage=100)

# %% [markdown]
# ### Check circuit

# %%
circuit_from_id = obi.CircuitFromID(id_str=circuit_id)
circuit_entity = circuit_from_id.entity(db_client=db_client)

print()
print(f"{circuit_entity.name} (ID {circuit_entity.id})")
print(f"#Neurons: {circuit_entity.number_neurons}, #Synapses: {circuit_entity.number_synapses}, #Connections: {circuit_entity.number_connections}")
# Out:
# [2026-02-16 17:11:54,011] INFO: HTTP Request: GET https://staging.cell-a.openbraininstitute.org/api/entitycore/circuit/418ceb65-af88-419b-98e9-3b3d8db3b4ff "HTTP/1.1 200 OK"
#
# nbS1-O1-vSub-nCN-HEX0-L1-01 (ID 418ceb65-af88-419b-98e9-3b3d8db3b4ff)
# #Neurons: 10, #Synapses: 234, #Connections: 11

# %% [markdown]
# ## Generate benchmark campaign

# %%
# Create a CircuitExtractionScanConfig.initialize object
initialize = obi.CircuitExtractionScanConfig.Initialize(circuit=circuit_from_id, do_virtual=do_virtual, create_external=create_external)

# Create a CircuitExtractionScanConfig object with the initialize object
scan_config = obi.CircuitExtractionScanConfig(initialize=initialize, neuron_set=neuron_set, info=info)

# Create the grid scan object
output_root = f"../../../../obi-output-BENCHMARKS/{info.campaign_name}/grid_scan"
scan = obi.GridScanGenerationTask(
    form=scan_config,
    coordinate_directory_option="ZERO_INDEX",
    output_root=output_root
)

# Run the scan
# use_cache = False  # W/o cache, each circuit will be downloaded separatly for every scan coordinate (and deleted afterwards)
use_cache = True  # With cache, each circuit will only be downloaded once (and kept in the root folder of the scan)
scan.execute(db_client=db_client)
# Out:
# [2026-02-16 17:17:27,415] INFO: 1. Initializing circuit extraction campaign in the database...
# [2026-02-16 17:17:27,416] INFO: -- Register CircuitExtractionCampaign Entity
# [2026-02-16 17:17:28,342] INFO: HTTP Request: POST https://staging.cell-a.openbraininstitute.org/api/entitycore/circuit-extraction-campaign "HTTP/1.1 200 OK"
# [2026-02-16 17:17:28,342] INFO: -- Upload campaign_generation_config
# [2026-02-16 17:17:28,787] INFO: HTTP Request: POST https://staging.cell-a.openbraininstitute.org/api/entitycore/circuit-extraction-campaign/77da7ca5-ecc8-442b-99c6-8e30b82df987/assets "HTTP/1.1 201 Created"
# [2026-02-16 17:17:28,790] INFO: 2.0 Saving circuit extraction 0 to database...
# [2026-02-16 17:17:28,791] INFO: -- Register CircuitExtractionConfig Entity
# [2026-02-16 17:17:28,974] INFO: HTTP Request: POST https://staging.cell-a.openbraininstitute.org/api/entitycore/circuit-extraction-config "HTTP/1.1 200 OK"
# [2026-02-16 17:17:28,975] INFO: -- Upload circuit_extraction_config
# [2026-02-16 17:17:29,469] INFO: HTTP Request: POST https://staging.cell-a.openbraininstitute.org/api/entitycore/circuit-extraction-config/e101ff78-8531-4218-86c2-a17c3759d41b/assets "HTTP/1.1 201 Created"
# [2026-02-16 17:17:29,470] INFO: 3. Saving completed circuit extraction campaign generation
# [2026-02-16 17:17:29,470] INFO: -- Register CircuitExtractionConfigGeneration Entity
# [2026-02-16 17:17:29,750] INFO: HTTP Request: POST https://staging.cell-a.openbraininstitute.org/api/entitycore/circuit-extraction-config-generation "HTTP/1.1 200 OK"

# %% [markdown]
# ### Check generated camapaign

# %%
campaign_entity = scan.form.campaign
print(f"Campaign '{campaign_entity.name}' (ID {campaign_entity.id}): {campaign_entity.description}")

assert len(scan.single_configs) == 1, "ERROR: Single coordinate expected!"

# Select first config and check entity
single_config_entity = scan.single_configs[0].single_entity
single_config_type = single_config_entity.__class__.__name__
single_config_id = single_config_entity.id
print(f"  -> Using '{single_config_type}' with ID {single_config_id}")
# Out:
# Campaign 'BENCHMARK-Extraction-a0_0' (ID 77da7ca5-ecc8-442b-99c6-8e30b82df987): BENCHMARK Extraction of 10 neurons
#   -> Using 'CircuitExtractionConfig' with ID e101ff78-8531-4218-86c2-a17c3759d41b

# %% [markdown]
# ## Launch benchmark

# %%
# Launch job
payload = {
    "task_type": "circuit_extraction",
    "config_id": str(single_config_id),
}
url = "/declared/task/launch"
response = api_client.post(url=url, json=payload, timeout=300.0)
# Out:
# [2026-02-16 17:21:36,247] INFO: HTTP Request: POST http://127.0.0.1:8100/declared/task/launch "HTTP/1.1 200 OK"

# %%
# Check status after job submission
if response.status_code == HTTPStatus.OK:
    data = response.json()
    print("Success:", data)
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# Success: {'task_type': 'circuit_extraction', 'config_id': 'e101ff78-8531-4218-86c2-a17c3759d41b', 'activity_id': '345a9167-dcbe-4f18-9c12-b1be6cda9a16', 'job_id': '019c6741-defa-7673-bab6-fe13585dcca9'}

# %% [markdown]
# ### Check execution activity
#
# The execution activity has information about the status, used config, executor job, and once done the extracted sub-circuit.

# %%
execution_activity_id = data["activity_id"]  # Response data is activity ID
execution_activity = db_client.get_entity(entity_type=models.CircuitExtractionExecution, entity_id=execution_activity_id)
job_id = execution_activity.execution_id
print(f"Activity '{str(execution_activity.type)}': ID {execution_activity_id}")
print(f"  Status: {execution_activity.status}")
for _used in execution_activity.used:
    print(f"  Used '{str(_used.type)}': ID {str(_used.id)}")
for _gen in execution_activity.generated:
    print(f"  Generated '{str(_gen.type)}': ID {str(_gen.id)}")
print(f"  Executed by '{str(execution_activity.executor)}': ID {job_id}")
# Out:
# [2026-02-16 17:24:39,326] INFO: HTTP Request: GET https://staging.cell-a.openbraininstitute.org/api/entitycore/circuit-extraction-execution/345a9167-dcbe-4f18-9c12-b1be6cda9a16 "HTTP/1.1 200 OK"
# Activity 'circuit_extraction_execution': ID 345a9167-dcbe-4f18-9c12-b1be6cda9a16
#   Status: done
#   Used 'circuit_extraction_config': ID e101ff78-8531-4218-86c2-a17c3759d41b
#   Generated 'circuit': ID 5f1f5bff-ce3c-4c62-9ee9-c7cf1aa97b71
#   Executed by 'single_node_job': ID 019c6741-defa-7673-bab6-fe13585dcca9

# %% [markdown]
# ---

# %%
# # Manually call failure callback
# callback_payload = {
#     "task_type": "circuit_extraction",
#     "activity_id": execution_activity_id,
# }
# callback_url = "/declared/task/callback/failure"
# callback_response = api_client.post(url=callback_url, params=callback_payload, timeout=300.0)
# Out:
# [2026-02-11 14:36:33,655] INFO: HTTP Request: POST http://127.0.0.1:8100/declared/task/callback/failure?task_type=circuit_extraction&activity_id=74460bc0-8bab-462f-bcbb-526424d9acd8 "HTTP/1.1 204 No Content"
