# %% [markdown]
# # Convert input spikes of a simulation campaign from .dat to .h5 format
#
# - Incl. patching the `simulation_config.json` files to point to the new .h5 files

# %%
import json
import subprocess
from pathlib import Path
from shutil import copyfile, move

# %%
# data_root = Path("/Users/pokorny/Data")
data_root = Path("/Users/james/Documents/obi/Data")

ignore_boundary_neurons = []

# CAMPAIGN_PATH = data_root / Path("Simulations/BBP-curated/SM-whisker-scan")
# SPIKE_PATH = data_root / Path("Simulations/BBP-raw/SM-whisker-scan/518fbeaf-f0ba-4f99-a0ff-22cb7e89eed7")
# blue_config_converted=False

# CAMPAIGN_PATH = data_root / Path("Simulations/BBP-curated/assemblies")
# SPIKE_PATH = data_root / Path("Simulations/BBP-raw/assemblies/d21efd45-7740-4268-b06f-e1de35f2b6cf")
# blue_config_converted=True

CAMPAIGN_PATH = data_root / Path("Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids")
SPIKE_PATH = data_root / Path("Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af")
blue_config_converted=True
ignore_boundary_neurons = [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]

SIM_CONFIG_NAME = "simulation_config.json"
STIM_NAME = "Stimulus spikeReplay"
STIM_POPULATION = "VPM"

# CONVERTER_TOOL = "/Users/pokorny/JupyterLab/git/libsonatareport/build/tools/converter/spikes_converter"
CONVERTER_TOOL = "/Users/james/Documents/obi/code/obi-misc/libsonatareport/build/tools/converter/spikes_converter"

# %%
# Check sub-folders
sim_folders = list(CAMPAIGN_PATH.glob("*[0-9]"))
sim_folder_names = [f.name for f in sim_folders]
print(sim_folder_names)
sim_configs = [_sim / SIM_CONFIG_NAME for _sim in sim_folders]
num_sims = len(sim_folders)
print(f"Found {num_sims} simulation(s) in campaign")
assert all(str(idx) in sim_folder_names for idx in range(num_sims)), "ERROR: Subfolder names do not match simulation indices!"
assert all(_cfg.is_file() for _cfg in sim_configs), "ERROR: Simulation config(s) not found!"
# Out:
# ['32', '35', '34', '33', '20', '18', '27', '9', '0', '11', '7', '29', '16', '6', '28', '17', '1', '10', '19', '26', '8', '21', '31', '30', '24', '23', '4', '15', '3', '12', '2', '13', '5', '14', '22', '25']
# Found 36 simulation(s) in campaign

# %%
# Check spike files
## NOTE THIS WONT WORK FOR CONVERTED BLUECONFIG SIMS WHICH WILL BE DEALT WITH LATER
input_spike_files = []
output_spike_files = []
for idx, cfg in enumerate(sim_configs):
    with open(cfg, "r") as f:
        cfg_dict = json.load(f)
    if blue_config_converted:
        inp_path = SPIKE_PATH / str(idx) / "input.dat"
        out_file = "input.h5"
    else:
        inp_file = cfg_dict["inputs"][STIM_NAME]["spike_file"]
        assert Path(inp_file).suffix.lower() == ".dat", "ERROR: .dat input expected!"
        inp_path = SPIKE_PATH / str(idx) / inp_file
        out_file = Path(inp_file).stem + ".h5"
    assert inp_path.is_file(), f"ERROR: Input spike file '{inp_path}' not found!"
    out_path = CAMPAIGN_PATH / str(idx) / out_file
    assert not out_path.is_file(), f"ERROR: Output spike file '{out_path}' already exists!"
    input_spike_files.append(inp_path)
    output_spike_files.append(out_path)
    print(f"Simulation {idx}: Spike file '{inp_path}'")

# %%
# Run conversion
for idx, (inp, out) in enumerate(zip(input_spike_files, output_spike_files)):
    print(f"Simulation {idx}: Converting '{inp}' -> '{out}'...")

    # Run conversion
    convert_out = subprocess.check_output(f"{CONVERTER_TOOL} {inp} {STIM_POPULATION}", shell=True, text=True)
    print(convert_out)

    # Move converted file from current directory to destination folder
    converted_file = inp.name + ".h5"
    assert Path(converted_file).is_file(), "ERROR: Converted file not found!"

    # if not blue_config_converted:
    move(src=converted_file, dst=out)

# %%
if not blue_config_converted:

    # Patch simulation configs
    for idx, cfg in enumerate(sim_configs):
        # Create .BAK
        bak_file = cfg.parent / (cfg.stem + ".BAK")
        if not bak_file.is_file():
            # Create only if not existing yet (to avoid overwriting)
            copyfile(src=cfg, dst=bak_file)

        # Patch config
        with open(cfg, "r") as f:
            cfg_dict = json.load(f)
        
        spk_file = cfg_dict["inputs"][STIM_NAME]["spike_file"]
        assert spk_file == input_spike_files[idx].name, "ERROR: Spike file name mismatch!"
        spk_file_new = output_spike_files[idx].name
        cfg_dict["inputs"][STIM_NAME]["spike_file"] = spk_file_new
        
        with open(cfg, "w") as f:
            json.dump(cfg_dict, f, indent=2)
        print(f"Simulation {idx}: Config file '{cfg}' written")

# %% [markdown]
# # Optionally split nbS1 inputs into two files (VPM and POm)
# For old BlueConfig based sims in which inputs were in one file

# %%
thalamic_input_files = output_spike_files

for idx, cfg in enumerate(sim_configs):
    spike_file = CAMPAIGN_PATH / f"{idx}" / "input.h5"
    output_spike_root = CAMPAIGN_PATH / f"{idx}"

    assert spike_file.is_file(), f"ERROR: Output spike file '{spike_file}' not found!"

    import h5py
    import numpy as np

    VPM_START = 5_000_000
    POM_START = 6_000_000  # exclusive
    
    vpm_out = output_spike_root / ("input_VPM.h5")
    pom_out = output_spike_root / ("input_POm.h5")

    # vpm_out = spike_file.with_name(spike_file.stem + "_VPM.h5")
    # pom_out = spike_file.with_name(spike_file.stem + "_POm.h5")

    with h5py.File(spike_file, "r") as fin:
        node_ids = fin["spikes/VPM/node_ids"][:]       # (N,)
        timestamps = fin["spikes/VPM/timestamps"][:]   # (N,)

        print(f"Input file:   {spike_file}")

        # Masks
        vpm_mask = (node_ids >= VPM_START) & (node_ids < POM_START)
        pom_mask = ~vpm_mask

    # -------- VPM FILE --------
    if len(timestamps[vpm_mask]) > 0:
        with h5py.File(vpm_out, "w") as fout:
            g_spikes = fout.create_group("spikes")
            g_vpm = g_spikes.create_group("VPM")

            g_vpm.create_dataset("node_ids", data=node_ids[vpm_mask] - VPM_START)
            g_vpm.create_dataset("timestamps", data=timestamps[vpm_mask])

            print(f"VPM file:     {vpm_out} ({vpm_mask.sum()} spikes)")
    else:
        print(f"WARNING: No VPM spikes found for simulation {idx}!")

    # -------- POm FILE --------
    if (len(timestamps[pom_mask]) > 0):
        with h5py.File(pom_out, "w") as fout:
            g_spikes = fout.create_group("spikes")
            g_pom = g_spikes.create_group("POm")

            g_pom.create_dataset("node_ids", data=node_ids[pom_mask] - POM_START)
            g_pom.create_dataset("timestamps", data=timestamps[pom_mask])

            print(f"POm file:     {pom_out} ({pom_mask.sum()} spikes)")
    else:
        print(f"WARNING: No POm spikes found for simulation {idx}!")

    print("-" * 50)

# %% [markdown]
# # Optionally create new output spike file with "S1nonbarrel_neurons" name
# (For old BlueConfig sims)

# %%
import h5py

if blue_config_converted:
    for idx, cfg in enumerate(sim_configs):
        inp_path = SPIKE_PATH / str(idx) / "out.h5"

        with h5py.File(inp_path, "r") as fin:
            node_ids = fin["spikes/All/node_ids"][:]       # (N,)
            timestamps = fin["spikes/All/timestamps"][:]   # (N,)

        reporting_dir = CAMPAIGN_PATH / str(idx) / "reporting"
        reporting_dir.mkdir(exist_ok=True)
        with h5py.File(reporting_dir / "spikes_corrected_population.h5", "w") as f:

            g_spikes = f.create_group("spikes")
            g_pom = g_spikes.create_group("S1nonbarrel_neurons")

            g_pom.create_dataset("node_ids", data=node_ids)
            g_pom.create_dataset("timestamps", data=timestamps)

# %% [markdown]
# # Remap output spike ids

# %%
import h5py
import json
import numpy as np
from pathlib import Path
from time import perf_counter

_ID_MAPPING_CACHE = None
_ID_MAPPING_FILE = Path("/Users/james/Documents/obi/Data/Circuits/nbS1-O1/id_mapping.json")

def _load_id_mapping():
    global _ID_MAPPING_CACHE

    if _ID_MAPPING_CACHE is not None:
        return _ID_MAPPING_CACHE

    if not _ID_MAPPING_FILE.exists():
        print(f"Mapping file not found: {_ID_MAPPING_FILE}")
        _ID_MAPPING_CACHE = {}
        return _ID_MAPPING_CACHE

    t0 = perf_counter()
    with _ID_MAPPING_FILE.open("r", encoding="utf-8") as f:
        _ID_MAPPING_CACHE = json.load(f)

    # print(mapping_dict['S1nonbarrel_neurons']["old_id"][1:10])
    # _ID_MAPPING_CACHE = {int(k): int(v) for k, v in mapping_dict.items()}
    # print(
    #     f"Loaded {_ID_MAPPING_FILE.name} with {len(_ID_MAPPING_CACHE):,} ids "
    #     f"in {perf_counter() - t0:.2f}s"
    # )
    return _ID_MAPPING_CACHE

def adjust_spike_file(spike_path, output_spike_path, population, map_spikes_to_new_node_ids):

    print(f"Adjusting spike file: {spike_path}")

    with h5py.File(spike_path, "r") as fin:
        print(fin["spikes"].keys())
        node_ids = fin[f"spikes/{population}/node_ids"][:]       # (N,)
        timestamps = fin[f"spikes/{population}/timestamps"][:]   # (N,)

    # new_node_ids = node_ids
    if map_spikes_to_new_node_ids:
        mapping_dict = _load_id_mapping()
        if mapping_dict:
            pop_old_ids = mapping_dict.get(population, {}).get("old_id", {})
            pop_new_ids = mapping_dict.get(population, {}).get("new_id", {})
            # print(pop_old_ids[:10])
            # Weirdly 4 neurons in the spiking data are on the lower boarder of the circuit and are not in the circuit O1
            # Probably the algorithmically cylindrical node sets missed these 4 neurons on the boundary.
            # Let's just not incude the spiking activity of these boundary 4 neurons
            pop_old_ids_dict = {old_id: new_id for old_id, new_id in zip(pop_old_ids, pop_new_ids) if old_id not in ignore_boundary_neurons}
            new_node_ids = np.asarray([pop_old_ids_dict[node_id] for node_id in node_ids if node_id not in ignore_boundary_neurons])
            # print(new_node_ids[:10])
            if len(ignore_boundary_neurons) > 0:
                print(f"WARNING: Ignoring spikes from {len(ignore_boundary_neurons)} boundary neurons: {ignore_boundary_neurons}")
            else:
                changed = int(np.count_nonzero(new_node_ids != node_ids))
                print(f"Remapped {changed:,}/{len(node_ids):,} spike node ids")

        reporting_dir = output_spike_path.parent
        reporting_dir.mkdir(exist_ok=True)
        with h5py.File(output_spike_path, "w") as f:

            g_spikes = f.create_group("spikes")
            g_pom = g_spikes.create_group(population)

            g_pom.create_dataset("node_ids", data=new_node_ids)
            g_pom.create_dataset("timestamps", data=timestamps)

if blue_config_converted:
    for idx, cfg in enumerate(sim_configs):
        if idx > 0:
            adjust_spike_file(CAMPAIGN_PATH / str(idx) / "reporting" / "spikes_corrected_population.h5", CAMPAIGN_PATH / str(idx) / "reporting" / "spikes.h5", "S1nonbarrel_neurons", True)
            # adjust_spike_file(CAMPAIGN_PATH / str(idx) / "input_VPM.h5", CAMPAIGN_PATH / str(idx) / "input_VPM.h5", "VPM", True)
            # adjust_spike_file(CAMPAIGN_PATH / str(idx) / "input_POm.h5", CAMPAIGN_PATH / str(idx) / "input_POm.h5", "POm", True)
        # break
# Out:
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/1/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/2/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/3/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/4/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/5/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/6/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/7/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/8/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/9/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/10/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/11/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/12/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/13/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/14/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/15/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/16/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/17/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/18/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/19/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/20/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/21/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/22/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/23/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/24/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/25/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/26/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/27/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/28/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/29/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/30/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/31/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/32/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/33/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/34/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/35/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# WARNING: Ignoring spikes from 8 boundary neurons: [1452535, 1760317, 1863909, 1884636, 2111859, 1774635, 1669417, 2116618]
