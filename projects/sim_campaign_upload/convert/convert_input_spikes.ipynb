# %% [markdown]
# # Convert input spikes of a simulation campaign from .dat to .h5 format
#
# - Incl. patching the `simulation_config.json` files to point to the new .h5 files

# %%
import json
import subprocess
from pathlib import Path
from shutil import copyfile, move

# %%
# data_root = Path("/Users/pokorny/Data")
data_root = Path("/Users/james/Documents/obi/Data")

# CAMPAIGN_PATH = data_root / Path("Simulations/BBP-curated/SM-whisker-scan")
# SPIKE_PATH = data_root / Path("Simulations/BBP-raw/SM-whisker-scan/518fbeaf-f0ba-4f99-a0ff-22cb7e89eed7")
# blue_config_converted=False

# CAMPAIGN_PATH = data_root / Path("Simulations/BBP-curated/assemblies")
# SPIKE_PATH = data_root / Path("Simulations/BBP-raw/assemblies/d21efd45-7740-4268-b06f-e1de35f2b6cf")
# blue_config_converted=True

CAMPAIGN_PATH = data_root / Path("Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids")
SPIKE_PATH = data_root / Path("Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af")
blue_config_converted=True

SIM_CONFIG_NAME = "simulation_config.json"
STIM_NAME = "Stimulus spikeReplay"
STIM_POPULATION = "VPM"

# CONVERTER_TOOL = "/Users/pokorny/JupyterLab/git/libsonatareport/build/tools/converter/spikes_converter"
CONVERTER_TOOL = "/Users/james/Documents/obi/code/obi-misc/libsonatareport/build/tools/converter/spikes_converter"

# %%
# Check sub-folders
sim_folders = list(CAMPAIGN_PATH.glob("*[0-9]"))
sim_folder_names = [f.name for f in sim_folders]
print(sim_folder_names)
sim_configs = [_sim / SIM_CONFIG_NAME for _sim in sim_folders]
num_sims = len(sim_folders)
print(f"Found {num_sims} simulation(s) in campaign")
assert all(str(idx) in sim_folder_names for idx in range(num_sims)), "ERROR: Subfolder names do not match simulation indices!"
assert all(_cfg.is_file() for _cfg in sim_configs), "ERROR: Simulation config(s) not found!"
# Out:
# ['32', '35', '34', '33', '20', '18', '27', '9', '0', '11', '7', '29', '16', '6', '28', '17', '1', '10', '19', '26', '8', '21', '31', '30', '24', '23', '4', '15', '3', '12', '2', '13', '5', '14', '22', '25']
# Found 36 simulation(s) in campaign

# %%
# Check spike files
## NOTE THIS WONT WORK FOR CONVERTED BLUECONFIG SIMS WHICH WILL BE DEALT WITH LATER
input_spike_files = []
output_spike_files = []
for idx, cfg in enumerate(sim_configs):
    with open(cfg, "r") as f:
        cfg_dict = json.load(f)
    if blue_config_converted:
        inp_path = SPIKE_PATH / str(idx) / "input.dat"
        out_file = "input.h5"
    else:
        inp_file = cfg_dict["inputs"][STIM_NAME]["spike_file"]
        assert Path(inp_file).suffix.lower() == ".dat", "ERROR: .dat input expected!"
        inp_path = SPIKE_PATH / str(idx) / inp_file
        out_file = Path(inp_file).stem + ".h5"
    assert inp_path.is_file(), f"ERROR: Input spike file '{inp_path}' not found!"
    out_path = CAMPAIGN_PATH / str(idx) / out_file
    assert not out_path.is_file(), f"ERROR: Output spike file '{out_path}' already exists!"
    input_spike_files.append(inp_path)
    output_spike_files.append(out_path)
    print(f"Simulation {idx}: Spike file '{inp_path}'")
# Out:
# Simulation 0: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/0/input.dat'
# Simulation 1: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/1/input.dat'
# Simulation 2: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/2/input.dat'
# Simulation 3: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/3/input.dat'
# Simulation 4: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/4/input.dat'
# Simulation 5: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/5/input.dat'
# Simulation 6: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/6/input.dat'
# Simulation 7: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/7/input.dat'
# Simulation 8: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/8/input.dat'
# Simulation 9: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/9/input.dat'
# Simulation 10: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/10/input.dat'
# Simulation 11: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/11/input.dat'
# Simulation 12: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/12/input.dat'
# Simulation 13: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/13/input.dat'
# Simulation 14: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/14/input.dat'
# Simulation 15: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/15/input.dat'
# Simulation 16: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/16/input.dat'
# Simulation 17: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/17/input.dat'
# Simulation 18: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/18/input.dat'
# Simulation 19: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/19/input.dat'
# Simulation 20: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/20/input.dat'
# Simulation 21: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/21/input.dat'
# Simulation 22: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/22/input.dat'
# Simulation 23: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/23/input.dat'
# Simulation 24: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/24/input.dat'
# Simulation 25: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/25/input.dat'
# Simulation 26: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/26/input.dat'
# Simulation 27: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/27/input.dat'
# Simulation 28: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/28/input.dat'
# Simulation 29: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/29/input.dat'
# Simulation 30: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/30/input.dat'
# Simulation 31: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/31/input.dat'
# Simulation 32: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/32/input.dat'
# Simulation 33: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/33/input.dat'
# Simulation 34: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/34/input.dat'
# Simulation 35: Spike file '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/35/input.dat'

# %%
# Run conversion
for idx, (inp, out) in enumerate(zip(input_spike_files, output_spike_files)):
    print(f"Simulation {idx}: Converting '{inp}' -> '{out}'...")

    # Run conversion
    convert_out = subprocess.check_output(f"{CONVERTER_TOOL} {inp} {STIM_POPULATION}", shell=True, text=True)
    print(convert_out)

    # Move converted file from current directory to destination folder
    converted_file = inp.name + ".h5"
    assert Path(converted_file).is_file(), "ERROR: Converted file not found!"

    # if not blue_config_converted:
    move(src=converted_file, dst=out)
# Out:
# Simulation 0: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/0/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/0/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/0/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 1: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/1/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/1/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/1/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/1/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 2: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/2/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/2/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/2/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/2/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 3: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/3/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/3/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/3/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/3/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 4: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/4/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/4/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/4/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/4/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 5: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/5/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/5/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/5/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/5/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 6: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/6/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/6/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/6/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/6/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 7: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/7/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/7/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/7/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/7/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 8: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/8/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/8/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/8/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/8/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 9: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/9/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/9/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/9/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/9/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 10: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/10/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/10/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/10/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/10/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 11: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/11/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/11/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/11/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/11/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 12: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/12/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/12/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/12/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/12/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 13: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/13/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/13/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/13/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/13/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 14: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/14/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/14/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/14/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/14/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 15: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/15/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/15/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/15/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/15/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 16: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/16/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/16/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/16/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/16/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 17: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/17/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/17/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/17/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/17/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 18: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/18/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/18/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/18/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/18/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 19: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/19/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/19/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/19/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/19/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 20: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/20/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/20/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/20/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/20/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 21: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/21/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/21/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/21/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/21/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 22: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/22/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/22/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/22/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/22/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 23: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/23/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/23/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/23/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/23/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 24: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/24/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/24/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/24/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/24/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 25: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/25/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/25/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/25/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/25/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 26: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/26/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/26/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/26/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/26/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 27: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/27/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/27/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/27/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/27/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 28: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/28/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/28/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/28/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/28/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 29: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/29/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/29/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/29/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/29/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 30: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/30/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/30/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/30/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/30/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 31: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/31/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/31/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/31/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/31/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 32: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/32/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/32/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/32/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/32/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 33: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/33/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/33/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/33/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/33/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 34: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/34/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/34/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/34/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/34/input.dat' successfully converted to 'input.dat.h5'
#
# Simulation 35: Converting '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/35/input.dat' -> '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/35/input.h5'...
# [REPORTS] [info] :: Trying to convert '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/35/input.dat' binary report...'
# [REPORTS] [info] :: File '/Users/james/Documents/obi/Data/Simulations/BBP-raw/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/35/input.dat' successfully converted to 'input.dat.h5'

# %%
if not blue_config_converted:

    # Patch simulation configs
    for idx, cfg in enumerate(sim_configs):
        # Create .BAK
        bak_file = cfg.parent / (cfg.stem + ".BAK")
        if not bak_file.is_file():
            # Create only if not existing yet (to avoid overwriting)
            copyfile(src=cfg, dst=bak_file)

        # Patch config
        with open(cfg, "r") as f:
            cfg_dict = json.load(f)
        
        spk_file = cfg_dict["inputs"][STIM_NAME]["spike_file"]
        assert spk_file == input_spike_files[idx].name, "ERROR: Spike file name mismatch!"
        spk_file_new = output_spike_files[idx].name
        cfg_dict["inputs"][STIM_NAME]["spike_file"] = spk_file_new
        
        with open(cfg, "w") as f:
            json.dump(cfg_dict, f, indent=2)
        print(f"Simulation {idx}: Config file '{cfg}' written")

# %% [markdown]
# # Optionally split nbS1 inputs into two files (VPM and POm)
# For old BlueConfig based sims in which inputs were in one file

# %%
thalamic_input_files = output_spike_files

for idx, cfg in enumerate(sim_configs):
    spike_file = CAMPAIGN_PATH / f"{idx}" / "input.h5"
    output_spike_root = CAMPAIGN_PATH / f"{idx}"

    assert spike_file.is_file(), f"ERROR: Output spike file '{spike_file}' not found!"

    import h5py
    import numpy as np

    VPM_START = 5_000_000
    POM_START = 6_000_000  # exclusive
    
    vpm_out = output_spike_root / ("input_VPM.h5")
    pom_out = output_spike_root / ("input_POm.h5")

    # vpm_out = spike_file.with_name(spike_file.stem + "_VPM.h5")
    # pom_out = spike_file.with_name(spike_file.stem + "_POm.h5")

    with h5py.File(spike_file, "r") as fin:
        node_ids = fin["spikes/VPM/node_ids"][:]       # (N,)
        timestamps = fin["spikes/VPM/timestamps"][:]   # (N,)

        print(f"Input file:   {spike_file}")

        # Masks
        vpm_mask = (node_ids >= VPM_START) & (node_ids < POM_START)
        pom_mask = ~vpm_mask

    # -------- VPM FILE --------
    if len(timestamps[vpm_mask]) > 0:
        with h5py.File(vpm_out, "w") as fout:
            g_spikes = fout.create_group("spikes")
            g_vpm = g_spikes.create_group("VPM")

            g_vpm.create_dataset("node_ids", data=node_ids[vpm_mask] - VPM_START)
            g_vpm.create_dataset("timestamps", data=timestamps[vpm_mask])

            print(f"VPM file:     {vpm_out} ({vpm_mask.sum()} spikes)")
    else:
        print(f"WARNING: No VPM spikes found for simulation {idx}!")

    # -------- POm FILE --------
    if (len(timestamps[pom_mask]) > 0):
        with h5py.File(pom_out, "w") as fout:
            g_spikes = fout.create_group("spikes")
            g_pom = g_spikes.create_group("POm")

            g_pom.create_dataset("node_ids", data=node_ids[pom_mask] - POM_START)
            g_pom.create_dataset("timestamps", data=timestamps[pom_mask])

            print(f"POm file:     {pom_out} ({pom_mask.sum()} spikes)")
    else:
        print(f"WARNING: No POm spikes found for simulation {idx}!")

    print("-" * 50)
# Out:
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 0!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/1/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/1/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 1!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/2/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/2/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 2!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/3/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/3/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 3!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/4/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/4/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 4!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/5/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/5/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 5!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/6/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/6/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 6!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/7/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/7/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 7!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/8/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/8/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 8!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/9/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/9/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 9!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/10/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/10/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 10!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/11/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/11/input_VPM.h5 (39550 spikes)
# WARNING: No POm spikes found for simulation 11!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/12/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/12/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 12!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/13/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/13/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 13!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/14/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/14/input_VPM.h5 (39950 spikes)
# WARNING: No POm spikes found for simulation 14!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/15/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/15/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 15!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/16/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/16/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 16!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/17/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/17/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 17!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/18/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/18/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 18!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/19/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/19/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 19!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/20/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/20/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 20!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/21/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/21/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 21!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/22/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/22/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 22!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/23/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/23/input_VPM.h5 (37950 spikes)
# WARNING: No POm spikes found for simulation 23!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/24/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/24/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 24!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/25/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/25/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 25!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/26/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/26/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 26!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/27/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/27/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 27!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/28/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/28/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 28!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/29/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/29/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 29!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/30/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/30/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 30!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/31/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/31/input_VPM.h5 (37950 spikes)
# WARNING: No POm spikes found for simulation 31!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/32/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/32/input_VPM.h5 (37250 spikes)
# WARNING: No POm spikes found for simulation 32!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/33/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/33/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 33!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/34/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/34/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 34!
# --------------------------------------------------
# Input file:   /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/35/input.h5
# VPM file:     /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/35/input_VPM.h5 (40000 spikes)
# WARNING: No POm spikes found for simulation 35!
# --------------------------------------------------

# %% [markdown]
# # Optionally create new output spike file with "S1nonbarrel_neurons" name
# (For old BlueConfig sims)

# %%
import h5py

if blue_config_converted:
    for idx, cfg in enumerate(sim_configs):
        inp_path = SPIKE_PATH / str(idx) / "out.h5"

        with h5py.File(inp_path, "r") as fin:
            node_ids = fin["spikes/All/node_ids"][:]       # (N,)
            timestamps = fin["spikes/All/timestamps"][:]   # (N,)

        reporting_dir = CAMPAIGN_PATH / str(idx) / "reporting"
        reporting_dir.mkdir(exist_ok=True)
        with h5py.File(reporting_dir / "spikes_corrected_population.h5", "w") as f:

            g_spikes = f.create_group("spikes")
            g_pom = g_spikes.create_group("S1nonbarrel_neurons")

            g_pom.create_dataset("node_ids", data=node_ids)
            g_pom.create_dataset("timestamps", data=timestamps)

# %% [markdown]
# # Remap output spike ids

# %%
import h5py
import json
import numpy as np
from pathlib import Path
from time import perf_counter

_ID_MAPPING_CACHE = None
_ID_MAPPING_FILE = Path("/Users/james/Documents/obi/Data/Circuits/nbS1-O1/id_mapping.json")

def _load_id_mapping():
    global _ID_MAPPING_CACHE

    if _ID_MAPPING_CACHE is not None:
        return _ID_MAPPING_CACHE

    if not _ID_MAPPING_FILE.exists():
        print(f"Mapping file not found: {_ID_MAPPING_FILE}")
        _ID_MAPPING_CACHE = {}
        return _ID_MAPPING_CACHE

    t0 = perf_counter()
    with _ID_MAPPING_FILE.open("r", encoding="utf-8") as f:
        _ID_MAPPING_CACHE = json.load(f)

    # print(mapping_dict['S1nonbarrel_neurons']["old_id"][1:10])
    # _ID_MAPPING_CACHE = {int(k): int(v) for k, v in mapping_dict.items()}
    # print(
    #     f"Loaded {_ID_MAPPING_FILE.name} with {len(_ID_MAPPING_CACHE):,} ids "
    #     f"in {perf_counter() - t0:.2f}s"
    # )
    return _ID_MAPPING_CACHE

def adjust_spike_file(spike_path, output_spike_path, population, map_spikes_to_new_node_ids):

    print(f"Adjusting spike file: {spike_path}")

    with h5py.File(spike_path, "r") as fin:
        print(fin["spikes"].keys())
        node_ids = fin[f"spikes/{population}/node_ids"][:]       # (N,)
        timestamps = fin[f"spikes/{population}/timestamps"][:]   # (N,)

    # new_node_ids = node_ids
    if map_spikes_to_new_node_ids:
        mapping_dict = _load_id_mapping()
        if mapping_dict:
            pop_old_ids = mapping_dict.get(population, {}).get("old_id", {})
            pop_new_ids = mapping_dict.get(population, {}).get("new_id", {})
            # print(pop_old_ids[:10])
            pop_old_ids_dict = {old_id: new_id for old_id, new_id in zip(pop_old_ids, pop_new_ids)}
            # print("HEY")
            # print(pop_old_ids_dict)
            new_node_ids = np.asarray([pop_old_ids_dict[node_id] for node_id in node_ids])
            # print(new_node_ids[:10])
            changed = int(np.count_nonzero(new_node_ids != node_ids))
            print(f"Remapped {changed:,}/{len(node_ids):,} spike node ids")

        reporting_dir = output_spike_path.parent
        reporting_dir.mkdir(exist_ok=True)
        with h5py.File(output_spike_path, "w") as f:

            g_spikes = f.create_group("spikes")
            g_pom = g_spikes.create_group(population)

            g_pom.create_dataset("node_ids", data=new_node_ids)
            g_pom.create_dataset("timestamps", data=timestamps)

if blue_config_converted:
    for idx, cfg in enumerate(sim_configs):
        adjust_spike_file(CAMPAIGN_PATH / str(idx) / "reporting" / "spikes_corrected_population.h5", CAMPAIGN_PATH / str(idx) / "reporting" / "spikes.h5", "S1nonbarrel_neurons", True)
        # adjust_spike_file(CAMPAIGN_PATH / str(idx) / "input_VPM.h5", CAMPAIGN_PATH / str(idx) / "input_VPM.h5", "VPM", True)
        # adjust_spike_file(CAMPAIGN_PATH / str(idx) / "input_POm.h5", CAMPAIGN_PATH / str(idx) / "input_POm.h5", "POm", True)
        break
# Out:
# Adjusting spike file: /Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0/reporting/spikes_corrected_population.h5
# <KeysViewHDF5 ['S1nonbarrel_neurons']>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 69
#      67 if blue_config_converted:
#      68     for idx, cfg in enumerate(sim_configs):
# ---> 69         adjust_spike_file(CAMPAIGN_PATH / str(idx) / "reporting" / "spikes_corrected_population.h5", CAMPAIGN_PATH / str(idx) / "reporting" / "spikes.h5", "S1nonbarrel_neurons", True)
#      70         # adjust_spike_file(CAMPAIGN_PATH / str(idx) / "input_VPM.h5", CAMPAIGN_PATH / str(idx) / "input_VPM.h5", "VPM", True)
#      71         # adjust_spike_file(CAMPAIGN_PATH / str(idx) / "input_POm.h5", CAMPAIGN_PATH / str(idx) / "input_POm.h5", "POm", True)
#      72         break
#
# Cell In[31], line 52, in adjust_spike_file(spike_path, output_spike_path, population, map_spikes_to_new_node_ids)
#      49 pop_old_ids_dict = {old_id: new_id for old_id, new_id in zip(pop_old_ids, pop_new_ids)}
#      50 # print("HEY")
#      51 # print(pop_old_ids_dict)
# ---> 52 new_node_ids = np.asarray([pop_old_ids_dict[node_id] for node_id in node_ids])
#      53 # print(new_node_ids[:10])
#      54 changed = int(np.count_nonzero(new_node_ids != node_ids))
#
# KeyError: np.uint64(1863909)
