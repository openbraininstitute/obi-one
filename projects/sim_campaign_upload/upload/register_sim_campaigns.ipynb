# %% [markdown]
# # Check and register existing (BBP) simulation campaigns to entitycore

# %%
import h5py
import json
import numpy as np
import subprocess
from bluepysnap import Circuit, Simulation
from datetime import datetime, UTC
from entitysdk import Client, ProjectContext, models, types
from entitysdk.staging.circuit import stage_circuit
from entitysdk.staging.simulation_result import stage_simulation, stage_simulation_result
from itertools import product
from libsonata import SimulationConfig
from obi_auth import get_token
from pathlib import Path
from sim_campaign_upload_helpers import generate_scan_config, generate_coordinate_configs

# %%
# SIM_ROOT = Path("/Users/pokorny/Data/Simulations/BBP-curated")
# CIRCUIT_ROOT = Path("/Users/pokorny/Data/Circuits")

SIM_ROOT = Path("/Users/james/Documents/obi/Data/Simulations/BBP-curated")
CIRCUIT_ROOT = Path("/Users/james/Documents/obi/Data/Circuits")

SIM_CONFIG_NAME = "simulation_config.json"
CIRCUIT_CONFIG_NAME = "circuit_config.json"

AWS_S3 = "s3://openbluebrain/"

UPLOAD_ROOT = Path("./UPLOAD")  # Temporary folder for preparing files for upload
UPLOAD_ROOT.mkdir(parents=True, exist_ok=False)  # Must not exist yet

# Options to upload assets directly from AWS S3
use_aws_spike_assets = False
use_aws_voltage_assets = False
use_aws_replay_assets = False

# %% [markdown]
# ### Campaign specification
# - Campaign path assumed to be `<SIM_ROOT>/<name>`
# - Circuit path assumed to be `<CIRCUIT_ROOT>/<circuit>`

# %%
# Campaign info & metadata
# sim_campaign = {
#     "campaign_name": "BBP-SM-whisker-soma",
#     "campaign_description": "BBP campaign consisting of a single simulation of the nbS1-O1-SM (Schneider-Mizell) circuit with whisker flick stimulation on VPM fibers, incl. soma recording.",
#     "folder_name": "SM-whisker-soma",
#     "campaign_config": "config.json",
#     "gpfs_path": "/gpfs/bbp.cscs.ch/project/proj83/home/isbister/simulations/elife_sscx_physiology_2024/9-SchneiderMizell/2_whisker_deflections_soma/2_whisker_deflections_soma_0__19_11_24",
#     "aws_path": "Simulation_data/Simulation_Campaigns/Rat/SSCx/f132b97aa0",
#     "aws_inputs": "e6efa007-e7fa-42ae-ae3d-53385ec57154",  # Subfolder with spike replay inputs
#     "circuit": "nbS1-O1-SM"
# }

# sim_campaign = {
#     "campaign_name": "BBP-SM-whisker-scan",
#     "campaign_description": "BBP campaign consisting of 72 simulations of the nbS1-O1-SM (Schneider-Mizell) circuit with whisker flick stimulation on VPM fibers, scanned over different values of calcium, Ornstein-Uhlenbeck std to mean ratio R_OU, in-vivo firing rate proportion P_FR, and percentage of VPM fibers. Related publication: Isbister et al., 2025 (DOI: 10.7554/eLife.99693.2)",
#     "folder_name": "SM-whisker-scan",
#     "campaign_config": "config.json",
#     "gpfs_path": "/gpfs/bbp.cscs.ch/project/proj83/home/isbister/simulations/elife_sscx_physiology_2024/9-SchneiderMizell/1_whisker_deflections/1_3_whisker_deflections_scan_16_4_24",
#     "aws_path": "staging/Simulation_data/Simulation_Campaigns/Rat/SSCx/3f6517825f",
#     "aws_inputs": "518fbeaf-f0ba-4f99-a0ff-22cb7e89eed7",  # Subfolder with spike replay inputs
#     "circuit": "nbS1-O1-SM"
# }

# sim_campaign = {
#     "campaign_name": "BBP-SM-recalib",
#     "campaign_description": "BBP campaign consisting of 60 simulations of the nbS1-O1-SM (Schneider-Mizell) circuit with 6.5s spontaneous activity, scanned over different values of calcium, Ornstein-Uhlenbeck std to mean ratio R_OU, and in-vivo firing rate proportion P_FR. Related publication: Isbister et al., 2025 (DOI: 10.7554/eLife.99693.2)",
#     "folder_name": "SM-recalib",
#     "campaign_config": "config.json",
#     "gpfs_path": "/gpfs/bbp.cscs.ch/project/proj83/home/isbister/simulations/elife_sscx_physiology_2024/9-SchneiderMizell/0_recalibration/0_0_recalibration_6thIter_20_3_24",
#     "aws_path": "Simulation_data/Simulation_Campaigns/Rat/SSCx/09151af2d2",
#     "aws_inputs": None,  # Subfolder with spike replay inputs
#     "circuit": "nbS1-O1-SM"
# }

# sim_campaign = {
#     "campaign_name": "TEST: BBP-Assemblies",
#     "campaign_description": "BBP campaign consisting of ... of nbS1-O1 circuit with whisker flick stimulation on VPM fibers, incl. soma recording.",
#     "folder_name": "assemblies",
#     "campaign_config": "config.json",
#     # "gpfs_path": "/gpfs/bbp.cscs.ch/project/proj83/home/isbister/simulations/elife_sscx_physiology_2024/9-SchneiderMizell/2_whisker_deflections_soma/2_whisker_deflections_soma_0__19_11_24",
#     # "aws_path": "Simulation_data/Simulation_Campaigns/Rat/SSCx/f132b97aa0",
#     "gpfs_path": "temp",
#     "aws_inputs": "e6efa007-e7fa-42ae-ae3d-53385ec57154",  # Subfolder with spike replay inputs
#     "circuit": "nbS1-O1",
#     "circuit_id": "0f25396a-1c16-43d7-9943-43e78f84e1ed", # Staging
#     "originally_blue_config_based": True,  # Whether the original simulations were run with the old blue config (before population node ID changes)
# }
sim_campaign = {
    "campaign_name": "TEST: 4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids0",
    "campaign_description": "BBP campaign consisting of ...",
    "folder_name": "4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids",
    "campaign_config": "config.json",
    # "gpfs_path": "/gpfs/bbp.cscs.ch/project/proj83/home/isbister/simulations/elife_sscx_physiology_2024/9-SchneiderMizell/2_whisker_deflections_soma/2_whisker_deflections_soma_0__19_11_24",
    # "aws_path": "Simulation_data/Simulation_Campaigns/Rat/SSCx/f132b97aa0",
    "gpfs_path": "temp",
    "aws_inputs": "0fcb7709-b1e9-4d84-b056-5801f20d55af",  # Subfolder with spike replay inputs
    "circuit": "nbS1-O1",
    "circuit_id": "0f25396a-1c16-43d7-9943-43e78f84e1ed", # Staging
    "originally_blue_config_based": True,  # Whether the original simulations were run with the old blue config (before population node ID changes)
}

# %% [markdown]
# ---
# ### 1. Check input paths
# - Assuming individual simulation subfolders `/0`, `/1`, ... (= index)
# - Assuming `"simulation_config.json"` within each subfolder

# %%
# Check folders
campaign_path = SIM_ROOT / sim_campaign["folder_name"]
circuit_path = CIRCUIT_ROOT / sim_campaign["circuit"]

assert campaign_path.is_dir(), "ERROR: Simulation path not found!"
assert circuit_path.is_dir(), "ERROR: Circuit path not found!"

# %%
# Check sub-folders
sim_folders = list(campaign_path.glob("*[0-9]"))
sim_folder_names = [f.name for f in sim_folders]
num_sims = len(sim_folders)
print(f"Found {num_sims} simulation(s) in campaign '{sim_campaign['folder_name']}'")
assert all(str(idx) in sim_folder_names for idx in range(num_sims)), "ERROR: Subfolder names do not match simulation indices!"

# Sort folders
sort_idx = np.argsort([int(name) for name in sim_folder_names])
sim_folders = np.array(sim_folders)[sort_idx].tolist()
sim_folder_names = np.array(sim_folder_names)[sort_idx].tolist()
# Out:
# Found 36 simulation(s) in campaign '4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids'

# %%
# Check simulation configs
sim_configs = [_dir / SIM_CONFIG_NAME for _dir in sim_folders]
sim_config_dicts = []
orig_circuit = None
for cfg in sim_configs:
    assert cfg.is_file(), f"ERROR: Simulation config '{sim_config}' not found!"
    with open(cfg, "r") as f:
        cfg_dict = json.load(f)
        sim_config_dicts.append(cfg_dict)
    if orig_circuit is None:
        orig_circuit = cfg_dict["network"]
    else:
        assert cfg_dict["network"] == orig_circuit, "ERROR: Circuit mismatch!"

# %%
# Check circuit config
circuit_config = circuit_path / CIRCUIT_CONFIG_NAME
assert circuit_config.is_file(), f"ERROR: Circuit config '{circuit_config}' not found!"
print(f"Original circuit:     '{orig_circuit}'")
print(f"New campaign circuit: '{circuit_config}'")
# Out:
# Original circuit:     '../circuit_config.json'
# New campaign circuit: '/Users/james/Documents/obi/Data/Circuits/nbS1-O1/circuit_config.json'

# %%
# Check AWS path (optional)
if sim_campaign.get("aws_path"):
    aws_out = subprocess.check_output(f"aws s3 ls {AWS_S3 + sim_campaign['aws_path']}/ --no-sign-request --human-readable --recursive", shell=True, text=True)
    print(aws_out.split("\n")[0])
    print("...")
    print(aws_out.split("\n")[-2])
else:
    aws_out = None

# %% [markdown]
# ### 2. Check simulation contents

# %%
def read_spikes(h5_file, population_name):
    with h5py.File(h5_file, "r") as h5:
        nids = h5[f"spikes/{population_name}"]["node_ids"][:]
        ts = h5[f"spikes/{population_name}"]["timestamps"][:]
    return nids, ts, np.unique(nids)

# %%
c = Circuit(circuit_config)
spike_files = []
voltage_reports = []
replay_files = []
for idx, cfg in enumerate(sim_configs):
    sim = Simulation(cfg)
    output_dir = Path(sim.config["output"]["output_dir"])
    node_set = sim.config["node_set"]
    print(f"SIMULATION {idx}")
    print(f"  Simulation length: {sim.time_start}-{sim.time_stop}ms")

    # Check populations
    npop = sim.spikes.population_names
    assert len(npop) == 1, "ERROR: Only one node population expected!"
    npop = npop[0]
    assert npop in c.nodes.population_names, f"ERROR: Node population '{npop}' not found in circuit!"
    print(f"  Population name: '{npop}'")
    
    # Check output spikes
    spike_file = Path(sim.spikes.config.output_dir) / sim.spikes.config.spikes_file
    nids, ts, unique_nids = read_spikes(spike_file, npop)
    print(unique_nids)
    print(c.nodes[npop].ids(node_set))
    assert np.all(np.isin(unique_nids, c.nodes[npop].ids(node_set))), f"ERROR: Node ID mismatch in '{spike_file}'!"
    print(f"  Node set: {node_set} ({len(c.nodes[npop].ids(node_set))} neurons)")
    print(f"  Node IDs: {min(nids)}-{max(nids)} ({len(unique_nids)} spiking neurons)")
    print(f"  Time stamps {min(ts):.1f}-{max(ts):.1f}ms")
    print(f"  #Spikes: {len(nids)}")
    if use_aws_spike_assets and aws_out:
        spike_file = str(Path(sim_campaign["aws_path"]) / spike_file.relative_to(campaign_path))
        assert spike_file in aws_out, f"ERROR: Spike file '{spike_file}' not found on {AWS_S3}!"
        print(f"  AWS: {spike_file}")
    spike_files.append(spike_file)

    # Check voltage reports (if any)
    report_files = []
    for report in sim.reports.values():
        report_file = output_dir / (report.name + ".h5")
        report_node_set = report.node_set
        with h5py.File(report_file, "r") as h5:
            nids = h5[f"report/{npop}/mapping"]["node_ids"][:]
        assert np.all(np.isin(nids, c.nodes[npop].ids(report_node_set))), f"ERROR: Node ID mismatch in '{report_file}'!"
        print(f"  Report '{report.name}':")
        print(f"    Node set: {report_node_set} ({len(c.nodes[npop].ids(report_node_set))} neurons)")
        print(f"    Node IDs: {min(nids)}-{max(nids)} ({len(np.unique(nids))} recorded neurons)")
        print(f"    Length: {report.time_start}-{report.time_stop}ms")
        if use_aws_voltage_assets and aws_out:
            report_file = str(Path(sim_campaign["aws_path"]) / report_file.relative_to(campaign_path))
            assert report_file in aws_out, f"ERROR: Report file '{report_file}' not found on {AWS_S3}!"
            print(f"    AWS: {report_file}")
        report_files.append(report_file)
    voltage_reports.append(report_files)

    # Check input spikes (if any)
    inp_files = []
    for inp_name, inp in sim.inputs.items():
        if not inp.input_type == SimulationConfig.InputBase.InputType.spikes:
            continue
        inp_spike_file = inp.spike_file
        print(f"  Spike input '{inp_name}':")
        inp_pop = inp.reader.get_population_names()
        assert len(inp_pop) == 1, "ERROR: Only one input node population expected!"
        inp_pop = inp_pop[0]
        inp_node_set = inp.node_set
        assert inp_pop in c.nodes.population_names, f"ERROR: Input node population '{inp_pop}' not found in circuit!"
        print(f"    Source population: '{inp_pop}'")
        assert inp_node_set in c.node_sets.content, f"ERROR: Input node set '{inp_node_set}' not found in circuit!"
        print(f"    Target node set: '{inp_node_set}'")
        inp_nids, inp_ts, unique_inp_nids = read_spikes(inp_spike_file, inp_pop)
        print(unique_inp_nids)
        print(c.nodes[inp_pop].ids())
        assert np.all(np.isin(unique_inp_nids, c.nodes[inp_pop].ids())), f"ERROR: Input node ID mismatch in '{inp_spike_file}'!"
        print(f"    Node IDs: {min(inp_nids)}-{max(inp_nids)} ({len(unique_inp_nids)} spiking neurons)")
        print(f"    Time stamps {min(inp_ts):.1f}-{max(inp_ts):.1f}ms")
        print(f"    #Spikes: {len(inp_nids)}")
        if use_aws_replay_assets and aws_out:
            inp_sub = sim_campaign.get("aws_inputs", "")
            inp_spike_file = str(Path(sim_campaign["aws_path"]) / inp_sub / Path(inp_spike_file).relative_to(campaign_path))
            assert inp_spike_file in aws_out, f"ERROR: Replay file '{inp_spike_file}' not found on {AWS_S3}!"
            print(f"    AWS: {inp_spike_file}")
        inp_files.append(inp_spike_file)
    replay_files.append(inp_files)
# Out:
# SIMULATION 0
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23242 spiking neurons)
#   Time stamps 46.4-101500.0ms
#   #Spikes: 1759877
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2505 2527 2570 2633 2695 2698 2717 2792 2958 3032 3129 3187 3189 3214
#  3242 3276 3284 3296 3393 3430 3436 3492 3678 3746 3842 3861 3946 3960
#  4009 4059 4092 4136 4279 4334 4373 4435 4487 4529 4558 4559 4561 4587
#  4628 4661 4680 4711 4747 4752 4822 5053 5167 5300 5472 5635 5639 5678
#  5789 5825 5849 5949 5963 5972 6016 6266 6314 6328 6415 6790 6826 6865
#  6904 6924 7018 7024 7050 7052 7108 7121 7161 7173 7264 7338 7341 7342
#  7371 7409 7504 7533 7582 7657 7689 7782 7938 7994]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2505-7994 (94 spiking neurons)
#     Time stamps 1501.4-101307.7ms
#     #Spikes: 40000
# SIMULATION 1
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23262 spiking neurons)
#   Time stamps 46.4-101499.7ms
#   #Spikes: 1752177
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2495 2505 2527 2570 2633 2695 2698 2717 2792 2848 2958 3032 3129 3187
#  3189 3242 3284 3296 3393 3430 3436 3492 3678 3842 3861 3946 3979 4009
#  4059 4092 4136 4249 4334 4373 4435 4487 4558 4561 4587 4628 4661 4680
#  4711 4747 4752 4822 4950 4958 5053 5167 5300 5366 5472 5635 5639 5678
#  5825 5849 5949 5963 5972 6016 6032 6266 6314 6790 6826 6865 6904 6924
#  6996 7018 7024 7050 7052 7108 7109 7161 7173 7264 7338 7341 7342 7371
#  7409 7419 7504 7533 7582 7657 7689 7709 7782 7834 8050 8085 8159 8274
#  8342 8377 8515 8686]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2495-8686 (102 spiking neurons)
#     Time stamps 1501.4-101307.6ms
#     #Spikes: 40000
# SIMULATION 2
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     90    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23456 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1794245
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2481 2492 2495 2527 2695 2792 2848 2958 3032 3187 3189 3242 3284 3296
#  3393 3430 3436 3678 3842 3946 3979 4059 4092 4136 4249 4373 4435 4487
#  4558 4561 4628 4661 4680 4685 4711 4747 4752 4822 4950 4954 4958 5053
#  5300 5366 5639 5678 5825 5831 5899 5949 5963 5972 5986 6032 6266 6524
#  6563 6623 6646 6694 6705 6790 6826 6865 6980 6996 7018 7024 7052 7108
#  7109 7158 7161 7173 7264 7338 7342 7371 7409 7419 7504 7533 7582 7653
#  7657 7689 7709 7782 7834 8050 8085 8159 8274 8342 8377 8515 8555 8615
#  8686 8699 8753 8787 8863 8886 8969 9047 9220 9223]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2481-9223 (108 spiking neurons)
#     Time stamps 1501.4-101307.6ms
#     #Spikes: 40000
# SIMULATION 3
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23846 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1945140
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2481  2492  2495  2527  2695  2848  2958  2980  3187  3189  3226  3284
#   3678  3842  3946  3979  4136  4249  4435  4487  4561  4680  4685  4711
#   4747  4752  4871  4950  4954  4958  5053  5300  5366  5678  5687  5831
#   5899  5986  6032  6266  6393  6443  6524  6563  6623  6646  6694  6705
#   6798  6826  6839  6980  6996  7052  7108  7109  7158  7173  7264  7342
#   7409  7419  7504  7533  7582  7653  7657  7666  7709  7834  7947  8050
#   8085  8274  8377  8555  8615  8686  8699  8863  8886  8969  9047  9220
#   9223  9338  9419  9474  9672  9744  9755  9773 10136 10215 10298]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2481-10298 (95 spiking neurons)
#     Time stamps 1501.4-101307.6ms
#     #Spikes: 40000
# SIMULATION 4
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24144 spiking neurons)
#   Time stamps 46.4-101499.7ms
#   #Spikes: 2046999
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2481  2492  2495  2527  2653  2848  2958  2980  3189  3226  3284  3528
#   3654  3842  3855  3942  3979  4136  4249  4435  4487  4648  4680  4685
#   4747  4785  4871  4950  4954  4958  5053  5366  5687  5831  5899  5907
#   5913  5986  6032  6135  6168  6266  6393  6443  6524  6563  6623  6646
#   6694  6705  6798  6826  6839  6942  6980  6996  7052  7108  7109  7158
#   7264  7409  7419  7504  7582  7653  7666  7709  7834  7947  8050  8079
#   8131  8274  8555  8615  8686  8699  8863  8886  8969  9047  9190  9220
#   9223  9338  9365  9419  9586  9672  9676  9744  9773 10136 10215 10289
#  10298 10338 10367]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2481-10367 (99 spiking neurons)
#     Time stamps 1501.6-101307.6ms
#     #Spikes: 40000
# SIMULATION 5
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24310 spiking neurons)
#   Time stamps 46.4-101500.0ms
#   #Spikes: 2099275
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2481 2492 2495 2653 2663 2848 2958 2980 3226 3528 3654 3842 3855 3942
#  3979 4168 4249 4283 4379 4399 4648 4685 4785 4845 4871 4950 4952 4954
#  4958 5033 5053 5237 5346 5366 5462 5597 5601 5630 5658 5687 5698 5831
#  5898 5899 5907 5913 5986 6032 6118 6135 6168 6266 6393 6443 6524 6563
#  6623 6646 6694 6705 6760 6798 6839 6942 6980 6996 7056 7109 7129 7158
#  7248 7264 7345 7419 7450 7504 7615 7653 7666 7709 7947 8040 8050 8079
#  8131 8274 8434 8555 8615 8686 8699 8863 8886 8969 9047 9190 9338 9365
#  9419 9586 9672 9676]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2481-9676 (102 spiking neurons)
#     Time stamps 1501.6-101307.6ms
#     #Spikes: 40000
# SIMULATION 6
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39     90 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24317 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 2109907
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2481 2492 2653 2663 2980 3226 3377 3457 3528 3654 3825 3855 3942 4168
#  4210 4249 4283 4379 4399 4648 4685 4785 4845 4851 4871 4952 4954 4958
#  5033 5164 5237 5242 5265 5346 5366 5462 5496 5597 5601 5630 5658 5668
#  5687 5698 5831 5898 5899 5907 5913 5986 6032 6107 6118 6135 6168 6393
#  6443 6524 6563 6623 6646 6694 6705 6760 6798 6839 6942 6980 6996 7056
#  7109 7110 7115 7129 7158 7248 7345 7366 7419 7450 7615 7653 7666 7717
#  7947 8040 8079 8131 8274 8434 8555 8615 8686 8886 8969 9190 9365 9419
#  9586 9676]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2481-9676 (100 spiking neurons)
#     Time stamps 1501.6-101307.6ms
#     #Spikes: 40000
# SIMULATION 7
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39     90 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24328 spiking neurons)
#   Time stamps 46.4-101499.8ms
#   #Spikes: 2105491
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2636  2653  2663  2666  2980  3194  3226  3377  3457  3528  3654  3825
#   3855  3942  4168  4210  4283  4379  4399  4442  4648  4785  4845  4851
#   4871  4952  5033  5164  5192  5237  5242  5265  5346  5462  5496  5597
#   5601  5630  5658  5668  5687  5698  5898  5899  5907  5913  5986  6107
#   6118  6135  6168  6393  6443  6563  6623  6674  6694  6760  6798  6839
#   6942  7056  7110  7115  7129  7158  7248  7345  7366  7450  7615  7653
#   7666  7717  7947  8040  8079  8131  8434  8472  8555  9190  9365  9419
#   9586  9676  9889 10177 10215 10279 10289 10338 10367 10751]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2636-10751 (94 spiking neurons)
#     Time stamps 1501.4-101307.6ms
#     #Spikes: 40000
# SIMULATION 8
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24202 spiking neurons)
#   Time stamps 46.4-101499.6ms
#   #Spikes: 2081027
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2475  2558  2636  2653  2663  2666  2719  3194  3377  3457  3528  3654
#   3825  3855  3942  3977  4162  4168  4210  4283  4379  4399  4415  4442
#   4648  4785  4845  4851  4871  4952  5033  5050  5164  5192  5237  5242
#   5265  5346  5462  5486  5496  5597  5601  5630  5658  5668  5698  5898
#   5907  5913  6107  6118  6135  6168  6321  6443  6674  6760  6839  6942
#   6976  7056  7110  7115  7129  7248  7262  7345  7366  7450  7615  7658
#   7666  7686  7717  7789  8036  8040  8079  8131  8203  8326  8434  8472
#   9190  9365  9419  9586  9676  9748  9889 10110 10177 10215 10279 10289
#  10338 10367 10763 10903 11101 11136]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2475-11136 (102 spiking neurons)
#     Time stamps 1501.4-101307.6ms
#     #Spikes: 40000
# SIMULATION 9
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39     90 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24159 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 2027877
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2475  2558  2636  2663  2666  2707  2719  3016  3194  3377  3457  3528
#   3591  3825  3942  3977  4162  4168  4210  4283  4379  4399  4415  4442
#   4474  4785  4845  4851  4902  4952  5033  5050  5164  5192  5237  5242
#   5265  5346  5462  5481  5486  5496  5597  5601  5630  5658  5668  5698
#   5898  5907  5913  6072  6107  6118  6168  6233  6321  6674  6719  6741
#   6760  6976  7056  7110  7115  7129  7159  7248  7262  7324  7345  7366
#   7450  7615  7658  7686  7717  7789  8036  8040  8079  8203  8326  8434
#   8472  9190  9586  9748  9889 10110 10177 10279 10319 10393 10468 10496
#  10763 10872 10903 10911 11101 11301 11417 11450 11624 11654 11663]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2475-11663 (107 spiking neurons)
#     Time stamps 1501.4-101307.6ms
#     #Spikes: 40000
# SIMULATION 10
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24051 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 2026600
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2475  2558  2636  2666  2707  2719  2960  3016  3194  3310  3377  3457
#   3591  3681  3825  3878  3925  3977  4162  4210  4415  4442  4474  4851
#   4902  5033  5050  5061  5153  5164  5192  5242  5256  5265  5375  5481
#   5486  5496  5601  5658  5668  5898  5977  6072  6107  6160  6233  6321
#   6351  6674  6719  6741  6976  7110  7115  7159  7262  7324  7366  7569
#   7640  7658  7686  7717  7745  7789  8036  8040  8160  8203  8326  8371
#   8472  8486  8551  9068  9680  9748  9889 10110 10177 10279 10319 10393
#  10468 10496 10763 10872 10903 10911 11101 11301 11347 11359 11417 11450
#  11624 11654 11663 11804 11918]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2475-11918 (101 spiking neurons)
#     Time stamps 1501.4-101307.7ms
#     #Spikes: 40000
# SIMULATION 11
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23942 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 2004080
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2475  2558  2636  2666  2707  2719  2960  3016  3194  3310  3591  3681
#   3878  3925  3977  4162  4415  4442  4474  4515  4576  4851  4902  5050
#   5061  5153  5192  5256  5375  5390  5481  5486  5741  5977  6072  6160
#   6233  6321  6351  6446  6568  6610  6674  6719  6741  6976  7159  7262
#   7300  7324  7569  7640  7658  7686  7745  7789  7841  8036  8160  8192
#   8203  8326  8371  8472  8486  8551  8889  9068  9680  9748 10110 10177
#  10279 10319 10393 10468 10496 10872 10903 10911 11101 11301 11347 11359
#  11417 11654 11663 11804 11918 12014 12168]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2475-12168 (91 spiking neurons)
#     Time stamps 1502.7-101307.7ms
#     #Spikes: 39550
# SIMULATION 12
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24205 spiking neurons)
#   Time stamps 46.4-101499.7ms
#   #Spikes: 2056268
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2475  2507  2558  2707  2719  2960  3013  3016  3194  3310  3364  3591
#   3681  3682  3878  3925  3977  4162  4350  4415  4474  4515  4576  4902
#   5050  5061  5153  5256  5375  5390  5481  5486  5717  5741  5864  5977
#   5983  6072  6074  6101  6160  6233  6321  6351  6446  6566  6568  6576
#   6610  6719  6741  6976  7159  7262  7300  7324  7569  7640  7658  7686
#   7745  7789  7841  8036  8160  8192  8203  8326  8371  8486  8551  8889
#   8996  9068  9680  9748  9892 10110 10319 10393 10468 10496 10808 10872
#  10903 10911 11301 11347 11359 11417 11437 11470 11654 11804 12014 12168]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2475-12168 (96 spiking neurons)
#     Time stamps 1502.9-101307.7ms
#     #Spikes: 40000
# SIMULATION 13
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24374 spiking neurons)
#   Time stamps 46.4-101499.7ms
#   #Spikes: 2078612
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2475  2507  2558  2707  2736  2890  2960  3013  3016  3310  3364  3591
#   3681  3682  3867  3878  3925  3977  4033  4350  4388  4415  4474  4515
#   4523  4576  4902  5046  5050  5061  5153  5190  5256  5375  5390  5481
#   5546  5717  5741  5864  5977  5983  6072  6074  6101  6160  6233  6351
#   6446  6486  6566  6568  6576  6610  6654  6719  6741  7159  7262  7300
#   7324  7381  7506  7569  7640  7658  7745  7789  7841  8036  8160  8185
#   8192  8203  8371  8486  8512  8534  8551  8625  8889  8996  9068  9680
#   9776  9892 10319 10393 10468 10496 10595 10808 10872 10911 11050 11347
#  11359 11437 11470 11568 11654 11693]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2475-11693 (102 spiking neurons)
#     Time stamps 1502.7-101307.7ms
#     #Spikes: 40000
# SIMULATION 14
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24265 spiking neurons)
#   Time stamps 46.4-101499.6ms
#   #Spikes: 2088591
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2507  2736  2890  2960  3013  3310  3364  3490  3666  3681  3682  3867
#   3878  3925  4033  4350  4388  4515  4523  4576  5028  5046  5061  5130
#   5153  5190  5256  5375  5390  5444  5481  5546  5676  5717  5741  5864
#   5977  5983  6072  6074  6101  6160  6207  6351  6446  6486  6566  6568
#   6576  6610  6654  6729  7251  7300  7324  7381  7506  7569  7640  7745
#   7841  7854  8160  8185  8192  8363  8371  8486  8512  8534  8551  8625
#   8889  8996  9068  9177  9284  9385  9680  9776  9892 10169 10524 10594
#  10595 10693 10808 10911 10917 11050 11057 11347 11359 11437 11470 11568
#  11693 11711 12019 12168 12196 12351]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2507-12351 (102 spiking neurons)
#     Time stamps 1502.1-101307.6ms
#     #Spikes: 39950
# SIMULATION 15
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (24220 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 2104201
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2507  2736  2890  3012  3013  3290  3364  3429  3490  3650  3666  3682
#   3867  4033  4350  4388  4515  4523  4576  4766  4811  4833  4995  5028
#   5046  5130  5190  5236  5353  5390  5444  5546  5671  5676  5717  5741
#   5864  5918  5983  6074  6101  6160  6207  6293  6446  6486  6519  6527
#   6566  6568  6576  6597  6610  6654  6729  7198  7251  7300  7381  7506
#   7569  7841  7854  7919  8160  8185  8192  8299  8363  8506  8512  8534
#   8546  8625  8889  8928  8996  9177  9222  9284  9385  9465  9554  9776
#   9859  9892  9920 10169 10291 10524 10594 10595 10693 10808 10817 10917
#  11050 11057 11437 11470 11568 11693 11711 12019 12168 12196]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2507-12196 (106 spiking neurons)
#     Time stamps 1502.1-101307.6ms
#     #Spikes: 40000
# SIMULATION 16
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23927 spiking neurons)
#   Time stamps 46.4-101498.8ms
#   #Spikes: 2045698
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2507 2597 2736 2890 3012 3013 3046 3141 3231 3290 3292 3364 3429 3490
#  3650 3666 3682 3867 4033 4047 4350 4388 4523 4576 4716 4766 4811 4833
#  4995 5028 5046 5130 5190 5236 5353 5398 5444 5546 5583 5671 5676 5717
#  5864 5918 5983 6074 6101 6176 6193 6207 6293 6446 6486 6519 6527 6566
#  6568 6576 6597 6610 6654 6729 6737 7198 7251 7381 7408 7506 7841 7854
#  7910 7919 7956 8057 8185 8192 8209 8299 8363 8506 8512 8534 8546 8625
#  8685 8889 8928 8996 9069 9177 9222 9284 9385 9465 9554 9652 9776 9859]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2507-9859 (98 spiking neurons)
#     Time stamps 1502.1-101307.6ms
#     #Spikes: 40000
# SIMULATION 17
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23436 spiking neurons)
#   Time stamps 46.4-101500.0ms
#   #Spikes: 1886387
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2507 2516 2569 2597 2654 2692 2736 2890 3012 3046 3084 3141 3231 3290
#  3292 3364 3429 3490 3650 3666 3682 3867 3935 4033 4047 4263 4371 4388
#  4523 4716 4766 4811 4833 4995 5021 5028 5046 5130 5190 5236 5353 5398
#  5439 5444 5546 5583 5629 5671 5676 5717 5910 5918 6015 6026 6101 6176
#  6193 6207 6293 6486 6519 6527 6560 6576 6596 6597 6654 6729 6737 6777
#  6850 7014 7198 7251 7381 7408 7506 7580 7854 7864 7910 7919 7956 8057
#  8172 8185 8209 8299 8328 8363 8506 8512 8534 8546 8625 8685 8928 8996
#  9069]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2507-9069 (99 spiking neurons)
#     Time stamps 1501.3-101307.3ms
#     #Spikes: 40000
# SIMULATION 18
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39     90 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23034 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1787694
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2516 2569 2597 2654 2692 2736 3012 3035 3046 3084 3141 3169 3231 3232
#  3290 3292 3429 3490 3650 3666 3717 3790 3834 3846 3933 3935 4033 4047
#  4128 4188 4263 4371 4472 4503 4523 4691 4716 4766 4811 4833 4995 5021
#  5028 5130 5190 5236 5353 5398 5438 5439 5444 5546 5583 5629 5671 5676
#  5910 5918 6015 6026 6176 6193 6207 6293 6390 6486 6519 6527 6560 6596
#  6597 6641 6645 6729 6737 6777 6850 6869 6893 7014 7091 7198 7251 7333
#  7408 7580 7854 7864 7910 7919 7956 8057 8172 8185 8209 8299 8328 8363
#  8462 8506 8546 8685]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2516-8685 (102 spiking neurons)
#     Time stamps 1501.7-101307.3ms
#     #Spikes: 40000
# SIMULATION 19
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (22789 spiking neurons)
#   Time stamps 46.4-101500.0ms
#   #Spikes: 1751905
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2509 2516 2569 2597 2654 2692 2793 3012 3035 3046 3084 3141 3169 3208
#  3231 3232 3290 3292 3429 3650 3717 3790 3834 3846 3933 3935 3982 4047
#  4128 4188 4263 4371 4472 4503 4691 4716 4766 4811 4833 4864 4995 5008
#  5021 5028 5130 5140 5236 5353 5398 5438 5439 5583 5629 5671 5910 5918
#  6015 6026 6176 6193 6230 6293 6390 6519 6527 6560 6596 6597 6641 6645
#  6737 6777 6850 6869 6893 7002 7014 7091 7198 7333 7368 7408 7525 7550
#  7580 7744 7756 7854 7864]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2509-7864 (89 spiking neurons)
#     Time stamps 1501.7-101306.8ms
#     #Spikes: 40000
# SIMULATION 20
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (22744 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1744896
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2509 2516 2569 2597 2631 2654 2684 2692 2793 3035 3046 3084 3141 3169
#  3208 3231 3232 3290 3292 3332 3429 3577 3717 3790 3834 3846 3933 3935
#  3982 4047 4128 4188 4263 4371 4472 4503 4547 4691 4716 4793 4811 4833
#  4864 5008 5021 5026 5140 5236 5353 5398 5438 5439 5580 5583 5629 5910
#  5966 6015 6026 6176 6193 6230 6293 6390 6560 6596 6607 6641 6645 6737
#  6777 6791 6850 6869 6893 7002 7014 7091 7198 7333 7368 7408 7525 7550
#  7580 7744 7756 7864 7910 7956 8057 8172 8209 8328 8397 8462 8595]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2509-8595 (97 spiking neurons)
#     Time stamps 1501.7-101306.6ms
#     #Spikes: 40000
# SIMULATION 21
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     90    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23032 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1831895
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2509  2516  2569  2631  2654  2684  2692  2793  3035  3084  3169  3208
#   3232  3292  3332  3577  3717  3790  3834  3846  3911  3933  3935  3982
#   4128  4188  4263  4297  4371  4472  4503  4547  4691  4716  4793  4802
#   4864  5008  5021  5026  5140  5348  5438  5439  5580  5629  5910  5966
#   6015  6026  6224  6230  6390  6456  6560  6596  6607  6641  6645  6737
#   6777  6791  6850  6869  6893  7002  7014  7091  7333  7368  7408  7525
#   7550  7580  7744  7756  7864  7910  7956  8172  8328  8397  8462  8595
#   8685  8764  9042  9063  9084  9158  9186  9202  9209  9261  9733  9790
#   9800  9981 10007 10012 10015 10100 10184 10483 10618 10695]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2509-10695 (106 spiking neurons)
#     Time stamps 1501.3-101306.6ms
#     #Spikes: 40000
# SIMULATION 22
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    305    315 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23333 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1955146
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2509  2612  2631  2684  2793  3035  3169  3208  3232  3332  3577  3717
#   3790  3834  3846  3849  3911  3933  3982  4128  4188  4297  4371  4472
#   4503  4547  4691  4793  4802  4864  4944  5008  5026  5140  5348  5438
#   5580  5966  6026  6224  6230  6390  6456  6596  6607  6641  6645  6777
#   6791  6869  6893  7002  7091  7333  7368  7525  7550  7744  7756  8328
#   8397  8403  8462  8595  8628  8764  9020  9027  9042  9063  9084  9158
#   9186  9209  9261  9328  9643  9733  9780  9790  9800  9981 10007 10012
#  10015 10100 10184 10259 10260 10483 10618 10744 10746 10758 10825 10869
#  10875 10901 11128]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2509-11128 (99 spiking neurons)
#     Time stamps 1501.7-101307.1ms
#     #Spikes: 40000
# SIMULATION 23
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    305    315 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23333 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1875948
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2509  2612  2631  2684  2793  3035  3208  3332  3577  3722  3789  3790
#   3834  3849  3883  3911  3933  3982  4188  4198  4297  4457  4484  4547
#   4629  4691  4793  4802  4864  4944  5008  5026  5140  5348  5438  5580
#   5966  6224  6230  6390  6409  6456  6607  6641  6645  6791  6821  6869
#   6936  7002  7070  7333  7368  7525  7550  7554  7563  7744  7756  7966
#   8118  8397  8403  8424  8595  8628  8704  8764  8798  9020  9027  9042
#   9063  9084  9186  9209  9238  9261  9328  9643  9780  9790  9800  9981
#  10007 10012 10015 10059 10259 10260 10346 10483 10744 10746 10758 10869
#  10875 10943 11128 11131 11253 11411 11453 11466 11682 11796 11888 11908
#  11931 11944 11958 12080 12438]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2509-12438 (113 spiking neurons)
#     Time stamps 1501.4-101307.1ms
#     #Spikes: 37950
# SIMULATION 24
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    305    315 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23036 spiking neurons)
#   Time stamps 46.4-101500.0ms
#   #Spikes: 1845877
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2606  2612  2631  2684  2787  2814  3011  3332  3577  3712  3722  3789
#   3849  3883  3911  4198  4255  4297  4457  4484  4547  4629  4793  4802
#   4928  4944  4947  5026  5077  5079  5348  5525  5547  5580  5623  5966
#   6164  6224  6334  6409  6456  6607  6791  6810  6821  6936  6990  7070
#   7368  7470  7550  7554  7563  7932  7966  8118  8397  8403  8424  8628
#   8704  8798  8955  9020  9027  9084  9186  9238  9255  9261  9328  9387
#   9643  9780  9820  9900  9981 10007 10012 10015 10054 10059 10259 10260
#  10346 10869 10875 10943 11128 11131 11253 11409 11411 11453 11466 11682
#  11796 11888 11908 11944 11958 12080 12438]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2606-12438 (103 spiking neurons)
#     Time stamps 1501.4-101307.1ms
#     #Spikes: 40000
# SIMULATION 25
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (22657 spiking neurons)
#   Time stamps 46.4-101499.3ms
#   #Spikes: 1757182
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2518  2606  2612  2615  2684  2748  2787  2814  3011  3336  3446  3712
#   3722  3789  3849  3883  3911  4191  4198  4255  4297  4457  4484  4629
#   4793  4802  4928  4944  4947  5077  5079  5348  5525  5547  5548  5580
#   5623  5631  5725  6164  6224  6334  6409  6456  6529  6537  6810  6821
#   6936  6990  7070  7470  7554  7563  7843  7932  7966  7978  8091  8118
#   8271  8397  8403  8424  8623  8628  8704  8798  8861  8955  9020  9027
#   9084  9238  9255  9261  9328  9356  9387  9557  9619  9643  9780  9820
#   9900  9981 10054 10059 10259 10260 10346 10943 11012 11128 11131 11409
#  11453 11466]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2518-11466 (98 spiking neurons)
#     Time stamps 1502.1-101307.1ms
#     #Spikes: 40000
# SIMULATION 26
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    305    315 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (22390 spiking neurons)
#   Time stamps 46.4-101499.6ms
#   #Spikes: 1686264
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2518  2606  2612  2615  2693  2705  2748  2787  2814  3011  3336  3358
#   3446  3712  3722  3789  3849  3883  4069  4191  4198  4255  4457  4484
#   4629  4725  4928  4944  4947  5077  5079  5348  5525  5547  5548  5623
#   5631  5725  6058  6164  6334  6401  6409  6529  6537  6598  6763  6810
#   6821  6936  6990  7070  7470  7554  7563  7701  7833  7843  7932  7966
#   7978  8091  8118  8271  8403  8424  8623  8628  8704  8710  8725  8798
#   8848  8861  8939  8955  9020  9027  9238  9255  9328  9356  9387  9484
#   9557  9619  9643  9780  9820  9900 10054 10059 10259 10260 10346 10943
#  11012]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2518-11012 (97 spiking neurons)
#     Time stamps 1502.1-101307.0ms
#     #Spikes: 40000
# SIMULATION 27
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211668 211686 211701]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211701 (22635 spiking neurons)
#   Time stamps 46.4-101499.5ms
#   #Spikes: 1722564
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2518 2606 2612 2615 2693 2705 2748 2787 2814 3011 3336 3358 3446 3712
#  3722 3789 3794 3849 3883 3910 4069 4191 4198 4255 4437 4457 4484 4629
#  4725 4928 4947 5073 5077 5079 5117 5525 5547 5548 5623 5631 5725 6009
#  6039 6058 6064 6164 6171 6334 6401 6409 6529 6537 6598 6763 6810 6821
#  6891 6936 6990 7070 7455 7470 7493 7554 7563 7701 7833 7843 7932 7966
#  7978 8000 8091 8118 8271 8403 8424 8623 8628 8650 8704 8710 8725 8792
#  8798 8848 8861 8939 8955 9238 9255]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2518-9255 (91 spiking neurons)
#     Time stamps 1502.1-101307.0ms
#     #Spikes: 40000
# SIMULATION 28
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (22954 spiking neurons)
#   Time stamps 46.4-101499.4ms
#   #Spikes: 1773013
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2518  2529  2606  2615  2693  2705  2748  2787  2814  3011  3336  3358
#   3419  3446  3712  3722  3789  3794  3910  4005  4069  4191  4255  4437
#   4484  4629  4725  4928  4947  5073  5077  5079  5117  5525  5547  5548
#   5623  5631  5725  5903  6009  6039  6058  6064  6164  6171  6334  6401
#   6409  6529  6537  6559  6598  6658  6763  6810  6821  6891  6990  7070
#   7402  7455  7470  7493  7563  7701  7723  7833  7843  7932  7966  7978
#   8000  8028  8091  8118  8271  8373  8424  8438  8623  8650  8704  8710
#   8725  8792  8798  8848  8861  8939  8955  9071  9113  9255  9356  9363
#   9387  9410  9484  9557  9619  9900  9989 10054 10171 10509 10716 10736
#  10908 11012]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2518-11012 (110 spiking neurons)
#     Time stamps 1502.4-101307.0ms
#     #Spikes: 40000
# SIMULATION 29
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23343 spiking neurons)
#   Time stamps 46.4-101499.4ms
#   #Spikes: 1873382
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2518  2529  2615  2693  2705  2748  2787  3190  3336  3358  3419  3446
#   3794  3910  4005  4069  4191  4437  4684  4725  5073  5077  5117  5345
#   5416  5525  5539  5548  5631  5640  5725  5859  5903  6009  6039  6058
#   6064  6164  6169  6171  6401  6529  6537  6559  6598  6658  6662  6763
#   6810  6891  7402  7455  7493  7542  7701  7723  7833  7843  7978  8000
#   8028  8082  8091  8271  8373  8438  8623  8650  8710  8725  8763  8792
#   8848  8861  8939  9071  9113  9181  9255  9356  9363  9410  9484  9557
#   9619  9946  9989 10171 10482 10509 10515 10573 10716 10736 10908 11185
#  11186 11188]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2518-11188 (98 spiking neurons)
#     Time stamps 1502.4-101307.0ms
#     #Spikes: 40000
# SIMULATION 30
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     39    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23724 spiking neurons)
#   Time stamps 46.4-101499.7ms
#   #Spikes: 1967444
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2518  2529  2615  2693  2705  3190  3336  3358  3419  3759  3794  3910
#   4005  4069  4437  4684  4725  5073  5117  5345  5416  5539  5631  5640
#   5859  5903  6009  6039  6058  6064  6169  6171  6401  6559  6598  6658
#   6662  6763  6785  6891  7146  7402  7455  7456  7493  7542  7701  7723
#   7833  7978  8000  8028  8082  8091  8373  8438  8650  8652  8710  8725
#   8763  8792  8848  8939  9071  9113  9181  9356  9363  9410  9484  9619
#   9946  9989 10171 10482 10509 10515 10573 10716 10736 10908 11024 11185
#  11186 11188 11322 11521 11645 11784 11894 11975 12337 12393]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2518-12393 (94 spiking neurons)
#     Time stamps 1502.4-101307.0ms
#     #Spikes: 40000
# SIMULATION 31
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    305    315 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23647 spiking neurons)
#   Time stamps 46.4-101499.8ms
#   #Spikes: 1923597
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2529  2670  2705  3190  3358  3419  3759  3794  3910  3960  4005  4069
#   4331  4437  4529  4684  4725  5073  5117  5202  5345  5416  5430  5539
#   5640  5789  5803  5859  5903  6009  6039  6058  6064  6119  6169  6171
#   6401  6559  6658  6662  6785  6891  7121  7146  7402  7455  7456  7493
#   7542  7701  7723  7833  7871  7994  8000  8028  8082  8282  8373  8438
#   8650  8652  8763  8792  8848  8939  9071  9097  9113  9181  9363  9410
#   9484  9734  9946  9989 10045 10171 10258 10412 10482 10509 10515 10573
#  10656 10716 10736 10908 11024 11186 11188 11521 11645 11739 11784 11840
#  11894 11975 12337 12393]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2529-12393 (100 spiking neurons)
#     Time stamps 1502.4-101306.7ms
#     #Spikes: 37950
# SIMULATION 32
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     90    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23410 spiking neurons)
#   Time stamps 46.4-101499.4ms
#   #Spikes: 1858087
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2529  2670  3190  3214  3276  3419  3492  3746  3759  3861  3960  4005
#   4009  4279  4331  4529  4559  4684  5167  5202  5345  5416  5430  5472
#   5539  5635  5640  5789  5803  5849  5859  5903  6016  6064  6119  6169
#   6171  6328  6415  6559  6658  6662  6785  7121  7146  7402  7455  7456
#   7542  7723  7871  7938  7994  8028  8082  8282  8373  8438  8652  8763
#   8792  8834  8875  9071  9097  9113  9181  9363  9410  9734  9946  9989
#  10045 10258 10315 10412 10482 10515 10573 10630 10656 10716 11024 11186
#  11188 11189 11521 11645 11667 11734 11739 11784 11840 11894 11975 12337
#  12393]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2529-12393 (97 spiking neurons)
#     Time stamps 1502.7-101307.7ms
#     #Spikes: 37250
# SIMULATION 33
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11    145    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23525 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1882889
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2505  2570  2633  2670  2698  2717  2792  3129  3190  3214  3276  3296
#   3436  3492  3746  3759  3861  3960  4009  4059  4279  4331  4334  4373
#   4529  4559  4587  4661  4684  5167  5202  5345  5416  5430  5472  5539
#   5635  5640  5789  5803  5849  5859  6016  6119  6169  6314  6328  6415
#   6559  6662  6785  6790  6865  6904  6924  7050  7121  7146  7161  7341
#   7402  7456  7542  7782  7871  7938  7994  8028  8082  8282  8515  8652
#   8763  8790  8834  8875  8978  9097  9181  9588  9734  9946 10045 10258
#  10315 10412 10482 10515 10573 10630 10656 10716 10832 10934 11024 11186
#  11188 11189 11394 11521 11536 11645 11667 11734 11739 11840 11975 12393]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2505-12393 (108 spiking neurons)
#     Time stamps 1502.0-101307.7ms
#     #Spikes: 40000
# SIMULATION 34
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     90    305 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23448 spiking neurons)
#   Time stamps 46.4-101499.8ms
#   #Spikes: 1834287
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [ 2505  2570  2633  2670  2698  2717  2792  3032  3129  3214  3242  3276
#   3296  3393  3430  3436  3492  3746  3759  3861  3946  3960  4009  4059
#   4092  4279  4331  4334  4373  4529  4558  4559  4587  4628  4661  4711
#   4822  5167  5202  5300  5416  5430  5472  5539  5635  5639  5640  5789
#   5803  5825  5849  5859  5949  5963  5972  6016  6119  6169  6314  6328
#   6415  6785  6790  6865  6904  6924  7018  7024  7050  7121  7146  7161
#   7338  7341  7371  7456  7533  7689  7782  7871  7938  7994  8082  8085
#   8159  8282  8342  8377  8515  8652  8753  8787  8790  8834  8875  8882
#   8978  9097  9413  9588  9734  9946 10045 10258 10315 10412 10630]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2505-10630 (107 spiking neurons)
#     Time stamps 1502.0-101307.7ms
#     #Spikes: 40000
# SIMULATION 35
#   Simulation length: 0-101500.0ms
#   Population name: 'S1nonbarrel_neurons'
# [    11     90    145 ... 211654 211668 211686]
# [     0      1      2 ... 211709 211710 211711]
#   Node set: hex_O1 (211712 neurons)
#   Node IDs: 11-211686 (23251 spiking neurons)
#   Time stamps 46.4-101499.9ms
#   #Spikes: 1784900
#   Spike input 'Stimulus spikeReplay VPM':
#     Source population: 'VPM'
#     Target node set: 'hex_O1'
# [2505 2527 2570 2633 2670 2695 2698 2717 2792 3032 3129 3187 3189 3214
#  3242 3276 3296 3393 3430 3436 3492 3678 3746 3861 3946 3960 4009 4059
#  4092 4136 4279 4331 4334 4373 4435 4529 4558 4559 4561 4587 4628 4661
#  4711 4747 4752 4822 5167 5202 5300 5430 5472 5635 5639 5678 5789 5803
#  5825 5849 5949 5963 5972 6016 6119 6314 6328 6415 6790 6826 6865 6904
#  6924 7018 7024 7050 7108 7121 7161 7173 7338 7341 7342 7371 7533 7657
#  7689 7782 7871 7938 7994 8085 8159 8282 8342 8377 8515]
# [    0     1     2 ... 14840 14841 14842]
#     Node IDs: 2505-8515 (95 spiking neurons)
#     Time stamps 1501.4-101307.7ms
#     #Spikes: 40000

# %% [markdown]
# ### 3. Check campaign config

# %%
if sim_campaign.get("originally_blue_config_based"):
    # Check campaign config
    campaign_config_file = campaign_path / sim_campaign["campaign_config"]
    with open(campaign_config_file, "r") as f:
        campaign_config_dict = json.load(f)
# else:
#     campaign_config_dict =
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 if sim_campaign.get("originally_blue_config_based"):
#       2     # Check campaign config
#       3     campaign_config_file = campaign_path / sim_campaign["campaign_config"]
# ----> 4     with open(campaign_config_file, "r") as f:
#       5         campaign_config_dict = json.load(f)
#       6 # else:
#       7 #     campaign_config_dict =
#
# File ~/Documents/obi/code/obi-main/obi-one/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/james/Documents/obi/Data/Simulations/BBP-curated/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/config.json'

# %%
# Campaign scan params dict
scan_params = {k: v["data"] for k, v in campaign_config_dict["coords"].items()}
scan_indices = {k: list(range(len(v))) for k, v in scan_params.items()}
print("Campaign param dict:")
print(scan_params)

# %%
# Single scan params list
single_params = list(product(*scan_params.values()))
single_indices = list(product(*scan_indices.values()))

# %%
# Check consistency with folders
for idx, scan_idx in enumerate(single_indices):
    data = campaign_config_dict["data"]
    for _i in scan_idx:
        data = data[_i]
    assert Path(data).name == f"simulation_{idx}", f"ERROR: Index {idx} mismatch ({scan_idx})!"

# %%
# Single scan param dicts
dims = campaign_config_dict["dims"]
assert list(scan_params.keys()) == dims, "ERROR: Dims mismtach!"
single_scan_params = [{dims[_d]: single_params[_i][_d] for _d in range(len(dims))} for _i in range(len(single_params))]
print("Single param dict(s):")
print(single_scan_params[0])
if len(single_scan_params) > 2:
    print("...")
if len(single_scan_params) > 1:
    print(single_scan_params[-1])

# %% [markdown]
# ### 4. Create and register `Simulation`, `SimulationCampaign`, and `SimulationResult` entities

# %%
authorized_public = True

# %%
token = get_token(environment="staging")
# project_context = ProjectContext.from_vlab_url("https://staging.openbraininstitute.org/app/virtual-lab/lab/1f91f30e-1489-4e2a-8eb7-1217257c8e19/project/7a411785-6895-4839-aaa2-d9f76e09875a/home")
project_context = ProjectContext.from_vlab_url("https://staging.openbraininstitute.org/app/virtual-lab/lab/e6030ed8-a589-4be2-80a6-f975406eb1f6/project/2720f785-a3a2-4472-969d-19a53891c817")
client = Client(environment="staging", project_context=project_context, token_manager=token)

# token = get_token(environment="production")
# project_context = ProjectContext.from_vlab_url("https://www.openbraininstitute.org/app/virtual-lab/lab/2050ff74-6d3b-4323-9d85-69ef8086ed5f/project/2e927512-489e-47d0-9d34-86188366f467/home")
# client = Client(environment="production", project_context=project_context, token_manager=token)

# %%
# Get circuit entity
circuit_entity = client.search_entity(entity_type=models.Circuit, query={"name": sim_campaign["circuit"]}).one()
print(f"Circuit '{circuit_entity.name}' (ID {circuit_entity.id})")

# %%
# Generate obi-one configs
obi_one_scan, obi_one_scan_file = generate_scan_config(sim_campaign, campaign_config_dict, sim_config_dicts, scan_params, circuit_entity, validate_config=False, save_path=UPLOAD_ROOT)
obi_one_coords, obi_one_coords_files = generate_coordinate_configs(sim_campaign, campaign_config_dict, sim_config_dicts, single_scan_params, circuit_entity, validate_config=False, save_path=UPLOAD_ROOT)

# %%
# Check if not yet registered
res = client.search_entity(entity_type=models.SimulationCampaign, query={"name": sim_campaign["campaign_name"]}).all()
assert len(res) == 0, f"ERROR: Campaign '{sim_campaign['campaign_name']}' already registered {[r.id for r in res]}!"

# Create and register SimulationCampaign entity + assets (config.json & obi_one_scan.json)
campaign_model = models.SimulationCampaign(
    name=sim_campaign["campaign_name"],
    description=sim_campaign["campaign_description"],
    entity_id=circuit_entity.id,
    scan_parameters=scan_params,
    authorized_public=authorized_public,
)
campaign_entity = client.register_entity(campaign_model)
print(f"Registered SimulationCampaign '{campaign_entity.name}' (ID {campaign_entity.id})")

campaign_asset = client.upload_file(
    entity_id=campaign_entity.id,
    entity_type=models.SimulationCampaign,
    file_path=campaign_config_file,
    file_content_type="application/json",
    asset_label="campaign_summary",
)
print(f"Uploaded '{campaign_asset.label}' asset for campaign '{campaign_entity.name}' (ID {campaign_asset.id})")

campaign_scan_asset = client.upload_file(
    entity_id=campaign_entity.id,
    entity_type=models.SimulationCampaign,
    file_path=obi_one_scan_file,
    file_content_type="application/json",
    asset_label="campaign_generation_config",
)
print(f"Uploaded '{campaign_scan_asset.label}' asset for campaign '{campaign_entity.name}' (ID {campaign_scan_asset.id})")

# %%
# Create and register Simulation entities + asset (SONATA config) and SimulationResult + assets
sim_entities = []
for idx, param_dict in enumerate(single_scan_params):
    ###############################################################################################
    # Simulation
    ###############################################################################################
    sim_model = models.Simulation(
        name=f"Simulation {idx}",
        description=f"Simulation {idx}",
        scan_parameters=param_dict,
        entity_id=circuit_entity.id,
        simulation_campaign_id=campaign_entity.id,
        authorized_public=authorized_public,
    )

    sim_entity = client.register_entity(sim_model)
    sim_entities.append(sim_entity)
    print(f"Registered Simulation '{sim_entity.name}' (ID {sim_entity.id})")

    sim_cfg_asset = client.upload_file(
        entity_id=sim_entity.id,
        entity_type=models.Simulation,
        file_path=sim_configs[idx],
        file_content_type="application/json",
        asset_label="sonata_simulation_config",
    )
    print(f"  > Uploaded '{sim_cfg_asset.path}' as '{sim_cfg_asset.label}' asset (ID {sim_cfg_asset.id})")

    sim_coord_cfg_asset = client.upload_file(
        entity_id=sim_entity.id,
        entity_type=models.Simulation,
        file_path=obi_one_coords_files[idx],
        file_content_type="application/json",
        asset_label="simulation_generation_config",
    )
    print(f"  > Uploaded '{sim_coord_cfg_asset.path}' as '{sim_coord_cfg_asset.label}' asset (ID {sim_coord_cfg_asset.id})")

    # REPLAY ASSETS
    asset_label = "replay_spikes"
    content_type = "application/x-hdf5"
    for repl in replay_files[idx]:
        if use_aws_replay_assets:
            sim_replay_asset = client.register_asset(
                entity_id=sim_entity.id,
                entity_type=models.Simulation,
                name=Path(repl).name,
                storage_path=repl,
                storage_type="aws_s3_open",
                is_directory=False,
                content_type=content_type,
                asset_label=asset_label,
            )
            msg = "Registered from AWS-S3"
        else:
            sim_replay_asset = client.upload_file(
                entity_id=sim_entity.id,
                entity_type=models.Simulation,
                file_path=repl,
                file_content_type=content_type,
                asset_label=asset_label,
            )
            msg = "Uploaded"
        print(f"  > {msg} '{sim_replay_asset.path}' as '{sim_replay_asset.label}' asset (ID {sim_replay_asset.id})")

    # CUSTOM NODE SET FILE
    # TODO: Use real file instead of empty dummy!
    nset_file = Path("./TMP/node_sets.json")
    nset_file.parent.mkdir(exist_ok=True, parents=True)
    with open(nset_file, "w") as f:
        json.dump({}, f)
    nset_asset = client.upload_file(
        entity_id=sim_entity.id,
        entity_type=models.Simulation,
        file_path=nset_file,
        file_content_type="application/json",
        asset_label="custom_node_sets",
    )
    print(f"  > Uploaded '{nset_asset.path}' as '{nset_asset.label}' asset (ID {nset_asset.id})")

    ###############################################################################################
    # SimulationResult
    ###############################################################################################
    sim_res_model = models.SimulationResult(
        name="simulation_result",
        description="Simulation result",
        simulation_id=sim_entity.id,
        authorized_public=authorized_public,
    )
    sim_res_entity = client.register_entity(sim_res_model)
    print(f"Registered SimulationResult '{sim_res_entity.name}' (ID {sim_res_entity.id})")

    # SPIKE ASSET
    asset_label = "spike_report"
    content_type = "application/x-hdf5"
    if use_aws_spike_assets:
        res_spk_asset = client.register_asset(
            entity_id=sim_res_entity.id,
            entity_type=models.SimulationResult,
            name=Path(spike_files[idx]).name,
            storage_path=spike_files[idx],
            storage_type="aws_s3_open",
            is_directory=False,
            content_type=content_type,
            asset_label=asset_label,
        )
        msg = "Registered from AWS-S3"
    else:
        res_spk_asset = client.upload_file(
            entity_id=sim_res_entity.id,
            entity_type=models.SimulationResult,
            file_path=spike_files[idx],
            file_content_type=content_type,
            asset_label=asset_label,
        )
        msg = "Uploaded"
    print(f"  > {msg} '{res_spk_asset.path}' as '{res_spk_asset.label}' asset (ID {res_spk_asset.id})")

    # VOLTAGE REPORT ASSETS
    asset_label = "voltage_report"
    content_type = "application/x-hdf5"
    for vrep in voltage_reports[idx]:
        if use_aws_voltage_assets:
            res_vrep_asset = client.register_asset(
                entity_id=sim_res_entity.id,
                entity_type=models.SimulationResult,
                name=Path(vrep).name,
                storage_path=vrep,
                storage_type="aws_s3_open",
                is_directory=False,
                content_type=content_type,
                asset_label=asset_label,
            )
            msg = "Registered from AWS-S3"
        else:
            res_vrep_asset = client.upload_file(
                entity_id=sim_res_entity.id,
                entity_type=models.SimulationResult,
                file_path=vrep,
                file_content_type=content_type,
                asset_label=asset_label,
            )
            msg = "Uploaded"
        print(f"  > {msg} '{res_vrep_asset.path}' as '{res_vrep_asset.label}' asset (ID {res_vrep_asset.id})")

    ###############################################################################################
    # SimulationExecution(Activity): Required to retrieve a SimulationResult for a given Simulation
    ###############################################################################################

    now = datetime.now(UTC)
    sim_exec_model = models.SimulationExecution(
        start_time=now,
        end_time=now,
        used=[sim_entity],
        generated=[sim_res_entity],
        status=types.SimulationExecutionStatus.done,
        authorized_public=authorized_public,
    )
    sim_exec_entity = client.register_entity(sim_exec_model)
    print(f"Registered SimulationExecution (ID {sim_exec_entity.id})")
    print()

###########################################################################################################
# SimulationGeneration(Activity): Can be used to retrieve all Simulations belonging to a SimulationCampaign
###########################################################################################################

now = datetime.now(UTC)
sim_gen_model = models.SimulationGeneration(
    start_time=now,
    used=[campaign_entity],
    generated=sim_entities,
    authorized_public=authorized_public,
)
sim_gen_entity = client.register_entity(sim_gen_model)
print(f"Registered SimulationGeneration (ID {sim_gen_entity.id})")

# %% [markdown]
# ### 5. Check registered campaign

# %%
registered_campaign = client.get_entity(entity_id=campaign_entity.id, entity_type=models.SimulationCampaign)
# OR
# registered_campaign = client.search_entity(entity_type=models.SimulationCampaign, query={"name": sim_campaign["campaign_name"]}).one()
print(f"Found campaign '{registered_campaign.name}' (ID {registered_campaign.id})")

# %%
print(f"SimulationCampaign '{registered_campaign.name}' (ID {registered_campaign.id})")
for a in registered_campaign.assets:
    print(f"  - Asset '{a.label}' ({a.id})")

sim_gen = client.search_entity(entity_type=models.SimulationGeneration, query={"used__id": registered_campaign.id}).all()
if len(sim_gen) > 0:
    assert len(sim_gen) == 1, "ERROR: Multiple SimulationGeneration activities found!"
    sim_gen = sim_gen[0]
    print(f"  > SimulationGeneration activity (ID {sim_gen.id}): {len(sim_gen.used)} used, {len(sim_gen.generated)} generated")

for sim in registered_campaign.simulations:
    sim = client.get_entity(entity_id=sim.id, entity_type=models.Simulation)  # To get assets!!
    print(f"  > Simulation '{sim.name}' (ID {sim.id})")
    for a in sim.assets:
        print(f"    - Asset '{a.label}' ({a.id})")
    sim_exec = client.search_entity(entity_type=models.SimulationExecution, query={"used__id": sim.id}).one()
    print(f"    > SimulationExecution activity (ID {sim_exec.id}): {len(sim_exec.used)} used, {len(sim_exec.generated)} generated")
    sim_res = client.get_entity(entity_id=sim_exec.generated[0].id, entity_type=models.SimulationResult)
    print(f"    > SimulationResult '{sim_res.name}' (ID {sim_res.id})")
    for a in sim_res.assets:
        print(f"      - Asset '{a.label}' ({a.id})")

# %% [markdown]
# ### 6. Stage circuit & campaign in local folder

# %%
CIRCUIT_STAGING_ROOT = Path("./STAGING/circuits")
CAMPAIGN_STAGING_ROOT = Path("./STAGING/simulation_campaigns")

# %%
def stage_campaign_circuit(simulation_campaign_id, output_root):
    """Stage the circuit of a simulation campaign, incl. caching."""
    # Get circuit ID from simulation campaign
    simulation_campaign = client.get_entity(entity_type=models.SimulationCampaign, entity_id=simulation_campaign_id)
    circuit_id = str(simulation_campaign.entity_id)
    circuit_entity = client.get_entity(entity_type=models.Circuit, entity_id=circuit_id)

    # Stage circuit or use from cache
    output_dir = Path(output_root).resolve() / circuit_id
    if output_dir.exists():
        print(f"INFO: Using cached circuit '{circuit_entity.name}'")
        circuit_config_path = output_dir / "circuit_config.json"
    else:
        circuit_config_path = stage_circuit(
            client=client,
            model=circuit_entity,
            output_dir=output_dir,
            max_concurrent=4,
        )
    assert circuit_config_path.is_file(), "ERROR: Circuit staging error - clear cache and retry!"
    print(f"INFO: Staged circuit '{circuit_entity.name}' at {circuit_config_path}")

    return circuit_config_path

def stage_sim_campaign(simulation_campaign_id, output_root, circuit_config_path):
    """Stage the simulation campaign w/o circuit, incl. caching."""
    simulation_campaign = client.get_entity(entity_type=models.SimulationCampaign, entity_id=simulation_campaign_id)
    campaign_output_dir = Path(output_root).resolve() / str(simulation_campaign_id)

    # Stage individual simulations and results
    simulation_config_paths = []
    for simulation in simulation_campaign.simulations:
        # IMPORTANT: The order of simulations returned by simulation_campaign.simulations is not necessarily ordered!!

        simulation = client.get_entity(entity_id=simulation.id, entity_type=models.Simulation)  # Required to get assets!!

        # Stage simulation + result or use from cache
        sim_dir = simulation.name.replace(" ", "_").lower()
        output_dir = campaign_output_dir / sim_dir
        if output_dir.exists():
            print(f"INFO: Using cached simulation '{simulation.name}'")
            simulation_config_path = output_dir / "simulation_config.json"
        else:
            # Stage simulation
            simulation_config_path = stage_simulation(
                client=client,
                model=simulation,
                output_dir=output_dir,
                circuit_config_path=circuit_config_path,
            )

            # Get simulation execution and stage simulation result
            simulation_executions = client.search_entity(
                entity_type=models.SimulationExecution,
                query={"used__id": simulation.id}
            ).all()

            if len(simulation_executions) == 0:
                print(f"WARNING: No SimulationExecution/Result found for Simulation ID {simulation.id}")
            else:
                simulation_execution = simulation_executions[0]
                simulation_result_id = simulation_execution.generated[0].id
                simulation_result = client.get_entity(entity_type=models.SimulationResult, entity_id=simulation_result_id)

                _ = stage_simulation_result(
                    client=client,
                    model=simulation_result,
                    output_dir=output_dir,
                    simulation_config_file=simulation_config_path,
                )
        
        assert simulation_config_path.is_file(), "ERROR: Simulation staging error - clear cache and retry!"
        print(f"INFO: Staged simulation '{simulation.name}' at {simulation_config_path}")

        simulation_config_paths.append(str(simulation_config_path))

    # Stage campaign summary
    config_path = None
    for asset in simulation_campaign.assets:
        if asset.label == "campaign_summary":
            config_path = client.download_file(
                asset_id=asset.id,
                entity_id=simulation_campaign_id,
                entity_type=models.SimulationCampaign,
                output_path=campaign_output_dir,
            )
            break

    if config_path is not None:
        # Update paths of campaign config
        with open(config_path, "r") as f:
            config_dict = json.load(f)
        config_dict["attrs"]["path_prefix"] = "./"
        config_dict["attrs"]["circuit_config"] = str(staged_circuit_config)
        with open(config_path, "w") as f:
            json.dump(config_dict, f, indent=2)

    print(f"INFO: Staged campaign '{simulation_campaign.name}' with {len(simulation_config_paths)} simulation(s)")

    return simulation_config_paths, config_path

# %%
staged_circuit_config = stage_campaign_circuit(
    simulation_campaign_id=registered_campaign.id,
    output_root=CIRCUIT_STAGING_ROOT,
)

# %%
staged_sim_configs, staged_campaign_config_path = stage_sim_campaign(
    simulation_campaign_id=registered_campaign.id,
    output_root=CAMPAIGN_STAGING_ROOT,
    circuit_config_path=staged_circuit_config
)

# %%
# Check staged spike file sizes
spike_fn = "spikes.h5"
for _sim in sim_folders:
    fsize_orig = (_sim / "reporting" / spike_fn).stat().st_size
    sim_id = _sim.name
    fsize_staged = (staged_campaign_config_path.parent / f"simulation_{sim_id}" / "reporting" / spike_fn).stat().st_size
    assert fsize_orig == fsize_staged, f"ERROR: File size mismatch for '{_sim}'!"

# %% [markdown]
# ### 7. Plot spikes

# %%
def plot_spikes(simulation_config_paths):
    for simulation_config_path in simulation_config_paths:
        # print(f"Processing simulation config path: {simulation_config_path}")
        
        # Plot and print the spikes
        snap_simulation = Simulation(simulation_config_path)
        spikes = snap_simulation.spikes
        spikes.filter().raster()

        # print(spikes.population_names)
        # for population in spikes.population_names:
        #     population_spikes = spikes[population]
        #     print(population_spikes.get())

# %%
plot_spikes(staged_sim_configs)
