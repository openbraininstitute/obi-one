# %%
import obi
import os

# %%
input_root = "/Volumes/4TB/Circuits"
output_root = "/Volumes/T7/Circuits-out"

# %%
morphology_containerization_form = obi.MorphologyContainerizationsForm(
                    initialize=obi.MorphologyContainerizationsForm.Initialize(
                        circuit_path=[
                            # obi.NamedPath(name="nbS1-HEX0", path=os.path.join(input_root, "nbS1-HEX0", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX1", path=os.path.join(input_root, "nbS1-HEX1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX2", path=os.path.join(input_root, "nbS1-HEX2", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX3", path=os.path.join(input_root, "nbS1-HEX3", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX4", path=os.path.join(input_root, "nbS1-HEX4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX5", path=os.path.join(input_root, "nbS1-HEX5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX6", path=os.path.join(input_root, "nbS1-HEX6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX0-L1", path=os.path.join(input_root, "nbS1-HEX0-L1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-L23", path=os.path.join(input_root, "nbS1-HEX0-L23", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-L4", path=os.path.join(input_root, "nbS1-HEX0-L4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-L5", path=os.path.join(input_root, "nbS1-HEX0-L5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-L6", path=os.path.join(input_root, "nbS1-HEX0-L6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX1-L1", path=os.path.join(input_root, "nbS1-HEX1-L1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX1-L23", path=os.path.join(input_root, "nbS1-HEX1-L23", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX1-L4", path=os.path.join(input_root, "nbS1-HEX1-L4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX1-L5", path=os.path.join(input_root, "nbS1-HEX1-L5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX1-L6", path=os.path.join(input_root, "nbS1-HEX1-L6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX2-L1", path=os.path.join(input_root, "nbS1-HEX2-L1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX2-L23", path=os.path.join(input_root, "nbS1-HEX2-L23", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX2-L4", path=os.path.join(input_root, "nbS1-HEX2-L4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX2-L5", path=os.path.join(input_root, "nbS1-HEX2-L5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX2-L6", path=os.path.join(input_root, "nbS1-HEX2-L6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX3-L1", path=os.path.join(input_root, "nbS1-HEX3-L1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX3-L23", path=os.path.join(input_root, "nbS1-HEX3-L23", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX3-L4", path=os.path.join(input_root, "nbS1-HEX3-L4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX3-L5", path=os.path.join(input_root, "nbS1-HEX3-L5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX3-L6", path=os.path.join(input_root, "nbS1-HEX3-L6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX4-L1", path=os.path.join(input_root, "nbS1-HEX4-L1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX4-L23", path=os.path.join(input_root, "nbS1-HEX4-L23", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX4-L4", path=os.path.join(input_root, "nbS1-HEX4-L4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX4-L5", path=os.path.join(input_root, "nbS1-HEX4-L5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX4-L6", path=os.path.join(input_root, "nbS1-HEX4-L6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX5-L1", path=os.path.join(input_root, "nbS1-HEX5-L1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX5-L23", path=os.path.join(input_root, "nbS1-HEX5-L23", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX5-L4", path=os.path.join(input_root, "nbS1-HEX5-L4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX5-L5", path=os.path.join(input_root, "nbS1-HEX5-L5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX5-L6", path=os.path.join(input_root, "nbS1-HEX5-L6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX6-L1", path=os.path.join(input_root, "nbS1-HEX6-L1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX6-L23", path=os.path.join(input_root, "nbS1-HEX6-L23", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX6-L4", path=os.path.join(input_root, "nbS1-HEX6-L4", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX6-L5", path=os.path.join(input_root, "nbS1-HEX6-L5", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX6-L6", path=os.path.join(input_root, "nbS1-HEX6-L6", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-HEX0-beta", path=os.path.join(input_root, "nbS1-HEX0-beta", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-ER", path=os.path.join(input_root, "nbS1-HEX0-beta-ER", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-DD", path=os.path.join(input_root, "nbS1-HEX0-beta-DD", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-BIP", path=os.path.join(input_root, "nbS1-HEX0-beta-BIP", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-OFF", path=os.path.join(input_root, "nbS1-HEX0-beta-OFF", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-POS", path=os.path.join(input_root, "nbS1-HEX0-beta-POS", "circuit_config.json"))

                            # obi.NamedPath(name="rCA1-CYLINDER-REF", path=os.path.join(input_root, "rCA1-CYLINDER-REF", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.1-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.1-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.2-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.2-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.3-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.3-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.4-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.4-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.5-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.5-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.6-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.6-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.7-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.7-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.8-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.8-RAD300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-CYLINDER-L0.9-RAD300", path=os.path.join(input_root, "rCA1-CYLINDER-L0.9-RAD300", "circuit_config.json")),

                            # obi.NamedPath(name="rCA1-SLICE-REF", path=os.path.join(input_root, "rCA1-SLICE-REF", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.05-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.05-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.16-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.16-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.27-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.27-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.37-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.37-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.48-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.48-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.59-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.59-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.69-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.69-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.80-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.80-THICK300", "circuit_config.json")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.90-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.90-THICK300", "circuit_config.json")),

                            # obi.NamedPath(name="nbS1-O1", path=os.path.join(input_root, "nbS1-O1", "circuit_config.json")),
                            # obi.NamedPath(name="nbS1-O1-SM", path=os.path.join(input_root, "nbS1-O1-SM", "circuit_config.json")),
                            
                            # obi.NamedPath(name="nbS1-O1-beta", path=os.path.join(input_root, "nbS1-O1-beta", "circuit_config_tc.json")),
                            # obi.NamedPath(name="nbS1-O1-beta-ER", path=os.path.join(input_root, "nbS1-O1-beta-ER", "circuit_config_tc.json")),
                            # obi.NamedPath(name="nbS1-O1-beta-DD", path=os.path.join(input_root, "nbS1-O1-beta-DD", "circuit_config_tc.json")),
                            # obi.NamedPath(name="nbS1-O1-beta-BIP", path=os.path.join(input_root, "nbS1-O1-beta-BIP", "circuit_config_tc.json")),
                            # obi.NamedPath(name="nbS1-O1-beta-OFF", path=os.path.join(input_root, "nbS1-O1-beta-OFF", "circuit_config_tc.json")),
                            # obi.NamedPath(name="nbS1-O1-beta-POS", path=os.path.join(input_root, "nbS1-O1-beta-POS", "circuit_config_tc.json")),

                            # obi.NamedPath(name="rCA1", path=os.path.join(input_root, "rCA1", "circuit_config.json")),
                        ],
                        hoc_template_old = "../../obi/modeling/morphology_containerization/cell_template_neurodamus.jinja2",
                        hoc_template_new = "../../obi/modeling/morphology_containerization/cell_template_neurodamus_obi.jinja2"
                    )
)

grid_scan = obi.GridScan(form=morphology_containerization_form, output_root=os.path.join(output_root, ""), coordinate_directory_option="VALUE")

# %%
grid_scan.run()
# Out:
# Running morphology containerization for 'nbS1-O1-beta'
# Copying circuit to output folder...
# ...DONE
# > 70881 unique morphologies in population 'S1nonbarrel_neurons' (211712)
# ...
# Merging .h5 into container: 100%|█████████████████████████████████████████████████████████████████████████████| 70881/70881 [02:23<00:00, 492.47it/s]
# Merged 70881 morphologies into container (0 already existed)
# Updating .hoc files: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 1069.72it/s]
# Cleaning morphology folders: ['/Volumes/T7/Circuits-out/nbS1-O1-beta/morphologies/ascii', '/Volumes/T7/Circuits-out/nbS1-O1-beta/morphologies/_h5_morphologies_tmp_']
# Morphology containerization DONE
# Running morphology containerization for 'nbS1-O1-beta-ER'
# Copying circuit to output folder...
# ...DONE
# > 70881 unique morphologies in population 'S1nonbarrel_neurons' (211712)
# ...
