# %%
import obi
import os

# %%
input_root = "/Volumes/T7/Circuits"
output_root = "/Volumes/T7/CircuitsCompressed"

# %%
folder_compressions_form = obi.FolderCompressions(
                    initialize=obi.FolderCompressions.Initialize(
                        folder_path=[
                            # obi.NamedPath(name="nbS1-HEX0", path=os.path.join(input_root, "nbS1-HEX0")),
                            # obi.NamedPath(name="nbS1-HEX1", path=os.path.join(input_root, "nbS1-HEX1")),
                            # obi.NamedPath(name="nbS1-HEX2", path=os.path.join(input_root, "nbS1-HEX2")),
                            # obi.NamedPath(name="nbS1-HEX3", path=os.path.join(input_root, "nbS1-HEX3")),
                            # obi.NamedPath(name="nbS1-HEX4", path=os.path.join(input_root, "nbS1-HEX4")),
                            # obi.NamedPath(name="nbS1-HEX5", path=os.path.join(input_root, "nbS1-HEX5")),
                            # obi.NamedPath(name="nbS1-HEX6", path=os.path.join(input_root, "nbS1-HEX6")),

                            # obi.NamedPath(name="nbS1-HEX0-L1", path=os.path.join(input_root, "nbS1-HEX0-L1")),
                            # obi.NamedPath(name="nbS1-HEX0-L23", path=os.path.join(input_root, "nbS1-HEX0-L23")),
                            # obi.NamedPath(name="nbS1-HEX0-L4", path=os.path.join(input_root, "nbS1-HEX0-L4")),
                            # obi.NamedPath(name="nbS1-HEX0-L5", path=os.path.join(input_root, "nbS1-HEX0-L5")),
                            # obi.NamedPath(name="nbS1-HEX0-L6", path=os.path.join(input_root, "nbS1-HEX0-L6")),

                            # obi.NamedPath(name="nbS1-HEX1-L1", path=os.path.join(input_root, "nbS1-HEX1-L1")),
                            # obi.NamedPath(name="nbS1-HEX1-L23", path=os.path.join(input_root, "nbS1-HEX1-L23")),
                            # obi.NamedPath(name="nbS1-HEX1-L4", path=os.path.join(input_root, "nbS1-HEX1-L4")),
                            # obi.NamedPath(name="nbS1-HEX1-L5", path=os.path.join(input_root, "nbS1-HEX1-L5")),
                            # obi.NamedPath(name="nbS1-HEX1-L6", path=os.path.join(input_root, "nbS1-HEX1-L6")),

                            # obi.NamedPath(name="nbS1-HEX2-L1", path=os.path.join(input_root, "nbS1-HEX2-L1")),
                            # obi.NamedPath(name="nbS1-HEX2-L23", path=os.path.join(input_root, "nbS1-HEX2-L23")),
                            # obi.NamedPath(name="nbS1-HEX2-L4", path=os.path.join(input_root, "nbS1-HEX2-L4")),
                            # obi.NamedPath(name="nbS1-HEX2-L5", path=os.path.join(input_root, "nbS1-HEX2-L5")),
                            # obi.NamedPath(name="nbS1-HEX2-L6", path=os.path.join(input_root, "nbS1-HEX2-L6")),

                            # obi.NamedPath(name="nbS1-HEX3-L1", path=os.path.join(input_root, "nbS1-HEX3-L1")),
                            # obi.NamedPath(name="nbS1-HEX3-L23", path=os.path.join(input_root, "nbS1-HEX3-L23")),
                            # obi.NamedPath(name="nbS1-HEX3-L4", path=os.path.join(input_root, "nbS1-HEX3-L4")),
                            # obi.NamedPath(name="nbS1-HEX3-L5", path=os.path.join(input_root, "nbS1-HEX3-L5")),
                            # obi.NamedPath(name="nbS1-HEX3-L6", path=os.path.join(input_root, "nbS1-HEX3-L6")),

                            # obi.NamedPath(name="nbS1-HEX4-L1", path=os.path.join(input_root, "nbS1-HEX4-L1")),
                            # obi.NamedPath(name="nbS1-HEX4-L23", path=os.path.join(input_root, "nbS1-HEX4-L23")),
                            # obi.NamedPath(name="nbS1-HEX4-L4", path=os.path.join(input_root, "nbS1-HEX4-L4")),
                            # obi.NamedPath(name="nbS1-HEX4-L5", path=os.path.join(input_root, "nbS1-HEX4-L5")),
                            # obi.NamedPath(name="nbS1-HEX4-L6", path=os.path.join(input_root, "nbS1-HEX4-L6")),

                            # obi.NamedPath(name="nbS1-HEX5-L1", path=os.path.join(input_root, "nbS1-HEX5-L1")),
                            # obi.NamedPath(name="nbS1-HEX5-L23", path=os.path.join(input_root, "nbS1-HEX5-L23")),
                            # obi.NamedPath(name="nbS1-HEX5-L4", path=os.path.join(input_root, "nbS1-HEX5-L4")),
                            # obi.NamedPath(name="nbS1-HEX5-L5", path=os.path.join(input_root, "nbS1-HEX5-L5")),
                            # obi.NamedPath(name="nbS1-HEX5-L6", path=os.path.join(input_root, "nbS1-HEX5-L6")),

                            # obi.NamedPath(name="nbS1-HEX6-L1", path=os.path.join(input_root, "nbS1-HEX6-L1")),
                            # obi.NamedPath(name="nbS1-HEX6-L23", path=os.path.join(input_root, "nbS1-HEX6-L23")),
                            # obi.NamedPath(name="nbS1-HEX6-L4", path=os.path.join(input_root, "nbS1-HEX6-L4")),
                            # obi.NamedPath(name="nbS1-HEX6-L5", path=os.path.join(input_root, "nbS1-HEX6-L5")),
                            # obi.NamedPath(name="nbS1-HEX6-L6", path=os.path.join(input_root, "nbS1-HEX6-L6")),

                            # obi.NamedPath(name="nbS1-HEX0-beta", path=os.path.join(input_root, "nbS1-HEX0-beta")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-ER", path=os.path.join(input_root, "nbS1-HEX0-beta-ER")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-DD", path=os.path.join(input_root, "nbS1-HEX0-beta-DD")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-BIP", path=os.path.join(input_root, "nbS1-HEX0-beta-BIP")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-OFF", path=os.path.join(input_root, "nbS1-HEX0-beta-OFF")),
                            # obi.NamedPath(name="nbS1-HEX0-beta-POS", path=os.path.join(input_root, "nbS1-HEX0-beta-POS")),

                            # obi.NamedPath(name="rCA1-SLICE-REF", path=os.path.join(input_root, "rCA1-SLICE-REF")),
                            # obi.NamedPath(name="rCA1-SLICE-L0.05-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.05-THICK300")),

                            # ^^^ DONE ^^^

                            # vvv TODO vvv
                            
                            obi.NamedPath(name="rCA1-SLICE-L0.16-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.16-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.27-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.27-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.37-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.37-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.48-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.48-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.59-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.59-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.69-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.69-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.80-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.80-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.90-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.90-THICK300")),

                            obi.NamedPath(name="rCA1-SLICE-REF", path=os.path.join(input_root, "rCA1-SLICE-REF")),
                            obi.NamedPath(name="rCA1-SLICE-L0.05-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.05-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.16-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.16-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.27-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.27-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.37-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.37-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.48-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.48-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.59-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.59-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.69-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.69-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.80-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.80-THICK300")),
                            obi.NamedPath(name="rCA1-SLICE-L0.90-THICK300", path=os.path.join(input_root, "rCA1-SLICE-L0.90-THICK300")),

                            obi.NamedPath(name="nbS1-O1", path=os.path.join(input_root, "nbS1-O1")),
                            obi.NamedPath(name="nbS1-O1-SM", path=os.path.join(input_root, "nbS1-O1-SM")),
                            
                            obi.NamedPath(name="nbS1-O1-beta", path=os.path.join(input_root, "nbS1-O1-beta")),
                            obi.NamedPath(name="nbS1-O1-beta-ER", path=os.path.join(input_root, "nbS1-O1-beta-ER")),
                            obi.NamedPath(name="nbS1-O1-beta-DD", path=os.path.join(input_root, "nbS1-O1-beta-DD")),
                            obi.NamedPath(name="nbS1-O1-beta-BIP", path=os.path.join(input_root, "nbS1-O1-beta-BIP")),
                            obi.NamedPath(name="nbS1-O1-beta-OFF", path=os.path.join(input_root, "nbS1-O1-beta-OFF")),
                            obi.NamedPath(name="nbS1-O1-beta-POS", path=os.path.join(input_root, "nbS1-O1-beta-POS")),

                            obi.NamedPath(name="rCA1", path=os.path.join(input_root, "rCA1")),

                        ],

                        file_format="gz",
                        file_name="circuit"
                    )
)

grid_scan = obi.GridScan(form=folder_compressions_form, output_root=os.path.join(output_root, ""), coordinate_directory_option="VALUE")

# %%
grid_scan.run()
