# %%
import obi_one as obi

from pathlib import Path
import bluepysnap as snap

circ_path = Path("/Users/mwr/Documents/artefacts/SONATA/O1_data/circuit_config.json")
node_set = "S1nonbarrel_neurons"
node_id = 1337

circ = snap.Circuit(circ_path)

# %% [markdown]
# # Synapse selections
#
# We demonstrate different ways of selecting subsets of afferent synapses on a neuron in a circuit.
#
# The output of the selectors is always a pandas.DataFrame with one row per selected synapse.
#
# The DataFrame contains sufficient information in its columns to identify the synapses unequivocally. It specifies both the name of their edge population and the edge id within the population; this tuple is the identifier of an edge in Sonata. Additionally, the node population and node id of the presynaptic neuron are returned. "afferent_section_id", etc. are provided to specify the location of the synapse on the morphology, for example for visualizations.
#
# Finally, some other, potentially useful statistics are also returned.

# %% [markdown]
# ## Case 1: Random, unbiased selection
#
# However, the second & third example show that section type, synapse class and node population can be filtered against.
#
# Also note that both intrinsic and extrinsic synapses are considered! To avoid that, set "pre_node_population" to a list of non-virtual populations.

# %%
tst = obi.RandomlySelectedNumberOfSynapses(
    n=3
)
display(tst.synapses_on(circ, node_set, node_id))

tst = obi.RandomlySelectedNumberOfSynapses(
    n=3,
    section_types=(1,),
    pre_synapse_class="INH",
    pre_node_populations=("S1nonbarrel_neurons",)
)
display(tst.synapses_on(circ, node_set, node_id))

tst = obi.RandomlySelectedNumberOfSynapses(
    n=3,
    section_types=(3, 4),
    pre_node_populations=("POm",)
)
display(tst.synapses_on(circ, node_set, node_id))
# Out:
#        source_population                                    edge_population  \
# 868  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
# 477  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
# 215  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
#
#      edge_id  afferent_section_id  afferent_segment_id  \
# 868  1186554                  124                   24
# 477  1186163                  142                    6
# 215  1185901                  147                    7
#
#      afferent_segment_offset  @source_node  @target_node  \
# 868                 0.588084        113999          1337
# 477                 0.880533         26229          1337
# 215                 0.953837         14544          1337
#
#      afferent_section_type
# 868                      3
# 477                      3
# 215                      3
# /Users/mwr/Documents/repositories/obi-one/obi_one/scientific/afferent_synapse_finder/find_specified_afferent_synapses.py:78: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pre_node_props = pandas.concat(pre_node_props, axis=0, names=["source_population", "edge_population"],
#         source_population                                    edge_population  \
# 1619  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
# 1277  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
# 1276  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
#
#       edge_id  afferent_section_id  afferent_segment_id  \
# 1619  1187305                    0                    0
# 1277  1186963                    0                    0
# 1276  1186962                    0                    0
#
#       afferent_segment_offset  @source_node  @target_node synapse_class  \
# 1619                      0.0        173904          1337           INH
# 1277                      0.0        141883          1337           INH
# 1276                      0.0        141883          1337           INH
#
#       afferent_section_type
# 1619                      1
# 1277                      1
# 1276                      1
#      source_population                     edge_population  edge_id  \
# 1820               POm  POm__S1nonbarrel_neurons__chemical   102540
# 1831               POm  POm__S1nonbarrel_neurons__chemical   102551
# 1819               POm  POm__S1nonbarrel_neurons__chemical   102539
#
#       afferent_section_id  afferent_segment_id  afferent_segment_offset  \
# 1820                  166                   68                 1.033777
# 1831                  162                   91                 0.347443
# 1819                  168                   21                 3.185710
#
#       @source_node  @target_node  afferent_section_type
# 1820          4794          1337                      4
# 1831          6022          1337                      4
# 1819          3832          1337                      4

# %% [markdown]
# ### Note on insufficient synapses
#
# In general, if there are fewer valid synapses than requested, no exception is raised. Instead simply the lower number of synapses is returned.
# The code has a "raise_insufficient" flag that can change the behavior, but it currently is not exposed to the user.
#
# Another question is: What happens if filter, e.g., by presynaptic synapse class, but the presynaptic nodes do not have a synapse_class attribute? This is set by the optional consider_nan_pass parameter.

# %%
# Requesting EXC synapses on the axon. There are none. This will return empty
tst = obi.RandomlySelectedNumberOfSynapses(
    n=3,
    section_types=(2, ),
    pre_synapse_class="EXC"
)
display(tst.synapses_on(circ, node_set, node_id))

# Default behavior: Even though the POm population has no synapse_class attribute, they will not be filtered. This returns 3 synapses
tst = obi.RandomlySelectedNumberOfSynapses(
    n=3,
    pre_synapse_class="EXC",
    pre_node_populations=("POm",)
)
display(tst.synapses_on(circ, node_set, node_id))

# More stric: POm, which have no synapse_class will be filtered. Hence, no synapses can be returned.
tst = obi.RandomlySelectedNumberOfSynapses(
    n=3,
    pre_synapse_class="EXC",
    pre_node_populations=("POm",),
    consider_nan_pass=False
)
display(tst.synapses_on(circ, node_set, node_id))
# Out:
# /Users/mwr/Documents/repositories/obi-one/obi_one/scientific/afferent_synapse_finder/find_specified_afferent_synapses.py:78: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pre_node_props = pandas.concat(pre_node_props, axis=0, names=["source_population", "edge_population"],
# Empty DataFrame
# Columns: [source_population, edge_population, edge_id, afferent_section_id, afferent_segment_id, afferent_segment_offset, @source_node, @target_node, synapse_class, afferent_section_type]
# Index: []
# /Users/mwr/Documents/repositories/obi-one/obi_one/scientific/afferent_synapse_finder/find_specified_afferent_synapses.py:78: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pre_node_props = pandas.concat(pre_node_props, axis=0, names=["source_population", "edge_population"],
#      source_population                     edge_population  edge_id  \
# 1820               POm  POm__S1nonbarrel_neurons__chemical   102540
# 1831               POm  POm__S1nonbarrel_neurons__chemical   102551
# 1819               POm  POm__S1nonbarrel_neurons__chemical   102539
#
#       afferent_section_id  afferent_segment_id  afferent_segment_offset  \
# 1820                  166                   68                 1.033777
# 1831                  162                   91                 0.347443
# 1819                  168                   21                 3.185710
#
#       @source_node  @target_node synapse_class  afferent_section_type
# 1820          4794          1337           NaN                      4
# 1831          6022          1337           NaN                      4
# 1819          3832          1337           NaN                      4
# /Users/mwr/Documents/repositories/obi-one/obi_one/scientific/afferent_synapse_finder/find_specified_afferent_synapses.py:78: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pre_node_props = pandas.concat(pre_node_props, axis=0, names=["source_population", "edge_population"],
# Empty DataFrame
# Columns: [source_population, edge_population, edge_id, afferent_section_id, afferent_segment_id, afferent_segment_offset, @source_node, @target_node, synapse_class, afferent_section_type]
# Index: []

# %% [markdown]
# ## Case 2: Synapse clusters
#
# There are two options: (1) Return all synapses that are within a specified maximum distance of the center of a cluster. (2) Return the n closest synapses to a cluster center.
#
# Now, an additional column "cluster_id" is added.

# %%
# All within the distance
tst = obi.ClusteredSynapsesByMaxDistance(
    n_clusters=3,
    cluster_max_distance=25.0
)
display(tst.synapses_on(circ, node_set, node_id))

# The 25 closest
tst = obi.ClusteredSynapsesByCount(
    n_clusters=3,
    n_per_cluster=25,
    pre_node_populations=("VPM", "POm")  # Additional filters still enabled
)
display(tst.synapses_on(circ, node_set, node_id))
# Out:
#       cluster_id    source_population  \
# 76             0  S1nonbarrel_neurons
# 109            0  S1nonbarrel_neurons
# 110            0  S1nonbarrel_neurons
# 261            0  S1nonbarrel_neurons
# 345            0  S1nonbarrel_neurons
# 369            0  S1nonbarrel_neurons
# 752            0  S1nonbarrel_neurons
# 774            0  S1nonbarrel_neurons
# 798            0  S1nonbarrel_neurons
# 805            0  S1nonbarrel_neurons
# 946            0  S1nonbarrel_neurons
# 947            0  S1nonbarrel_neurons
# 948            0  S1nonbarrel_neurons
# 970            0  S1nonbarrel_neurons
# 1015           0  S1nonbarrel_neurons
# 1049           0  S1nonbarrel_neurons
# 1076           0  S1nonbarrel_neurons
# 1422           0  S1nonbarrel_neurons
# 1524           0  S1nonbarrel_neurons
# 1653           0  S1nonbarrel_neurons
# 1807           0  S1nonbarrel_neurons
# 2006           0                  VPM
# 2008           0                  VPM
# 70             1  S1nonbarrel_neurons
# 396            1  S1nonbarrel_neurons
# 520            1  S1nonbarrel_neurons
# 569            1  S1nonbarrel_neurons
# 845            1  S1nonbarrel_neurons
# 965            1  S1nonbarrel_neurons
# 1080           1  S1nonbarrel_neurons
# 1081           1  S1nonbarrel_neurons
# 1082           1  S1nonbarrel_neurons
# 1517           1  S1nonbarrel_neurons
# 1698           1  S1nonbarrel_neurons
# 1699           1  S1nonbarrel_neurons
# 1896           1  S1nonbarrel_neurons
# 1897           1  S1nonbarrel_neurons
# 2296           1                  VPM
# 172            2  S1nonbarrel_neurons
# 775            2  S1nonbarrel_neurons
# 854            2  S1nonbarrel_neurons
# 911            2  S1nonbarrel_neurons
# 1197           2  S1nonbarrel_neurons
# 1319           2  S1nonbarrel_neurons
# 1623           2  S1nonbarrel_neurons
# 2104           2                  VPM
# 2160           2                  VPM
# 2186           2                  VPM
# 2215           2                  VPM
#
#                                         edge_population  edge_id  \
# 76    S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185762
# 109   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185795
# 110   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185796
# 261   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185947
# 345   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186031
# 369   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186055
# 752   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186438
# 774   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186460
# 798   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186484
# 805   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186491
# 946   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186632
# 947   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186633
# 948   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186634
# 970   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186656
# 1015  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186701
# 1049  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186735
# 1076  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186762
# 1422  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187108
# 1524  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187210
# 1653  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187339
# 1807  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187493
# 2006                 VPM__S1nonbarrel_neurons__chemical   178325
# 2008                 VPM__S1nonbarrel_neurons__chemical   178327
# 70    S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185756
# 396   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186082
# 520   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186206
# 569   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186255
# 845   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186531
# 965   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186651
# 1080  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186766
# 1081  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186767
# 1082  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186768
# 1517  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187203
# 1698  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187384
# 1699  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187385
# 1896  external_S1nonbarrel_neurons__S1nonbarrel_neur...   286801
# 1897  external_S1nonbarrel_neurons__S1nonbarrel_neur...   286802
# 2296                 VPM__S1nonbarrel_neurons__chemical   178615
# 172   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185858
# 775   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186461
# 854   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186540
# 911   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186597
# 1197  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186883
# 1319  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187005
# 1623  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187309
# 2104                 VPM__S1nonbarrel_neurons__chemical   178423
# 2160                 VPM__S1nonbarrel_neurons__chemical   178479
# 2186                 VPM__S1nonbarrel_neurons__chemical   178505
# 2215                 VPM__S1nonbarrel_neurons__chemical   178534
#
#       afferent_section_id  afferent_segment_id  afferent_segment_offset  \
# 76                    112                   61                 4.696655
# 109                   112                   59                 1.138809
# 110                   112                   55                 0.718337
# 261                   112                   61                 9.148268
# 345                   112                   46                 0.731925
# 369                   112                   53                 0.905540
# 752                   112                   61                 6.166913
# 774                   112                   61                 6.493636
# 798                   112                   60                 4.890615
# 805                   112                   60                 3.097389
# 946                   112                   55                 0.024454
# 947                   112                   50                 2.050208
# 948                   112                   47                 0.480590
# 970                   112                   49                 0.279661
# 1015                  112                   58                 0.816938
# 1049                  112                   59                 0.081344
# 1076                  112                   54                 1.179659
# 1422                  112                   59                 6.304123
# 1524                  112                   58                 1.602455
# 1653                  112                   59                 4.961956
# 1807                  112                   59                 8.175025
# 2006                  112                   53                 1.455946
# 2008                  112                   61                 3.768493
# 70                     98                   36                 1.745864
# 396                    98                   49                 0.927618
# 520                    98                   29                 1.002683
# 569                    98                   36                 2.027748
# 845                    98                   44                 0.669937
# 965                    98                   62                 1.336032
# 1080                   98                   36                 0.136396
# 1081                   98                   35                 1.466927
# 1082                   98                   35                 1.387326
# 1517                   98                   56                 0.465646
# 1698                   98                   62                 0.668016
# 1699                   98                   58                 0.549083
# 1896                   98                   34                 1.254159
# 1897                   98                   31                 1.477459
# 2296                   98                   45                 0.166481
# 172                   108                   14                 0.241880
# 775                   108                   26                 0.716052
# 854                   108                    4                 0.368019
# 911                   108                   25                 0.445984
# 1197                  108                   21                 0.345970
# 1319                  108                   23                 0.457311
# 1623                  108                    4                 0.044299
# 2104                  108                   21                 1.021641
# 2160                  108                   12                 0.878110
# 2186                  108                    1                 0.132824
# 2215                  108                   23                 0.250113
#
#       @source_node  @target_node  afferent_section_type
# 76            4529          1337                      3
# 109           6648          1337                      3
# 110           6648          1337                      3
# 261          16208          1337                      3
# 345          19660          1337                      3
# 369          20340          1337                      3
# 752         110176          1337                      3
# 774         111297          1337                      3
# 798         112286          1337                      3
# 805         112286          1337                      3
# 946         118496          1337                      3
# 947         118496          1337                      3
# 948         118496          1337                      3
# 970         119398          1337                      3
# 1015        124065          1337                      3
# 1049        126278          1337                      3
# 1076        129426          1337                      3
# 1422        153994          1337                      3
# 1524        164814          1337                      3
# 1653        177273          1337                      3
# 1807        210146          1337                      3
# 2006          3352          1337                      3
# 2008          3352          1337                      3
# 70            4395          1337                      3
# 396          22022          1337                      3
# 520          28262          1337                      3
# 569          30657          1337                      3
# 845         113740          1337                      3
# 965         118808          1337                      3
# 1080        129450          1337                      3
# 1081        129450          1337                      3
# 1082        129450          1337                      3
# 1517        164235          1337                      3
# 1698        189546          1337                      3
# 1699        189546          1337                      3
# 1896         79936          1337                      3
# 1897         79936          1337                      3
# 2296         10878          1337                      3
# 172          10842          1337                      3
# 775         111459          1337                      3
# 854         113890          1337                      3
# 911         117472          1337                      3
# 1197        138391          1337                      3
# 1319        142830          1337                      3
# 1623        174539          1337                      3
# 2104          6299          1337                      3
# 2160          7307          1337                      3
# 2186          7431          1337                      3
# 2215          7860          1337                      3
#       cluster_id source_population                     edge_population  \
# 2109           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 2351           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 2045           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 2352           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 2227           0               VPM  VPM__S1nonbarrel_neurons__chemical
# ...          ...               ...                                 ...
# 1977           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 2199           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 2136           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 1988           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 2096           2               VPM  VPM__S1nonbarrel_neurons__chemical
#
#       edge_id  afferent_section_id  afferent_segment_id  \
# 2109   178428                  122                   35
# 2351   178670                  122                   34
# 2045   178364                  122                   38
# 2352   178671                  122                   43
# 2227   178546                  122                   24
# ...       ...                  ...                  ...
# 1977   178296                  132                    0
# 2199   178518                  151                   12
# 2136   178455                  132                    2
# 1988   178307                  104                   12
# 2096   178415                  127                    8
#
#       afferent_segment_offset  @source_node  @target_node  \
# 2109                 0.196120          6372          1337
# 2351                 0.116039         12047          1337
# 2045                 1.423923          4487          1337
# 2352                 0.054273         12047          1337
# 2227                 0.480743          8615          1337
# ...                       ...           ...           ...
# 1977                 0.258751          2958          1337
# 2199                 0.307418          7504          1337
# 2136                 2.312972          7052          1337
# 1988                 0.451906          3187          1337
# 2096                 0.203371          6266          1337
#
#       afferent_section_type
# 2109                      3
# 2351                      3
# 2045                      3
# 2352                      3
# 2227                      3
# ...                     ...
# 1977                      3
# 2199                      4
# 2136                      3
# 1988                      3
# 2096                      3
#
# [75 rows x 10 columns]

# %% [markdown]
# ## Case 3: Also consider path distance

# %%
# All within the distance
tst = obi.ClusteredPDSynapsesByMaxDistance(
    n_clusters=3,
    cluster_max_distance=25.0,
    soma_pd_mean=100.0,
    soma_pd_sd=10.0
)
display(tst.synapses_on(circ, node_set, node_id))

# The 25 closest
tst = obi.ClusteredPDSynapsesByCount(
    n_clusters=3,
    n_per_cluster=25,
    soma_pd_mean=400.0,
    soma_pd_sd=10.0,
    pre_node_populations=("VPM", "POm")
)
display(tst.synapses_on(circ, node_set, node_id))
# Out:
#       cluster_id    source_population  \
# 122            0  S1nonbarrel_neurons
# 238            0  S1nonbarrel_neurons
# 272            0  S1nonbarrel_neurons
# 461            0  S1nonbarrel_neurons
# 519            0  S1nonbarrel_neurons
# ...          ...                  ...
# 2279           2                  VPM
# 2318           2                  VPM
# 2358           2                  VPM
# 2366           2                  VPM
# 2367           2                  VPM
#
#                                         edge_population  edge_id  \
# 122   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185808
# 238   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185924
# 272   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1185958
# 461   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186147
# 519   S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186205
# ...                                                 ...      ...
# 2279                 VPM__S1nonbarrel_neurons__chemical   178598
# 2318                 VPM__S1nonbarrel_neurons__chemical   178637
# 2358                 VPM__S1nonbarrel_neurons__chemical   178677
# 2366                 VPM__S1nonbarrel_neurons__chemical   178685
# 2367                 VPM__S1nonbarrel_neurons__chemical   178686
#
#       afferent_section_id  afferent_segment_id  afferent_segment_offset  \
# 122                    93                  143                 0.348943
# 238                    93                  127                 0.532427
# 272                    93                  115                 0.277223
# 461                    93                  104                 1.056867
# 519                    93                  113                 0.378717
# ...                   ...                  ...                      ...
# 2279                  175                    0                 0.277927
# 2318                  176                    8                 0.304326
# 2358                  176                    8                 0.247544
# 2366                  176                    7                 0.797054
# 2367                  175                    6                 0.277673
#
#       @source_node  @target_node  afferent_section_type
# 122           7580          1337                      3
# 238          15486          1337                      3
# 272          16627          1337                      3
# 461          25279          1337                      3
# 519          28262          1337                      3
# ...            ...           ...                    ...
# 2279          9773          1337                      4
# 2318         11184          1337                      4
# 2358         12105          1337                      4
# 2366         12383          1337                      4
# 2367         12383          1337                      4
#
# [104 rows x 10 columns]
#       cluster_id source_population                     edge_population  \
# 1837           0               POm  POm__S1nonbarrel_neurons__chemical
# 1814           0               POm  POm__S1nonbarrel_neurons__chemical
# 1826           0               POm  POm__S1nonbarrel_neurons__chemical
# 1823           0               POm  POm__S1nonbarrel_neurons__chemical
# 1824           0               POm  POm__S1nonbarrel_neurons__chemical
# ...          ...               ...                                 ...
# 2034           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 2276           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 2221           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 2168           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 2334           2               VPM  VPM__S1nonbarrel_neurons__chemical
#
#       edge_id  afferent_section_id  afferent_segment_id  \
# 1837   102557                  158                   34
# 1814   102534                  159                    3
# 1826   102546                  160                    6
# 1823   102543                  160                   14
# 1824   102544                  159                   16
# ...       ...                  ...                  ...
# 2034   178353                  134                    5
# 2276   178595                  136                    3
# 2221   178540                  133                    8
# 2168   178487                  133                    8
# 2334   178653                  137                    0
#
#       afferent_segment_offset  @source_node  @target_node  \
# 1837                 0.593004          7100          1337
# 1814                 0.429863          3206          1337
# 1826                 0.125907          5398          1337
# 1823                 0.368883          5285          1337
# 1824                 0.845747          5285          1337
# ...                       ...           ...           ...
# 2034                 0.073935          4416          1337
# 2276                 5.043669          9773          1337
# 2221                 0.688999          8474          1337
# 2168                 0.417249          7342          1337
# 2334                 0.645790         11689          1337
#
#       afferent_section_type
# 1837                      4
# 1814                      4
# 1826                      4
# 1823                      4
# 1824                      4
# ...                     ...
# 2034                      3
# 2276                      3
# 2221                      3
# 2168                      3
# 2334                      3
#
# [75 rows x 10 columns]

# %% [markdown]
# ## Case 4: Consider connections instead of individual synapses
#
# This one may be useful for spike replay. The idea is that instead of selecting individual synapses, the code selects from presynaptic neurons.
#
# This can be applied by setting "merge_multiple_syns_con" to True in any of the Blocks.
#
# In that case, path distances are considered by averaging them over synapse from the same presynaptic neuron. That is, for each presynaptic neuron, its path distance to all others and to the soma is the mean of its synapses onto the morphology.
# It is up to the user to decide how much sense that makes in their use case. Otherwise, they can stick to the non-path-distance based selectors.
#
# #### Note
# The output in that case is much leaner: It contains only the required information to identify the presynaptic neuron selected. This is because for most of the outputs of the dataframe, such as section id, averaging does not make sense. So they are dropped instead.

# %%
tst = obi.PathDistanceConstrainedNumberOfSynapses(
    n=25,
    soma_pd_mean=400.0,
    soma_pd_sd=10.0,
    pre_node_populations=("VPM", "POm"),
    merge_multiple_syns_con=True
)
display(tst.synapses_on(circ, node_set, node_id))
# Out:
#    source_population  @source_node
# 26               VPM          3352
# 84               VPM         11100
# 2                POm          2498
# 55               VPM          7342
# 68               VPM          8615
# 81               VPM         10689
# 16               POm          6985
# 78               VPM          9773
# 54               VPM          7307
# 66               VPM          8419
# 53               VPM          7264
# 89               VPM         11545
# 71               VPM          8863
# 13               POm          5607
# 7                POm          3832
# 30               VPM          4394
# 22               VPM          2958
# 24               VPM          3189
# 33               VPM          4566
# 8                POm          4794
# 43               VPM          6266
# 62               VPM          7755
# 3                POm          2899
# 86               VPM         11207
# 45               VPM          6372
