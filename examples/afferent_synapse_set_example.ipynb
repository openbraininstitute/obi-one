# %%
import obi_one as obi

from pathlib import Path
import bluepysnap as snap

circ_path = Path("/Users/mwr/Documents/artefacts/SONATA/O1_data/circuit_config.json")
node_set = "S1nonbarrel_neurons"
node_id = 1337

circ = snap.Circuit(circ_path)

# %%
tst = obi.RandomlySelectedNumberOfSynapses(
    n=3
)
display(tst.synapses_on(circ, node_set, node_id))

tst = obi.RandomlySelectedNumberOfSynapses(
    n=3,
    section_types=(1,),
    pre_synapse_class="INH",
    pre_node_populations=("S1nonbarrel_neurons",)
)
display(tst.synapses_on(circ, node_set, node_id))
# Out:
# {}
#         source_population                                    edge_population  \
# 776   S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
# 393                   VPM                 VPM__S1nonbarrel_neurons__chemical
# 1744  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
#
#       edge_id  afferent_section_id  afferent_segment_id  \
# 776   1185898                  144                    5
# 393    178649                  153                    6
# 1744  1186866                  124                   10
#
#       afferent_segment_offset  @source_node  @target_node  \
# 776                  2.893842         14524          1337
# 393                  0.423346         11533          1337
# 1744                 0.853679        138265          1337
#
#       afferent_section_type
# 776                       3
# 393                       4
# 1744                      3
# {'synapse_class': 'INH', 'source_population': ['S1nonbarrel_neurons'], 'afferent_section_type': [1]}
# /Users/mwr/Documents/repositories/obi-one/obi_one/scientific/afferent_synapse_finder/find_specified_afferent_synapses.py:54: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pre_node_props = pandas.concat(pre_node_props, axis=0, names=["source_population", "edge_population"],
#         source_population                                    edge_population  \
# 1840  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
# 1841  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
# 1850  S1nonbarrel_neurons  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...
#
#       edge_id  afferent_section_id  afferent_segment_id  \
# 1840  1186962                    0                    0
# 1841  1186963                    0                    0
# 1850  1186972                    0                    0
#
#       afferent_segment_offset  @source_node  @target_node synapse_class  \
# 1840                      0.0        141883          1337           INH
# 1841                      0.0        141883          1337           INH
# 1850                      0.0        141883          1337           INH
#
#       afferent_section_type
# 1840                      1
# 1841                      1
# 1850                      1

# %%
tst = obi.ClusteredPDSynapsesByMaxDistance(
    n_clusters=3,
    cluster_max_distance=25.0,
    soma_pd_mean=100.0,
    soma_pd_sd=10.0
)
display(tst.synapses_on(circ, node_set, node_id))

tst = obi.ClusteredPDSynapsesByMaxDistance(
    n_clusters=3,
    cluster_max_distance=25.0,
    soma_pd_mean=100.0,
    soma_pd_sd=10.0,
    pre_node_populations=("VPM", "POm")
)
display(tst.synapses_on(circ, node_set, node_id))
# Out:
# {}
#       cluster_id    source_population  \
# 108            0                  VPM
# 151            0                  VPM
# 172            0                  VPM
# 257            0                  VPM
# 290            0                  VPM
# ...          ...                  ...
# 1575           2  S1nonbarrel_neurons
# 1712           2  S1nonbarrel_neurons
# 1766           2  S1nonbarrel_neurons
# 1777           2  S1nonbarrel_neurons
# 1965           2  S1nonbarrel_neurons
#
#                                         edge_population  edge_id  \
# 108                  VPM__S1nonbarrel_neurons__chemical   178364
# 151                  VPM__S1nonbarrel_neurons__chemical   178407
# 172                  VPM__S1nonbarrel_neurons__chemical   178428
# 257                  VPM__S1nonbarrel_neurons__chemical   178513
# 290                  VPM__S1nonbarrel_neurons__chemical   178546
# ...                                                 ...      ...
# 1575  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186697
# 1712  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186834
# 1766  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186888
# 1777  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1186899
# 1965  S1nonbarrel_neurons__S1nonbarrel_neurons__chem...  1187087
#
#       afferent_section_id  afferent_segment_id  afferent_segment_offset  \
# 108                   122                   38                 1.423923
# 151                   122                   52                 0.762191
# 172                   122                   35                 0.196120
# 257                   122                   47                 1.253788
# 290                   122                   24                 0.480743
# ...                   ...                  ...                      ...
# 1575                  115                   32                 0.478972
# 1712                  115                   50                 0.384419
# 1766                  115                   66                 0.011807
# 1777                  115                   60                 0.037433
# 1965                  115                   57                 0.208582
#
#       @source_node  @target_node  afferent_section_type
# 108           4487          1337                      3
# 151           6247          1337                      3
# 172           6372          1337                      3
# 257           7504          1337                      3
# 290           8615          1337                      3
# ...            ...           ...                    ...
# 1575        123603          1337                      3
# 1712        135957          1337                      3
# 1766        138690          1337                      3
# 1777        138816          1337                      3
# 1965        149390          1337                      3
#
# [97 rows x 10 columns]
# {'source_population': ['VPM', 'POm']}
#      cluster_id source_population                     edge_population  \
# 153           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 173           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 240           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 321           0               VPM  VPM__S1nonbarrel_neurons__chemical
# 121           1               VPM  VPM__S1nonbarrel_neurons__chemical
# 220           1               VPM  VPM__S1nonbarrel_neurons__chemical
# 226           1               VPM  VPM__S1nonbarrel_neurons__chemical
# 300           1               VPM  VPM__S1nonbarrel_neurons__chemical
# 334           1               VPM  VPM__S1nonbarrel_neurons__chemical
# 343           1               VPM  VPM__S1nonbarrel_neurons__chemical
# 354           1               VPM  VPM__S1nonbarrel_neurons__chemical
# 157           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 163           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 243           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 279           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 322           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 376           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 408           2               VPM  VPM__S1nonbarrel_neurons__chemical
# 431           2               VPM  VPM__S1nonbarrel_neurons__chemical
#
#      edge_id  afferent_section_id  afferent_segment_id  \
# 153   178409                  102                   24
# 173   178429                  102                   38
# 240   178496                  102                   37
# 321   178577                  102                   35
# 121   178377                  155                   21
# 220   178476                  155                   17
# 226   178482                  155                    0
# 300   178556                  155                   25
# 334   178590                  155                   15
# 343   178599                  155                    7
# 354   178610                  155                   21
# 157   178413                  101                   32
# 163   178419                  101                   57
# 243   178499                  101                   56
# 279   178535                  101                   69
# 322   178578                  101                   46
# 376   178632                  101                   50
# 408   178664                  101                   46
# 431   178687                  101                   54
#
#      afferent_segment_offset  @source_node  @target_node  \
# 153                 0.626658          6247          1337
# 173                 1.269388          6372          1337
# 240                 1.685837          7419          1337
# 321                 0.613510          9047          1337
# 121                 0.999704          4889          1337
# 220                 1.669493          7264          1337
# 226                 0.125993          7307          1337
# 300                 1.971910          8736          1337
# 334                 0.744264          9474          1337
# 343                 0.846280          9773          1337
# 354                 1.607831         10689          1337
# 157                 0.326422          6247          1337
# 163                 0.267532          6266          1337
# 243                 0.785262          7419          1337
# 279                 0.005200          8215          1337
# 322                 0.146503          9047          1337
# 376                 0.922205         11100          1337
# 408                 0.661682         11901          1337
# 431                 0.600292         12383          1337
#
#      afferent_section_type
# 153                      3
# 173                      3
# 240                      3
# 321                      3
# 121                      4
# 220                      4
# 226                      4
# 300                      4
# 334                      4
# 343                      4
# 354                      4
# 157                      3
# 163                      3
# 243                      3
# 279                      3
# 322                      3
# 376                      3
# 408                      3
# 431                      3
