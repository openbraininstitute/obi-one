# %% [markdown]
# # Basic connectivity plots
#
# Example notebook on how to generate basic connectivity plots from a ConnectivityMatrix object

# %%
import obi

# %%
basic_connectivity_plots_form = obi.BasicConnectivityPlots(
                    initialize=obi.BasicConnectivityPlots.Initialize(
                        matrix_path=[obi.NamedPath(name="Human_L23", path="/Users/danielaegas/Desktop/Human_pruned_E_to_E_conmat.h5"),
                                     obi.NamedPath(name="Rat_2015", path="/Users/danielaegas/Desktop/connectome.h5")],
                        plot_formats=("png",) # sub-tuple of ('png', 'pdf', 'svg'), if not specified all are plotted
                        # plot_types=("nodes",) # sub-tuple of ('nodes', 'connectivity_global', 'connectivity_pathway'), if not specified all are plotted
                        #dpi=int default 300
                        )
                        )

grid_scan = obi.GridScan(form=basic_connectivity_plots_form, output_root='../../obi-output/basic_connectivity_plots/grid_scan', coordinate_directory_option="VALUE")

# %%
grid_scan.run()
# Out:
# Plot Formats: ('png',)
# Plot Types: ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Running idx 0, plots for ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Loading matrix 'Human_L23'
# Neuron, connection and synapse counts
# [  20064 3595201 9309663]
# <BarContainer object of 2 artists>
# <BarContainer object of 2 artists>
# Done with 0
# Plot Formats: ('png',)
# Plot Types: ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Running idx 1, plots for ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Loading matrix 'Rat_2015'
# Neuron, connection and synapse counts
# [  31346 7803528 7803528]
# <BarContainer object of 2 artists>
# <BarContainer object of 2 artists>
# Done with 1

# %%
# Display the intermediary data
grid_scan.multiple_value_parameters(display=True)
grid_scan.coordinate_parameters(display=True)
grid_scan.coordinate_instances(display=True)
# Out:
# MULTIPLE VALUE PARAMETERS
# initialize.matrix_path: [Human_L23, Rat_2015]
#
# COORDINATE PARAMETERS (Reimplement)
# initialize.matrix_path: Human_L23
# initialize.matrix_path: Rat_2015
#
# COORDINATE INSTANCES
# BasicConnectivityPlot(idx=0, scan_output_root='', coordinate_directory_option='NAME_EQUALS_VALUE', single_coordinate_scan_params=SingleCoordinateScanParams(type='SingleCoordinateScanParams', scan_params=[SingleValueScanParam(type='SingleValueScanParam', location_list=['initialize', 'matrix_path'], value=Human_L23)], nested_coordinate_subpath_str=''), type='BasicConnectivityPlots', initialize=Initialize(type='BasicConnectivityPlots.Initialize', matrix_path=Human_L23, plot_formats=('png',), plot_types=('nodes', 'connectivity_global', 'connectivity_pathway'), dpi=300))
# BasicConnectivityPlot(idx=1, scan_output_root='', coordinate_directory_option='NAME_EQUALS_VALUE', single_coordinate_scan_params=SingleCoordinateScanParams(type='SingleCoordinateScanParams', scan_params=[SingleValueScanParam(type='SingleValueScanParam', location_list=['initialize', 'matrix_path'], value=Rat_2015)], nested_coordinate_subpath_str=''), type='BasicConnectivityPlots', initialize=Initialize(type='BasicConnectivityPlots.Initialize', matrix_path=Rat_2015, plot_formats=('png',), plot_types=('nodes', 'connectivity_global', 'connectivity_pathway'), dpi=300))
# [BasicConnectivityPlot(idx=0, scan_output_root='', coordinate_directory_option='NAME_EQUALS_VALUE', single_coordinate_scan_params=SingleCoordinateScanParams(type='SingleCoordinateScanParams', scan_params=[SingleValueScanParam(type='SingleValueScanParam', location_list=['initialize', 'matrix_path'], value=Human_L23)], nested_coordinate_subpath_str=''), type='BasicConnectivityPlots', initialize=Initialize(type='BasicConnectivityPlots.Initialize', matrix_path=Human_L23, plot_formats=('png',), plot_types=('nodes', 'connectivity_global', 'connectivity_pathway'), dpi=300)),
#  BasicConnectivityPlot(idx=1, scan_output_root='', coordinate_directory_option='NAME_EQUALS_VALUE', single_coordinate_scan_params=SingleCoordinateScanParams(type='SingleCoordinateScanParams', scan_params=[SingleValueScanParam(type='SingleValueScanParam', location_list=['initialize', 'matrix_path'], value=Rat_2015)], nested_coordinate_subpath_str=''), type='BasicConnectivityPlots', initialize=Initialize(type='BasicConnectivityPlots.Initialize', matrix_path=Rat_2015, plot_formats=('png',), plot_types=('nodes', 'connectivity_global', 'connectivity_pathway'), dpi=300))]

# %%
# Deserialize
grid_scan_ds = obi.deserialize_obi_object_from_json_file("../../obi-output/basic_connectivity_plots/grid_scan/run_scan_config.json")
grid_scan_ds
# Out:
# GridScan(type='GridScan', form=BasicConnectivityPlots(type='BasicConnectivityPlots', initialize=Initialize(type='BasicConnectivityPlots.Initialize', matrix_path=[Human_L23, Rat_2015], plot_formats=('png',), plot_types=('nodes', 'connectivity_global', 'connectivity_pathway'), dpi=300)), output_root='../../obi-output/basic_connectivity_plots/grid_scan', coordinate_directory_option='VALUE')

# %%
grid_scan_ds.run()
# Out:
# Plot Formats: ('png',)
# Plot Types: ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Running idx 0, plots for ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Loading matrix 'Human_L23'
# Neuron, connection and synapse counts
# [  20064 3595201 9309663]
# <BarContainer object of 2 artists>
# <BarContainer object of 2 artists>
# Done with 0
# Plot Formats: ('png',)
# Plot Types: ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Running idx 1, plots for ('nodes', 'connectivity_global', 'connectivity_pathway')
# Info: Loading matrix 'Rat_2015'
# Neuron, connection and synapse counts
# [  31346 7803528 7803528]
# <BarContainer object of 2 artists>
# <BarContainer object of 2 artists>
# Done with 1

# %%
grid_coord_ds = obi.deserialize_obi_object_from_json_file("../../obi-output/basic_connectivity_plots/grid_scan/Human_L23/run_coordinate_instance.json")
