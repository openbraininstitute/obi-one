# %% [markdown]
# # MEModel With Synapses Simulation Example with Inter-Spike Interval Distribution Stimuli
#
# This notebook demonstrates how to run an MEModel With Synapses simulation using the OBI-One form-based workflow.
#
# It also shows the inter-spike-interval distribution workflow, where spike trains are generated by sampling intervals from reusable distribution blocks.
#
# This example covers:
#
# 1. Connecting to the staging entitycore database
# 2. Creating a simulation form
# 3. Defining timestamps and stimuli
# 4. Using `InterSpikeIntervalDistributionSpikeStimulus` with an explicit `ExponentialDistribution`
# 5. Validating and running the simulation
# 6. Inspecting output spikes and recordings

# %%
from entitysdk import Client
from obi_auth import get_token

import obi_one as obi
from entitysdk import Client, ProjectContext


obi_one_api_url = "http://127.0.0.1:8100"

token = get_token(environment="staging")
project_context = ProjectContext(virtual_lab_id=obi.LAB_ID_STAGING_TEST, project_id=obi.PROJECT_ID_STAGING_TEST)
db_client = Client(api_url="https://staging.openbraininstitute.org/api/entitycore", project_context=project_context, token_manager=token)

# %% [markdown]
# ## Select the synaptome circuit
#
# Set the entity ID of the MEModel With Synapses circuit to simulate.

# %%
entity_ID = "5c43e35b-7e44-4705-a2a1-2e5ac24af536"

# %% [markdown]
# ## Create the simulation form

# %%
sim_form = obi.MEModelWithSynapsesCircuitSimulationScanConfig.empty_config()
sim_duration = 1500.0

# Info
info = obi.Info(
    campaign_name="MEModel With Synapses Simulation",
    campaign_description="Simulation of example MEModel With Synapses"
)
sim_form.set(info, name="info")

# %% [markdown]
# ## Define timestamps
#
# Stimuli can be repeated over time using timestamp blocks.

# %%
timestamps = obi.RegularTimestamps(
    start_time=0.0,
    number_of_repetitions=3,
    interval=500.0,
)
sim_form.add(timestamps, name="Timestamps")

# %% [markdown]
# ## Define distribution blocks
#
# A spike train can be generated by sampling inter-spike intervals (ISI) from a distribution.
#
# Common examples:
#
# - `FloatConstantDistribution` → regular spikes
# - `ExponentialDistribution` → Poisson-like spikes
# - `GammaDistribution` → controllable spike-timing regularity
#
# Here we define an exponential distribution corresponding to a Poisson-like input.

# %%
poisson_interval = obi.ExponentialDistribution(
    scale=20.0,  # mean interval in ms -> ~50 Hz
    random_seed=42,
)

sim_form.add(poisson_interval, name="PoissonInterval")

# %% [markdown]
# ## Initialize the circuit
#
# Set the circuit and simulation parameters first so that the available populations
# can be inspected before defining spike replay neuron sets.

# %%
init = obi.MEModelWithSynapsesCircuitSimulationScanConfig.Initialize(
    circuit=obi.MEModelWithSynapsesCircuitFromID(id_str=entity_ID),
    simulation_length=sim_duration,
)
sim_form.set(init, name="initialize")

# %% [markdown]
# ## Add spike replay stimuli
#
# This example demonstrates how to define spike replay inputs using distribution-driven spike generation.
#
# ### `InterSpikeIntervalDistributionSpikeStimulus`
# A stimulus that explicitly references a distribution block used to sample inter-spike intervals.

# %%
distribution_spike_stimulus = obi.InterSpikeIntervalDistributionSpikeStimulus(
    duration=500.0,
    timestamps=timestamps.ref,
    distribution=obi.AllDistributionsReference(
        block_dict_name="distributions",
        block_name="PoissonInterval",
    ),
    resample_each_repetition=True,
)
sim_form.add(distribution_spike_stimulus, name="DistributionSpikeInput")

# %% [markdown]
# > Note
# > In this example, source and target neuron sets for spike replay are left implicit.
# >
# > A follow-up change may make it possible to explicitly select source and target
# > populations for replay stimuli in a more controlled way.

# %% [markdown]
# ## Add an additional current clamp stimulus

# %%
current_clamp = obi.ConstantCurrentClampSomaticStimulus(
    timestamps=timestamps.ref,
    duration=1000.0,
    amplitude=0.5,
)
sim_form.add(current_clamp, name="CurrentClampInput")

# %% [markdown]
# ## Add recording

# %%
recording = obi.SomaVoltageRecording()
sim_form.add(recording, name="SomaVoltage")

# %% [markdown]
# ## Initialize and validate the simulation form

# %%
init = obi.MEModelWithSynapsesCircuitSimulationScanConfig.Initialize(
    circuit=obi.MEModelWithSynapsesCircuitFromID(id_str=entity_ID),
    simulation_length=sim_duration,
)
sim_form.set(init, name="initialize")

validated_sim_conf = sim_form.validated_config()
print(validated_sim_conf)
# Out:
# MEModelWithSynapsesCircuitSimulationScanConfig(type='MEModelWithSynapsesCircuitSimulationScanConfig', info=Info(type='Info', campaign_name='MEModel With Synapses Simulation', campaign_description='Simulation of example MEModel With Synapses'), timestamps={'Timestamps': RegularTimestamps(type='RegularTimestamps', start_time=0.0, interval=500.0, number_of_repetitions=3)}, recordings={'SomaVoltage': SomaVoltageRecording(type='SomaVoltageRecording', neuron_set=None, dt=0.1)}, neuron_sets={}, synaptic_manipulations={}, initialize=Initialize(type='MEModelWithSynapsesCircuitSimulationScanConfig.Initialize', circuit=MEModelWithSynapsesCircuitFromID(id_str='5c43e35b-7e44-4705-a2a1-2e5ac24af536', type='MEModelWithSynapsesCircuitFromID'), simulation_length=1500.0, extracellular_calcium_concentration=1.1, v_init=-80.0, random_seed=1), stimuli={'DistributionSpikeInput': InterSpikeIntervalDistributionSpikeStimulus(type='InterSpikeIntervalDistributionSpikeStimulus', timestamps=TimestampsReference(b
# ...

# %% [markdown]
# ## Generate the scan and run tasks

# %%
grid_scan = obi.GridScanGenerationTask(
    form=validated_sim_conf,
    coordinate_directory_option="ZERO_INDEX",
    output_root="./obi-output/run_distribution_spike_simulation/grid_scan",
)
grid_scan.execute(db_client=db_client)
obi.run_tasks_for_generated_scan(grid_scan, db_client=db_client)

# %% [markdown]
# ## Inspect input spike replay (ISI stimulus)
#
# Before running the simulation, we can inspect the generated spike replay file to verify
# that the inter-spike interval statistics match the chosen distribution.m

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# Find spike replay file (adjust name if needed)
spike_file = list((grid_scan.single_configs[0].coordinate_output_root).glob("*_spikes.h5"))[0]
print(spike_file)

with h5py.File(spike_file, "r") as f:
    pop = list(f["/spikes"].keys())[0]
    timestamps = f[f"/spikes/{pop}/timestamps"][:]
    node_ids = f[f"/spikes/{pop}/node_ids"][:]
# Out:
# obi-output/run_distribution_spike_simulation/grid_scan/0/DistributionSpikeInput_spikes.h5

# %%
plt.figure(figsize=(8, 4))
plt.scatter(timestamps, node_ids, s=4)
plt.xlabel("Time (ms)")
plt.ylabel("Node ID")
plt.title("Input spike raster (ISI stimulus)")
plt.show()

# %%
isis = []

for gid in np.unique(node_ids):
    times = np.sort(timestamps[node_ids == gid])
    if len(times) > 1:
        isis.extend(np.diff(times))

plt.figure(figsize=(6, 4))
plt.hist(isis, bins=30)
plt.xlabel("Inter-spike interval (ms)")
plt.ylabel("Count")
plt.title("ISI distribution")
plt.show()

# %% [markdown]
# ## Inspect generated simulation files

# %%
simulation_config_path = (
    grid_scan.single_configs[0].coordinate_output_root / "simulation_config.json"
)
print(simulation_config_path)

circuit_folder = grid_scan.single_configs[0].coordinate_output_root / "sonata_circuit"
print(circuit_folder)
# Out:
# obi-output/run_distribution_spike_simulation/grid_scan/0/simulation_config.json
# obi-output/run_distribution_spike_simulation/grid_scan/0/sonata_circuit

# %% [markdown]
# ## Compile mod files
#
# If needed, compile the NEURON mod files for the generated circuit.

# %%
# Remove the old compiled mod files folder
! rm -r arm64/
# flag DISABLE_REPORTINGLIB to skip SonataReportHelper.mod and SonataReport.mod from compilation.
# !../../.venv/bin/nrnivmodl -incflags "-DDISABLE_REPORTINGLIB" {circuit_folder}/mod

# %% [markdown]
# ## Run the simulation with BlueCelluLab

# %%
from obi_one.scientific.library.simulation.entrypoint import run

run(
    simulation_config=simulation_config_path,
    simulator="bluecellulab",
    libnrnmech_path="./arm64",
)

# %% [markdown]
# ## Inspect spike output

# %%
import bluepysnap

snap_simulation = bluepysnap.Simulation(simulation_config_path)
spikes = snap_simulation.spikes

print(spikes.time_start, spikes.time_stop, spikes.dt)
print(spikes.population_names)
# Out:
# 0 1500.0 0.025
# ['hippocampus_neurons']

# %%
spike_pop = spikes[spikes.population_names[0]]
filtered = spikes.filter(t_start=spikes.time_start, t_stop=spikes.time_stop)
filtered.report.head()
# Out:
#          ids           population
# times
# 7.050      0  hippocampus_neurons
# 19.575     0  hippocampus_neurons
# 43.325     0  hippocampus_neurons
# 97.225     0  hippocampus_neurons
# 153.675    0  hippocampus_neurons

# %% [markdown]
# ## Inspect recorded voltage output

# %%
snap_simulation.reports
# Out:
# {'SomaVoltage': <bluepysnap.frame_report.SomaReport at 0x12469e0c0>}

# %%
soma_report = snap_simulation.reports["SomaVoltage"]
print(soma_report.time_start, soma_report.time_stop, soma_report.dt)
# Out:
# [Rank 0] 2026-04-30 11:38:05,180 WARNING bluepysnap.frame_report: dt from the report differs from the global simulation dt.
# 0.0 1500.0 0.1

# %% [markdown]
# ## Try other interval distributions
#
# You can swap the interval distribution used by `InterSpikeIntervalDistributionSpikeStimulus` to change spike statistics.
#
# Examples:
#
# - regular spikes:
#   ```python
#   obi.FloatConstantDistribution(value=50.0)
# - more regular stochastic spikes:
#   ```python
#   obi.GammaDistribution(shape=5.0, scale=10.0, random_seed=42)
# - different Poisson-like rate:
#   ```python
#   obi.ExponentialDistribution(scale=25.0, random_seed=42)  # ~40 Hz
