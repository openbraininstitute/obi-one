# %%
import obi_one as obi
from entitysdk import Client, ProjectContext

from obi_auth import get_token

token = get_token(environment="staging")
project_context = ProjectContext(virtual_lab_id=obi.LAB_ID_STAGING_TEST, project_id=obi.PROJECT_ID_STAGING_TEST)
db_client = Client(api_url="https://staging.openbraininstitute.org/api/entitycore", token_manager=token, project_context=project_context)

# %%
circuit_id = "7d007c43-201f-42d6-960d-93f6229fe935"

# %%
scan_config = obi.CreateExtracellularRecordingArrayScanConfig.empty_config()

info = obi.Info(campaign_name="Campaign Name", campaign_description="Campaign Description")
scan_config.set(info, name="info")

scan_config_initialize = obi.CreateExtracellularRecordingArrayScanConfig.Initialize(circuit=obi.CircuitFromID(id_str=circuit_id), 
                                                            calculation_method=["PointSource", "LineSource", "ObjectiveCSD"])
scan_config.set(scan_config_initialize, name='initialize')


validated_sim_conf = scan_config.validated_config()

# %%
grid_scan = obi.GridScanGenerationTask(form=validated_sim_conf, coordinate_directory_option="ZERO_INDEX", output_root='../../../../obi-output/circuit_simulations/grid_scan')
grid_scan.multiple_value_parameters(display=True)
grid_scan.coordinate_parameters(display=True)
grid_scan.execute(db_client=db_client)
obi.run_tasks_for_generated_scan(grid_scan, db_client=db_client)
# Out:
# [2026-04-26 22:34:54,898] INFO:
# MULTIPLE VALUE PARAMETERS
# [2026-04-26 22:34:54,898] INFO: initialize.calculation_method: ['PointSource', 'LineSource', 'ObjectiveCSD']
# [2026-04-26 22:34:54,899] INFO:
# COORDINATE PARAMETERS
# [2026-04-26 22:34:54,899] INFO: initialize.calculation_method: PointSource
# [2026-04-26 22:34:54,899] INFO: initialize.calculation_method: LineSource
# [2026-04-26 22:34:54,899] INFO: initialize.calculation_method: ObjectiveCSD
# [2026-04-26 22:34:54,902] INFO: initialize.circuit is a CircuitFromID instance.
# [2026-04-26 22:34:55,847] INFO: HTTP Request: GET https://staging.openbraininstitute.org/api/entitycore/circuit/7d007c43-201f-42d6-960d-93f6229fe935 "HTTP/1.1 401 Unauthorized"
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/Documents/obi/code/obi-main/obi-one/.venv/lib/python3.12/site-packages/entitysdk/utils/http.py:62, in make_db_api_request(url, method, json, data, parameters, files, project_context, token, http_client)
#      61 try:
# ---> 62     response.raise_for_status()
#      63 except httpx.HTTPStatusError as e:
#
# File ~/Documents/obi/code/obi-main/obi-one/.venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://staging.openbraininstitute.org/api/entitycore/circuit/7d007c43-201f-42d6-960d-93f6229fe935'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# EntitySDKError                            Traceback (most recent call last)
# Cell In[4], line 5
#       3 grid_scan.coordinate_parameters(display=True)
#       4 grid_scan.execute(db_client=db_client)
# ----> 5 obi.run_tasks_for_generated_scan(grid_scan, db_client=db_client)
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/core/run_tasks.py:52, in run_tasks_for_generated_scan(scan_generation, db_client, entity_cache)
#      46 def run_tasks_for_generated_scan(
#      47     scan_generation: ScanGenerationTask,
#      48     *,
#      49     db_client: entitysdk.client.Client = None,
#      50     entity_cache: bool = False,
#      51 ) -> Any:
# ---> 52     return run_task_for_single_configs(
#      53         scan_generation.single_configs, db_client=db_client, entity_cache=entity_cache
#      54     )
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/core/run_tasks.py:41, in run_task_for_single_configs(single_configs, db_client, entity_cache)
#      34 def run_task_for_single_configs(
#      35     single_configs: list[SingleConfigMixin],
#      36     *,
#      37     db_client: entitysdk.client.Client = None,
#      38     entity_cache: bool = False,
#      39 ) -> list[Any]:
#      40     return [
# ---> 41         run_task_for_single_config(single_config, db_client=db_client, entity_cache=entity_cache)
#      42         for single_config in single_configs
#      43     ]
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/core/run_tasks.py:29, in run_task_for_single_config(single_config, db_client, entity_cache, execution_activity_id)
#      27 task_type = get_configs_task_type(single_config)
#      28 task = task_type(config=single_config)
# ---> 29 return task.execute(
#      30     db_client=db_client, entity_cache=entity_cache, execution_activity_id=execution_activity_id
#      31 )
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/scientific/tasks/create_recording_array/create_recording_array.py:196, in CreateExtracellularRecordingArrayTask.execute(self, db_client, entity_cache, execution_activity_id)
#     191 """Run the task."""
#     192 execution_activity = CreateExtracellularRecordingArrayTask._get_execution_activity(
#     193     db_client=db_client, execution_activity_id=execution_activity_id
#     194 )
# --> 196 self._resolve_circuit(db_client=db_client, entity_cache=entity_cache)
#     198 test_locations = [[0.0, 0.0, 0.0], [50.0, 50.0, 50.0]]  # multiple x, y, z locations to test
#     200 # Use BlueRecording to generate a weights file for the circuit and test locations
#     201 # Using the three valid values of self.config.initialize.calculation_method
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/scientific/tasks/create_recording_array/create_recording_array.py:175, in CreateExtracellularRecordingArrayTask._resolve_circuit(self, db_client, entity_cache)
#     171     else:
#     172         # Stage circuit in a temporary directory --> Will be deleted after extraction!
#     173         circuit_dest_dir = self._create_temp_dir() / "sonata_circuit"
# --> 175     self._circuit = self.config.initialize.circuit.stage_circuit(
#     176         db_client=db_client, dest_dir=circuit_dest_dir, entity_cache=entity_cache
#     177     )
#     178     self._circuit_entity = self.config.initialize.circuit.entity(db_client=db_client)
#     180 if self._circuit is None:
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/scientific/from_id/circuit_from_id.py:24, in CircuitFromID.stage_circuit(self, dest_dir, db_client, entity_cache)
#      17 def stage_circuit(
#      18     self,
#      19     *,
#    (...)     22     entity_cache: bool = False,
#      23 ) -> Circuit:
# ---> 24     for asset in self.entity(db_client=db_client).assets:
#      25         if asset.label == "sonata_circuit":
#      26             if not entity_cache and dest_dir.exists():
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/core/entity_from_id.py:28, in EntityFromID.entity(self, db_client)
#      26 def entity(self, db_client: entitysdk.client.Client) -> Entity:
#      27     if self._entity is None:
# ---> 28         self._entity = self.__class__.fetch(self.id_str, db_client=db_client)
#      29     return self._entity
#
# File ~/Documents/obi/code/obi-main/obi-one/obi_one/core/entity_from_id.py:24, in EntityFromID.fetch(cls, entity_id, db_client)
#      22 @classmethod
#      23 def fetch(cls, entity_id: str, db_client: entitysdk.client.Client) -> Entity:
# ---> 24     return db_client.get_entity(entity_id=entity_id, entity_type=cls.entitysdk_class)
#
# File ~/Documents/obi/code/obi-main/obi-one/.venv/lib/python3.12/site-packages/entitysdk/client.py:172, in Client.get_entity(self, entity_id, entity_type, project_context, options, admin)
#     163 url = route.get_entities_endpoint(
#     164     api_url=self.api_url,
#     165     entity_type=entity_type,
#     166     entity_id=entity_id,
#     167     admin=admin,
#     168 )
#     169 context = (
#     170     self._optional_user_context(override_context=project_context) if not admin else None
#     171 )
# --> 172 return core.get_entity(
#     173     url=url,
#     174     options=options,
#     175     entity_type=entity_type,
#     176     project_context=context,
#     177     http_client=self._http_client,
#     178     token=self._token_manager.get_token(),
#     179 )
#
# File ~/Documents/obi/code/obi-main/obi-one/.venv/lib/python3.12/site-packages/entitysdk/core.py:94, in get_entity(url, entity_type, project_context, token, options, http_client)
#      84 def get_entity(
#      85     url: str,
#      86     *,
#    (...)     91     http_client: httpx.Client | None = None,
#      92 ) -> TIdentifiable:
#      93     """Instantiate entity with model ``entity_type`` from resource id."""
# ---> 94     response = make_db_api_request(
#      95         url=url,
#      96         method="GET",
#      97         json=None,
#      98         parameters=options,
#      99         project_context=project_context,
#     100         token=token,
#     101         http_client=http_client,
#     102     )
#     103     return serdes.deserialize_model(response.json(), entity_type)
#
# File ~/Documents/obi/code/obi-main/obi-one/.venv/lib/python3.12/site-packages/entitysdk/utils/http.py:71, in make_db_api_request(url, method, json, data, parameters, files, project_context, token, http_client)
#      63 except httpx.HTTPStatusError as e:
#      64     message = (
#      65         f"HTTP error {response.status_code} for {method} {url}\n"
#      66         f"data       : {data}\n"
#    (...)     69         f"response   : {response.text}"
#      70     )
# ---> 71     raise EntitySDKError(message) from e
#      72 return response
#
# EntitySDKError: HTTP error 401 for GET https://staging.openbraininstitute.org/api/entitycore/circuit/7d007c43-201f-42d6-960d-93f6229fe935
# data       : None
# json       : null
# params     : None
# response   : {"error_code":"NOT_AUTHENTICATED","message":"User not authenticated","details":null}
