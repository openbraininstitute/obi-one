# %% [markdown]
# Circuit Simulation Example with OBI-One
# ======================================
#
# This notebook demonstrates how to run circuit simulations using the obi-one simulation framework
# with [BlueCelluLab](https://github.com/openbraininstitute/BlueCelluLab) as the simulator. Let's get the path to the simulation configuration and circuit configuration file paths and the population name of the circuit that you want to simulate.
#
# For this example, we will use the pre-made `simulation_config.json` (simulation configuration) file instead of the one generated by obi-one.

# %% [markdown]
# To Do
# - get circuit from entioty core
# - generate simualtion config
# - stage if necessary
# - run it with bluecellulab

# %% [markdown]
# Get circuit from entitycore

# %%
from entitysdk import Client, ProjectContext, models
from obi_auth import get_token
import os
import time
import obi_one as obi
from pathlib import Path

# Authenticate
proj_url = "https://www.openbraininstitute.org/app/virtual-lab/lab/04c93af1-5955-43a9-9180-b8a4bda4712c/project/50280a36-44b9-45e7-8b7d-db220a203ce5/explore/interactive/model/circuit?br_id=4642cddb-4fbe-4aae-bbf7-0946d6ada066&br_av=8"
token = get_token(environment="production", auth_mode="daf")
project_context = ProjectContext.from_vlab_url(proj_url)
client = Client(environment="production", project_context=project_context, token_manager=token)

# %%
# Download using unique ID
# nbS1-O1-E2PV-maxNsyn-HEX0-L3
entity_ID = "b595c41d-b721-4125-8048-a6e2164cdd08"  # <<< FILL IN UNIQUE CIRCUIT ID HERE

# # Fetch circuit
fetched = client.get_entity(entity_id=entity_ID, entity_type=models.Circuit)
print(f"Circuit fetched: {fetched.name} (ID {fetched.id})\n")
print(f"#Neurons: {fetched.number_neurons}, #Synapses: {fetched.number_synapses}, #Connections: {fetched.number_connections}\n")
print(f"{fetched.description}\n")

# Download SONATA circuit files
asset = [asset for asset in fetched.assets if asset.label=="sonata_circuit"][0]
asset_dir = asset.path 
circuit_dir = "analysis_circuit"
assert not os.path.exists(asset_dir), f"ERROR: Circuit download folder '{asset_dir}' already exists! Please delete folder."
assert not os.path.exists(circuit_dir), f"ERROR: Circuit folder '{circuit_dir}' already exists! Delete folder or choose a different path."

t0 = time.time()
client.download_directory(
    entity_id=fetched.id,
    entity_type=models.Circuit,
    asset_id=asset.id,
    output_path=".",
    max_concurrent=4,  # Parallel file download
)
t = time.time() - t0
print(f"Circuit files downloaded to '{asset_dir}' in {t:.1f}s")
# Out:
# 2025-07-23 15:17:32,444 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08 "HTTP/1.1 200 OK"
# Circuit fetched: nbS1-O1-E2PV-maxNsyn-HEX0-L3 (ID b595c41d-b721-4125-8048-a6e2164cdd08)
#
# #Neurons: 2, #Synapses: 48, #Connections: 1
#
# A neuron pair from the nbS1-O1 circuit, located in layer 3 of subcolumn HEX0. The pair consists of one excitatory neuron targeting one inhibitory PV (parvalbumin) neuron, with the highest number of synapses connecting them.
#
# 2025-07-23 15:17:32,624 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:32,959 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/list "HTTP/1.1 200 OK"
# 2025-07-23 15:17:33,247 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=.DS_Store "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:33,792 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=S1nonbarrel_neurons%2Fnodes.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:33,841 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=POm__S1nonbarrel_neurons__chemical%2Fedges.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:33,844 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=POm%2Fnodes.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:33,915 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/.DS_Store?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=B%2Fn1rxUJhlZxnASGro8GCqU8Tl0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277253 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:34,110 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=S1nonbarrel_neurons__S1nonbarrel_neurons__chemical%2Fedges.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:34,380 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/S1nonbarrel_neurons/nodes.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=34lONF6sqHMeK3SxTkodLsgc0l0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277253 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:34,385 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/S1nonbarrel_neurons__S1nonbarrel_neurons__chemical/edges.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=WLPBU36CT8XV7mdgC2FkFxWPCZ4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277254 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:34,408 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/POm/nodes.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=qE5D%2FLIqiseOh0XjeCEM2Qu0WNg%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277253 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:34,458 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/POm__S1nonbarrel_neurons__chemical/edges.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=lF3FvzxtY4N6Pwpeiot6%2B45QvP8%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277253 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:34,601 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=VPM%2Fnodes.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:34,617 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=VPM__S1nonbarrel_neurons__chemical%2Fedges.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:34,885 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/VPM/nodes.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=Ksm6UxPng8daTUEI6rBkHjRQ2yM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277254 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:34,957 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/VPM__S1nonbarrel_neurons__chemical/edges.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=58RUsCmqy%2FbFHxPuIhzbWXjkNi0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277254 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:35,092 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=circuit_config.json "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:35,166 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=emodels_hoc%2FcACint_L23MC.hoc "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:35,190 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=emodels_hoc%2FcADpyr_L2TPC.hoc "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:35,361 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/circuit_config.json?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=uQV2wWK%2Bb8EtyneJnvAn5qI0Vvs%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277255 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:35,369 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/emodels_hoc/cACint_L23MC.hoc?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=TkILcoCwK8xC4eIFhqSnE51gO2g%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277255 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:35,433 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/emodels_hoc/cADpyr_L2TPC.hoc?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=7tFvl3nvtv3dabIam0ZEF9cDxEg%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277255 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:35,580 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=external_S1nonbarrel_neurons%2Fnodes.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:35,584 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=external_S1nonbarrel_neurons__S1nonbarrel_neurons__chemical.h5 "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:35,664 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=id_mapping.json "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:35,694 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FCaDynamics_DC0.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:35,851 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/external_S1nonbarrel_neurons__S1nonbarrel_neurons__chemical.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=B6ZYwLbe2TSo5uGiszL1aLsgBL4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277255 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:35,894 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/id_mapping.json?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=SRcGjzWz8d4VRWFw1P%2BpKvRrYvk%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277255 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:35,936 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/external_S1nonbarrel_neurons/nodes.h5?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=PExmUfuzi6ghT3Y%2Fn4O5QnQiRjQ%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277255 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:36,056 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/CaDynamics_DC0.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=Uk5XOYUDDq1pQqcB%2F2AiijNEEW0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277255 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:36,210 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FCa_HVA2.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:36,332 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FCa_LVAst.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:36,356 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FConductanceSource.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:36,430 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/Ca_HVA2.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=M39YSZ3XikVx%2BP1QYBNMEc88l8I%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277256 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:36,659 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/Ca_LVAst.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=WvhN6tZ1kvBLRq1XK2uxruZO%2FOA%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277256 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:36,671 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/ConductanceSource.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=Iv990L9QeBQsZry8WSooGIj0eUE%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277256 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:36,672 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FDetAMPANMDA.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:36,860 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FDetGABAAB.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:36,864 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FGluSynapse.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:36,894 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/DetAMPANMDA.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=m3fQ7%2BY%2FFlQqmiWn2Sm7HxSlNTU%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277256 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,031 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FIh.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:37,070 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/GluSynapse.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=qmQpqauvEWTg2PfzcErT836LUjM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277256 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,085 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/DetGABAAB.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=GDX8zd7GtcNPQNa0pqlUorsd46A%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277256 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,091 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FK_Pst.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:37,249 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/Ih.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=fL5i7Zuk6A%2BZLC%2FVDaGRYAnE%2FM4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277257 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,292 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FK_Tst.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:37,304 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FKdShu2007.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:37,352 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/K_Pst.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=Kcwvl%2FtwTjbRpu1ReLknWhfWHV0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277257 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,469 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FKv7.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:37,518 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/K_Tst.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=rYBZpUnsyi0%2Fm%2FsC0291lV96RcY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277257 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,519 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/KdShu2007.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=dNoPQYvq8KFHmKGqJN5dywQXdms%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277257 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,544 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FMembraneCurrentSource.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:37,709 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/Kv7.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=vpE9cGC%2F%2By8cRYXWX0I7JeDJ3p4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277257 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:37,716 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2FNaTg.mod "HTTP/1.1 307 Temporary Redirect"
# ...
# 2025-07-23 15:17:39,288 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=morphologies%2F.DS_Store "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:39,289 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=mod%2Fvecevent.mod "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:39,294 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/gap.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=KtgY9Yk2nBzuMbhKABMC4oQ73MQ%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:39,299 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/netstim_inhpoisson.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=1FNT9gvtwSkisfPixJ%2BgblKjF%2FU%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:39,510 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/morphologies/.DS_Store?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=GNLMC50AtsJElFja4B96jfu%2BvTM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:39,521 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=morphologies%2Fswc%2FmtC090800B_idB_-_Scale_x1.000_y1.050_z1.000.swc "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:39,522 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/mod/vecevent.mod?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=P8ng%2FiVs7YMATae4SyPOnY7iAhY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:39,522 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=morphologies%2Fswc%2Fdend-mtC221001A_idA_axon-C260897C-P2_-_Scale_x1.000_y1.050_z1.000.swc "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:39,798 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=node_sets.json "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:39,800 - httpx - INFO - HTTP Request: GET https://www.openbraininstitute.org/api/entitycore/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/assets/654a7853-1720-483b-8108-edef8c146b05/download?asset_path=run_coordinate_instance.json "HTTP/1.1 307 Temporary Redirect"
# 2025-07-23 15:17:39,811 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/morphologies/swc/mtC090800B_idB_-_Scale_x1.000_y1.050_z1.000.swc?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=bLVHDZYZ1NPbrwbk0QXaRplGHRY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:39,934 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/morphologies/swc/dend-mtC221001A_idA_axon-C260897C-P2_-_Scale_x1.000_y1.050_z1.000.swc?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=DlUbxC6ySmgTQN15thvRUi2o9gQ%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:40,042 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/node_sets.json?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=2Zgt2oFmxYWNxBY1R08Gs9NBpgI%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# 2025-07-23 15:17:40,085 - httpx - INFO - HTTP Request: GET https://entitycore-data-production.s3.amazonaws.com/public/5f8376bf-b84f-4188-8ef5-e1df3d7529b4/7d22829c-edc6-4b1d-8ab9-99dd9e511e74/assets/circuit/b595c41d-b721-4125-8048-a6e2164cdd08/sonata_circuit/run_coordinate_instance.json?AWSAccessKeyId=ASIAZYSNA64ZYRC3OKON&Signature=r9qaKWM9GVdfidELEeRFyfwhB9s%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEOn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIDdH9vTUF6IidQA8dIXNKLb8mkYRhnODc8cNgzbSKizBAiEA6oh0tylBuo%2Fz8CoS0nbso9zRnxm1dvLqzxW07GaFmsAqgwQIEhAAGgw2NzEyNTAxODM5ODciDB5RVvmPU70%2BbTZ5xyrgAystBf9MGoG2WNM1RB9g1UUfzVztOnj%2B%2BivCXhkUxeKNkTHLpV7mkt9i%2F96T0TbHaVrqy60lKsAFlQcj0YL2MlAABUinRHu3RAPKUqAQkv8%2BTIVbfo4ZxsCMCmnPxwZ4sH%2B%2FW%2BCCdM9OSL45WesZiwhC5sgQxCn%2B44FbY9O0GlZriLVv1Om7FdNoCxxrC%2BaUbpskphkfDCAyvIo6QxJ1AhdqnrEFKZaJ%2FW1XrcfP2D%2B0l3RdB11%2BpcHSQCkgBQSUWJFLhgvr3v5nEdutxj88DQ6f0hG39NcWGqX6hnapjat5KsukgNwe7t1C3OUl2QDX2fohdUF%2BqI19X6Fmojqn89N%2FLKJjZTkYAWlyPjeMECbrLCj%2FhCTzO9bHsfs%2Fab%2Be4xqThhLzGy%2FCr%2FMfLKTu7DCvcIMBAmwiUMz6H4PXlSfbr1tofZdFC%2FZSfUpFTOuKnVCZDGUA8OoSXT8Fe20sORh6Vo9KT%2BxZX45wYGHnjAAPzRxK2wKmb7yCkoNoh4SIkoRWJak7ili6CURp4JOFs2lge5x9lOQiEH%2B48QvA4SOmrGsjSumHUcHQeySkQ2%2FqQrQ5NS3xQZLFgIajSGgrfWBnjaY%2BoYPenHP2hhQ7vDCe7nPGz6uvMc%2Be8JjJFRXbnDDgvoLEBjqlAQBvT5bLRcZEc2jbq15JNAvYj%2B1eGRkQ6KxXDygaDvvHlLdqQEuwk%2FtUF3nNK3FwsrGBeHPFxTyZ%2BM1IHw1kdMj554htmA0jJ729GYk350wIKUoRimPwjsAvJlmrB9o31Ec7wSn6TdoSHWZ1npNES5Bblnci8LcoXhLi8IW%2FKYPhK0%2BxSuJZvbruZDAa0T7ENasocMT6uxbx4Dtk9pWaqoUAfa6OOA%3D%3D&Expires=1753277259 "HTTP/1.1 200 OK"
# Circuit files downloaded to 'sonata_circuit' in 9.5s

# %% [markdown]
# Generate Simulation Config with new nodeset

# %%
circuit_path_prefix = "sonata_circuit/"
circ_path = f"{circuit_path_prefix}/circuit_config.json"
circuit = obi.Circuit(name="nbS1-O1-E2PV-maxNsyn-HEX0-L3", path=circ_path)
print(f"Circuit '{circuit}' with {circuit.sonata_circuit.nodes.size} neurons and {circuit.sonata_circuit.edges.size} synapses")
print(f"Default node population: '{circuit.default_population_name}'")
# Out:
# Circuit 'nbS1-O1-E2PV-maxNsyn-HEX0-L3' with 720 neurons and 3112 synapses
# Default node population: 'S1nonbarrel_neurons'

# %%
# Get SONATA circuit object
c = circuit.sonata_circuit
# Out:
# ...id': [], 'layer': ['6']}}

# %%
# Adding a node set to the circuit
obi.NeuronSet.add_node_set_to_circuit(c, {"my_new_node_set": {
    "population": "S1nonbarrel_neurons",
    "node_id": [0, 1]
  }
})

# %%
print("..." + str(c.node_sets.content)[-80:])
# Out:
# {'Mosaic': ['All'],
#  'All': ['L4_SBC',
#   'L5_TPC:B',
#   'L4_NBC',
#   'L4_DBC',
#   'L23_DBC',
#   'L5_TPC:A',
#   'L3_TPC:A',
#   'L4_BTC',
#   'L6_BTC',
#   'L4_UPC',
#   'L6_LBC',
#   'L6_IPC',
#   'L23_BP',
#   'L4_MC',
#   'L5_DBC',
#   'L6_NBC',
#   'L1_LAC',
#   'L6_CHC',
#   'L23_MC',
#   'L1_HAC',
#   'L6_NGC',
#   'L4_NGC',
#   'L2_IPC',
#   'L6_HPC',
#   'L5_BTC',
#   'L4_CHC',
#   'L5_NGC',
#   'L4_BP',
#   'L2_TPC:A',
#   'L5_SBC',
#   'L5_UPC',
#   'L6_DBC',
#   'L23_CHC',
#   'L5_NBC',
#   'L1_NGC-SA',
#   'L6_BPC',
#   'L6_UPC',
#   'L23_LBC',
#   'L4_SSC',
#   'L5_LBC',
#   'L6_SBC',
#   'L1_NGC-DA',
#   'L6_TPC:C',
#   'L23_SBC',
#   'L5_MC',
#   'L1_DAC',
#   'L2_TPC:B',
#   'L6_TPC:A',
#   'L5_CHC',
#   'L23_NBC',
#   'L3_TPC:C',
#   'L6_BP',
#   'L4_LBC',
#   'L5_BP',
#   'L23_BTC',
#   'L6_MC',
#   'L1_SAC',
#   'L4_TPC',
#   'L5_TPC:C',
#   'L23_NGC'],
#  'Excitatory': {'synapse_class': 'EXC'},
#  'Inhibitory': {'synapse_class': 'INH'},
#  'L1_DAC': {'mtype': 'L1_DAC'},
#  'L1_HAC': {'mtype': 'L1_HAC'},
#  'L1_LAC': {'mtype': 'L1_LAC'},
#  'L1_NGC-DA': {'mtype': 'L1_NGC-DA'},
#  'L1_NGC-SA': {'mtype': 'L1_NGC-SA'},
#  'L1_SAC': {'mtype': 'L1_SAC'},
#  'L23_BP': {'mtype': 'L23_BP'},
#  'L23_BTC': {'mtype': 'L23_BTC'},
#  'L23_CHC': {'mtype': 'L23_CHC'},
#  'L23_DBC': {'mtype': 'L23_DBC'},
#  'L23_LBC': {'mtype': 'L23_LBC'},
#  'L23_MC': {'mtype': 'L23_MC'},
#  'L23_NBC': {'mtype': 'L23_NBC'},
#  'L23_NGC': {'mtype': 'L23_NGC'},
#  'L23_SBC': {'mtype': 'L23_SBC'},
#  'L2_IPC': {'mtype': 'L2_IPC'},
#  'L2_TPC:A': {'mtype': 'L2_TPC:A'},
#  'L2_TPC:B': {'mtype': 'L2_TPC:B'},
#  'L3_TPC:A': {'mtype': 'L3_TPC:A'},
#  'L3_TPC:C': {'mtype': 'L3_TPC:C'},
#  'L4_BP': {'mtype': 'L4_BP'},
#  'L4_BTC': {'mtype': 'L4_BTC'},
#  'L4_CHC': {'mtype': 'L4_CHC'},
#  'L4_DBC': {'mtype': 'L4_DBC'},
#  'L4_LBC': {'mtype': 'L4_LBC'},
#  'L4_MC': {'mtype': 'L4_MC'},
#  'L4_NBC': {'mtype': 'L4_NBC'},
#  'L4_NGC': {'mtype': 'L4_NGC'},
#  'L4_SBC': {'mtype': 'L4_SBC'},
#  'L4_SSC': {'mtype': 'L4_SSC'},
#  'L4_TPC': {'mtype': 'L4_TPC'},
#  'L4_UPC': {'mtype': 'L4_UPC'},
#  'L5_BP': {'mtype': 'L5_BP'},
#  'L5_BTC': {'mtype': 'L5_BTC'},
#  'L5_CHC': {'mtype': 'L5_CHC'},
#  'L5_DBC': {'mtype': 'L5_DBC'},
#  'L5_LBC': {'mtype': 'L5_LBC'},
#  'L5_MC': {'mtype': 'L5_MC'},
#  'L5_NBC': {'mtype': 'L5_NBC'},
#  'L5_NGC': {'mtype': 'L5_NGC'},
#  'L5_SBC': {'mtype': 'L5_SBC'},
#  'L5_TPC:A': {'mtype': 'L5_TPC:A'},
#  'L5_TPC:B': {'mtype': 'L5_TPC:B'},
#  'L5_TPC:C': {'mtype': 'L5_TPC:C'},
#  'L5_UPC': {'mtype': 'L5_UPC'},
#  'L6_BP': {'mtype': 'L6_BP'},
#  'L6_BPC': {'mtype': 'L6_BPC'},
#  'L6_BTC': {'mtype': 'L6_BTC'},
#  'L6_CHC': {'mtype': 'L6_CHC'},
#  'L6_DBC': {'mtype': 'L6_DBC'},
#  'L6_HPC': {'mtype': 'L6_HPC'},
#  'L6_IPC': {'mtype': 'L6_IPC'},
#  'L6_LBC': {'mtype': 'L6_LBC'},
#  'L6_MC': {'mtype': 'L6_MC'},
#  'L6_NBC': {'mtype': 'L6_NBC'},
#  'L6_NGC': {'mtype': 'L6_NGC'},
#  'L6_SBC': {'mtype': 'L6_SBC'},
#  'L6_TPC:A': {'mtype': 'L6_TPC:A'},
#  'L6_TPC:C': {'mtype': 'L6_TPC:C'},
#  'L6_UPC': {'mtype': 'L6_UPC'},
#  'bAC': {'etype': 'bAC'},
#  'bIR': {'etype': 'bIR'},
#  'bNAC': {'etype': 'bNAC'},
#  'bSTUT': {'etype': 'bSTUT'},
#  'cACint': {'etype': 'cACint'},
#  'cADpyr': {'etype': 'cADpyr'},
#  'cIR': {'etype': 'cIR'},
#  'cNAC': {'etype': 'cNAC'},
#  'cSTUT': {'etype': 'cSTUT'},
#  'dNAC': {'etype': 'dNAC'},
#  'dSTUT': {'etype': 'dSTUT'},
#  'Layer1': {'layer': '1'},
#  'Layer2': {'layer': '2'},
#  'Layer3': {'layer': '3'},
#  'Layer4': {'layer': '4'},
#  'Layer5': {'layer': '5'},
#  'Layer6': {'layer': '6'},
#  'Layer2Excitatory': ['L2_TPC:A', 'L2_TPC:B', 'L2_IPC'],
#  'Layer3Excitatory': ['L3_TPC:C', 'L3_TPC:A'],
#  'Layer23Excitatory': ['Layer3Excitatory', 'Layer2Excitatory'],
#  'Layer4Excitatory': ['L4_UPC', 'L4_TPC', 'L4_SSC'],
#  'Layer5Excitatory': ['L5_UPC', 'L5_TPC:A', 'L5_TPC:B', 'L5_TPC:C'],
#  'Layer6Excitatory': ['L6_BPC',
#   'L6_HPC',
#   'L6_UPC',
#   'L6_TPC:C',
#   'L6_IPC',
#   'L6_TPC:A'],
#  'Layer1Inhibitory': ['L1_HAC',
#   'L1_NGC-SA',
#   'L1_NGC-DA',
#   'L1_DAC',
#   'L1_SAC',
#   'L1_LAC'],
#  'Layer23Inhibitory': ['L23_NGC',
#   'L23_DBC',
#   'L23_LBC',
#   'L23_BTC',
#   'L23_SBC',
#   'L23_BP',
#   'L23_MC',
#   'L23_NBC',
#   'L23_CHC'],
#  'Layer4Inhibitory': ['L4_SBC',
#   'L4_NBC',
#   'L4_DBC',
#   'L4_NGC',
#   'L4_LBC',
#   'L4_BTC',
#   'L4_CHC',
#   'L4_BP',
#   'L4_MC'],
#  'Layer5Inhibitory': ['L5_NBC',
#   'L5_BTC',
#   'L5_BP',
#   'L5_LBC',
#   'L5_NGC',
#   'L5_MC',
#   'L5_DBC',
#   'L5_SBC',
#   'L5_CHC'],
#  'Layer6Inhibitory': ['L6_NGC',
#   'L6_BP',
#   'L6_BTC',
#   'L6_SBC',
#   'L6_LBC',
#   'L6_MC',
#   'L6_NBC',
#   'L6_DBC',
#   'L6_CHC'],
#  'hex0': {'population': 'S1nonbarrel_neurons', 'node_id': [0, 1]},
#  'hex1': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'hex2': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'hex3': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'hex4': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'hex5': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'hex6': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'hex_O1': ['hex6', 'hex0', 'hex4', 'hex2', 'hex3', 'hex5', 'hex1'],
#  'hex_O1PV': {'population': 'S1nonbarrel_neurons', 'node_id': [1]},
#  'hex_O1Sst': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'hex_O15HT3aR': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'proj_Thalamocortical_VPM_Source': {'population': 'VPM'},
#  'proj_Thalamocortical_POM_Source': {'population': 'POm'},
#  'nbS1-HEX0': {'population': 'S1nonbarrel_neurons', 'node_id': [0, 1]},
#  'nbS1-HEX1': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'nbS1-HEX2': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'nbS1-HEX3': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'nbS1-HEX4': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'nbS1-HEX5': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'nbS1-HEX6': {'population': 'S1nonbarrel_neurons', 'node_id': []},
#  'nbS1-HEX0-L1': {'population': 'S1nonbarrel_neurons',
#   'node_id': [0, 1],
#   'layer': ['1']},
#  'nbS1-HEX1-L1': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['1']},
#  'nbS1-HEX2-L1': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['1']},
#  'nbS1-HEX3-L1': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['1']},
#  'nbS1-HEX4-L1': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['1']},
#  'nbS1-HEX5-L1': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['1']},
#  'nbS1-HEX6-L1': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['1']},
#  'nbS1-HEX0-L23': {'population': 'S1nonbarrel_neurons',
#   'node_id': [0, 1],
#   'layer': ['2', '3']},
#  'nbS1-HEX1-L23': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['2', '3']},
#  'nbS1-HEX2-L23': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['2', '3']},
#  'nbS1-HEX3-L23': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['2', '3']},
#  'nbS1-HEX4-L23': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['2', '3']},
#  'nbS1-HEX5-L23': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['2', '3']},
#  'nbS1-HEX6-L23': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['2', '3']},
#  'nbS1-HEX0-L4': {'population': 'S1nonbarrel_neurons',
#   'node_id': [0, 1],
#   'layer': ['4']},
#  'nbS1-HEX1-L4': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['4']},
#  'nbS1-HEX2-L4': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['4']},
#  'nbS1-HEX3-L4': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['4']},
#  'nbS1-HEX4-L4': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['4']},
#  'nbS1-HEX5-L4': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['4']},
#  'nbS1-HEX6-L4': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['4']},
#  'nbS1-HEX0-L5': {'population': 'S1nonbarrel_neurons',
#   'node_id': [0, 1],
#   'layer': ['5']},
#  'nbS1-HEX1-L5': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['5']},
#  'nbS1-HEX2-L5': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['5']},
#  'nbS1-HEX3-L5': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['5']},
#  'nbS1-HEX4-L5': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['5']},
#  'nbS1-HEX5-L5': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['5']},
#  'nbS1-HEX6-L5': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['5']},
#  'nbS1-HEX0-L6': {'population': 'S1nonbarrel_neurons',
#   'node_id': [0, 1],
#   'layer': ['6']},
#  'nbS1-HEX1-L6': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['6']},
#  'nbS1-HEX2-L6': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['6']},
#  'nbS1-HEX3-L6': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['6']},
#  'nbS1-HEX4-L6': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['6']},
#  'nbS1-HEX5-L6': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['6']},
#  'nbS1-HEX6-L6': {'population': 'S1nonbarrel_neurons',
#   'node_id': [],
#   'layer': ['6']},
#  'my_new_node_set': {'population': 'S1nonbarrel_neurons', 'node_id': [0, 1]}}

# %%
# Write new circuit's node set file
obi.NeuronSet.write_circuit_node_set_file(c, output_path="./", file_name="new_node_sets.json", overwrite_if_exists=True)

# %%
# Sim duration
sim_duration = 3000.0

# Empty Simulation Configuration
sim_conf = obi.SimulationsForm.empty_config()

# Info
info = obi.Info(campaign_name="Small Microcircuit Simulation", campaign_description="Simulation of circuit with predefined neuron set and constant current stimulus")
sim_conf.set(info, name="info")

# Neuron Sets
sim_neuron_set = obi.IDNeuronSet(neuron_ids=obi.NamedTuple(name="IDNeuronSet1", elements=range(1)))
sim_conf.add(sim_neuron_set, name='ID1')

sync_neuron_set = obi.IDNeuronSet(neuron_ids=obi.NamedTuple(name="IDNeuronSet2", elements=range(1,3)))
sim_conf.add(sync_neuron_set, name='ID2')


# Regular Timesteps
regular_timestamps = obi.RegularTimestamps(start_time=0.0, number_of_repetitions=3, interval=sim_duration)
sim_conf.add(regular_timestamps, name='RegularTimestamps')

# Stimulus
poisson_input = obi.PoissonSpikeStimulus(duration=800.0, timestamps=regular_timestamps.ref, frequency=20, source_neuron_set=sim_neuron_set.ref, targeted_neuron_set=sim_neuron_set.ref)
sim_conf.add(poisson_input, name='PoissonInputStimulus')

# sync_input = obi.FullySynchronousSpikeStimulus(timestamps=regular_timestamps.ref, source_neuron_set=sync_neuron_set.ref, targeted_neuron_set=sim_neuron_set.ref)
# sim_conf.add(sync_input, name='SynchronousInputStimulus')

# current_stim = obi.ConstantCurrentClampSomaticStimulus(timestamps=regular_timestamps.ref, neuron_set=sim_neuron_set.ref, amplitude=0.1)
# sim_conf.add(current_stim, name='ConstantCurrentClampSomaticStimulus')

# Recordings
voltage_recording = obi.SomaVoltageRecording(neuron_set=sim_neuron_set.ref)
sim_conf.add(voltage_recording, name='VoltageRecording')

time_window_voltage_recording = obi.TimeWindowSomaVoltageRecording(neuron_set=sim_neuron_set.ref, start_time=0.0, end_time=2000.0)
sim_conf.add(time_window_voltage_recording, name='TimeWindowVoltageRecording')

# Initialization
simulations_initialize = obi.SimulationsForm.Initialize(circuit=obi.CircuitFromID(id_str=entity_ID), 
                                                        node_set=sim_neuron_set.ref, 
                                                        simulation_length=sim_duration)
sim_conf.set(simulations_initialize, name='initialize')

# Validated Config
validated_sim_conf = sim_conf.validated_config()

# %%
population_name = "S1nonbarrel_neurons"
circuit_folder = "../data/tiny_circuits/N_10__top_nodes_dim6__asc/"
circuit_config_path = "../data/tiny_circuits/N_10__top_nodes_dim6__asc/circuit_config.json"
simulation_config_path = "../data/tiny_circuits/N_10__top_nodes_dim6__asc/simulation_config.json"

# %% [markdown]
# Get the path to the mod files and compile the mod files.

# %%
# Remove the old compiled mod files folder
! rm -r arm64/
# flag DISABLE_REPORTINGLIB to skip SonataReportHelper.mod and SonataReport.mod from compilation.
# !nrnivmodl -incflags "-DDISABLE_REPORTINGLIB" {circuit_folder}/mod
# !nrnivmodl {circuit_folder}/mod

# %% [markdown]
# Import required modules from obi-one

# %%
from obi_one.scientific.simulation.simulations import Simulation
from obi_one.scientific.simulation.stimulus import ConstantCurrentClampSomaticStimulus
from obi_one.scientific.simulation.recording import SomaVoltageRecording
from obi_one.scientific.simulation.timestamps import RegularTimestamps
from obi_one.scientific.circuit.neuron_sets import IDNeuronSet
from obi_one.core.tuple import NamedTuple
from obi_one.scientific.unions.unions_neuron_sets import NeuronSetReference
from obi_one.scientific.unions.unions_timestamps import TimestampsReference
from matplotlib import pyplot as plt

# %% [markdown]
# Create the `Simulation` object.

# %%
# Stimulus
poisson_input = obi.PoissonSpikeStimulus(duration=800.0, timestamps=regular_timestamps.ref, frequency=20, source_neuron_set=sim_neuron_set.ref, targeted_neuron_set=sim_neuron_set.ref)
sim_conf.add(poisson_input, name='PoissonInputStimulus')

# %%
# Create regular timestamps with start, end, and dt
timestamps = RegularTimestamps(
    number_of_repetitions=1,
    interval=100.0,  # ms
    start_time=0.0,  # ms
    end_time=100.0,  # ms
    dt=0.1,          # ms
    simulation_level_name="timestamps_1"
)

# Create a NamedTuple with the neuron IDs
neuron_ids = NamedTuple(name="neuron_ids", elements=[1, 2, 3])  # List of cell IDs to include

# Create neuron set using IDNeuronSet
neuron_set = IDNeuronSet(
    population=population_name,
    neuron_ids=neuron_ids,
    simulation_level_name="neuron_set_1"
)

# First, create the timestamps reference
timestamps_ref = TimestampsReference(block=timestamps, block_name="timestamps_1")

# Then create the stimulus with the reference
stimulus = ConstantCurrentClampSomaticStimulus(
    timestamps=timestamps_ref,
    delay=10.0,  # ms
    duration=50.0,  # ms
    amplitude=0.1,  # nA
    neuron_set=NeuronSetReference(block=neuron_set, block_name="neuron_set_1"),
    simulation_level_name="stimulus_1"
)
# Create recordings (example with voltage recording)
recording = SomaVoltageRecording(
    start_time=0.0,
    end_time=100.0,
    dt=0.1,
    neuron_set=NeuronSetReference(block=neuron_set, block_name="neuron_set_1"),
    simulation_level_name="voltage_recording_1"
)

from obi_one.scientific.circuit.circuit import Circuit

# First create the circuit object
circuit = Circuit(
    name="N_10__top_nodes_dim6__asc",
    path=circuit_config_path,
    node_population=population_name,
)

from obi_one.core.info import Info
# Create info object
simulation_info = Info(
    campaign_name="N_10__top_nodes_dim6__asc Simulation",
    campaign_description="A test simulation with a small microcircuit",
)

# Then use it in the simulation initialization
simulation = Simulation(
    name="simulation_1",
    info=simulation_info,
    timestamps={"timestamps_1": timestamps},  # Make sure this matches the block_name
    stimuli={"stimulus_1": stimulus},
    recordings={"voltage_recording_1": recording},
    neuron_sets={"neuron_set_1": neuron_set},
    initialize={
        "circuit": circuit,
        "simulation_length": 100.0,  # ms
        "node_set": NeuronSetReference(block=neuron_set, block_name="neuron_set_1"),
        "timestep": 0.025  # ms
    }
)

# %%
# Get SONATA circuit object
c = circuit.sonata_circuit
print("..." + str(c.node_sets.content)[-25:])

# Adding a node set to the circuit
obi.NeuronSet.add_node_set_to_circuit(c, {"Layer23": {"layer": [2, 3]}})
print("..." + str(c.node_sets.content)[-55:])

# Adding a node set with an exising name => NOT POSSIBLE
# obi.NeuronSet.add_node_set_to_circuit(c, {"Layer23": {"layer": [2, 3]}})  # AssertionError: Node set 'Layer23' already exists!

# Update/overwrite an existing node set
obi.NeuronSet.add_node_set_to_circuit(c, {"Layer23": ["Layer2", "Layer3"]}, overwrite_if_exists=True)  # Update/overwrite
print("..." + str(c.node_sets.content)[-58:])

# Adding multiple node sets
obi.NeuronSet.add_node_set_to_circuit(c, {"Layer45": ["Layer4", "Layer5"], "Layer56": ["Layer5", "Layer6"]})
print("..." + str(c.node_sets.content)[-124:])

# Add node set from NeuronSet object, resolved in circuit's default node population
neuron_set = obi.CombinedNeuronSet(node_sets=("Layer1", "Layer2", "Layer3"))
obi.NeuronSet.add_node_set_to_circuit(c, {"Layer123": neuron_set.get_node_set_definition(circuit, circuit.default_population_name)})
print("..." + str(c.node_sets.content)[-168:])

# Adding a node sets based on previously added node sets
obi.NeuronSet.add_node_set_to_circuit(c, {"AllLayers": ["Layer123", "Layer4", "Layer56"]})
print("..." + str(c.node_sets.content)[-216:])

# Write new circuit's node set file
obi.NeuronSet.write_circuit_node_set_file(c, output_path="./", file_name="new_node_sets.json", overwrite_if_exists=True)

# %% [markdown]
# Run circuit simulation using BlueCelluLab backend. In future, we will support Neurodamus backend as well. This will run a SONATA simulation and save voltage traces for the specified cells.

# %%
# Run the simulation
simulation.run(
    simulation_config=simulation_config_path,
    simulator="bluecellulab", # Optional: bluecellulab or neurodamus. Default: bluecellulab
    save_nwb=True            # Optional: Save results in NWB format. Default: False
)

# %% [markdown]
# The results are stored in the output directory of the circuit folder. The logs are also stored in the logs in notebooks folder.

# %% [markdown]
# ### Spike Report Analysis using BluePySnap
#
# We will use the example [notebook](https://github.com/openbraininstitute/snap/blob/master/doc/source/notebooks/06_spike_reports.ipynb) from BluePySnap to analyse the spike report generated by the circuit simulation.

# %%
import bluepysnap

snap_simulation = bluepysnap.Simulation(simulation_config_path)
spikes = snap_simulation.spikes
print(
    spikes.time_start,
    spikes.time_stop,
    spikes.dt
)
print(spikes.population_names)

# %% [markdown]
# See what simulation_config.json file contents:

# %%
snap_simulation.config

# %%
spike_pop = spikes['S1nonbarrel_neurons']
print(type(spike_pop))

node_population = spike_pop.nodes
print(f'{node_population.name}: {type(node_population)}')

# %% [markdown]
# ids = spike_pop.node_ids
# node_population.get(ids, properties=['layer','synapse_class','x','y','z']).head()

# %%
filtered = spikes.filter(group={'layer':'6'}, t_start=spikes.time_start, t_stop=spikes.time_stop)
filtered.report.head()

# %%
filtered.raster();

# %%
filtered.firing_rate_histogram();

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.gca()
ax.set_xlabel("Time [ms]")
ax.set_ylabel("PSTH [Hz]")
ax.set_title(f"PSTH for group: {filtered.group}")

times = filtered.report.index

time_start = np.min(times)
time_stop = np.max(times)

# heuristic for a nice bin size (~100 spikes per bin on average)
time_binsize = min(50.0, (time_stop - time_start) / ((len(times) / 100.0) + 1.0))

bins = np.append(np.arange(time_start, time_stop, time_binsize), time_stop)
hist, bin_edges = np.histogram(times, bins=bins)
node_count = len(snap_simulation.circuit.nodes.ids(filtered.group))  # Get length of node ids for whole `group`
freq = 1.0 * hist / node_count / (0.001 * time_binsize)

# use the middle of the bins instead of the start of the bin
ax.plot(0.5 * (bin_edges[1:] + bin_edges[:-1]), freq, label="PSTH", drawstyle="steps-mid");

# %%
spikes.filter().raster();

# %%
spikes.filter().raster(y_axis='etype');

# %%
spikes.filter().isi(binsize=100);

# %% [markdown]
# ### Soma Report Analysis
#
# Let's [load](https://github.com/openbraininstitute/snap/blob/master/doc/source/notebooks/07_frame_reports.ipynb) the soma report using BluePySnap and plot it.

# %%
snap_simulation.reports

# %%
soma_report = snap_simulation.reports['SomaVoltRec']

# %%
print(
    soma_report.time_start,
    soma_report.time_stop,
    soma_report.dt,
    soma_report.time_units
)  # Gives a warning in case the dt differs from simulation.dt

# %%
soma_report.population_names

# %%
soma_pop = soma_report['S1nonbarrel_neurons']
print(type(soma_pop))

# %%
node_population = soma_pop.nodes
print(f'{node_population.name}: {type(node_population)}')

# %%
ids = soma_pop.node_ids
node_population.get(ids, properties=['layer','synapse_class','x','y','z']).head()

# %%
filtered = soma_report.filter(group={'layer':'6'}, t_start= soma_report.time_start, t_stop= soma_report.time_stop)
filtered.report.head()

# %%
filtered.trace();

# %%
soma_report.filter().trace();
